# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_final.csv'
df = pd.read_csv (dataset_path)
df
# Out:
#     year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0      2009-12            67       4950       2549  34382.0          8549.0
# 1      2010-01            33       1966        954  13781.0          3127.0
# 2      2010-02            34       2046       1749  10434.0          2244.0
# 3      2010-03           148       3124       1862  30397.0          6404.0
# 4      2010-04            61       2009        447  11846.0          2502.0
# ..         ...           ...        ...        ...      ...             ...
# 147    2022-03             1         11          2      0.0             0.0
# 148    2022-04             2         12          8    773.0           195.0
# 149    2022-05             0          0          0      0.0             0.0
# 150    2022-06             0          0          0      0.0             0.0
# 151    2022-07             1         23         27      0.0             0.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0           220329.0       0.607826             0.622492              0.611475
# 1            96179.0       0.474168             0.722588              0.609118
# 2            62732.0       0.659774             0.537594              0.651629
# 3           176282.0       0.494667             0.542906              0.640304
# 4            71821.0       0.479652             0.626278              0.510277
# ..               ...            ...                  ...                   ...
# 147              0.0       0.000000             0.000000              0.000000
# 148           4484.0       0.000000             0.000000              0.000000
# 149              0.0       0.000000             0.000000              0.000000
# 150              0.0       0.000000             0.000000              0.000000
# 151              0.0       0.000000             0.000000              0.000000
#
# [152 rows x 10 columns]

# %%
# df['year_month'] = pd.to_datetime(df['year_month'])
df = df.set_index(df['year_month'])
df
# Out:
#            year_month  commit_count  additions  deletions  agg_loc  \
# year_month
# 2009-12       2009-12            67       4950       2549  34382.0
# 2010-01       2010-01            33       1966        954  13781.0
# 2010-02       2010-02            34       2046       1749  10434.0
# 2010-03       2010-03           148       3124       1862  30397.0
# 2010-04       2010-04            61       2009        447  11846.0
# ...               ...           ...        ...        ...      ...
# 2022-03       2022-03             1         11          2      0.0
# 2022-04       2022-04             2         12          8    773.0
# 2022-05       2022-05             0          0          0      0.0
# 2022-06       2022-06             0          0          0      0.0
# 2022-07       2022-07             1         23         27      0.0
#
#             agg_complexity  agg_token_count  dmm_unit_size  \
# year_month
# 2009-12             8549.0         220329.0       0.607826
# 2010-01             3127.0          96179.0       0.474168
# 2010-02             2244.0          62732.0       0.659774
# 2010-03             6404.0         176282.0       0.494667
# 2010-04             2502.0          71821.0       0.479652
# ...                    ...              ...            ...
# 2022-03                0.0              0.0       0.000000
# 2022-04              195.0           4484.0       0.000000
# 2022-05                0.0              0.0       0.000000
# 2022-06                0.0              0.0       0.000000
# 2022-07                0.0              0.0       0.000000
#
#             dmm_unit_complexity  dmm_unit_interfacing
# year_month
# 2009-12                0.622492              0.611475
# 2010-01                0.722588              0.609118
# 2010-02                0.537594              0.651629
# 2010-03                0.542906              0.640304
# 2010-04                0.626278              0.510277
# ...                         ...                   ...
# 2022-03                0.000000              0.000000
# 2022-04                0.000000              0.000000
# 2022-05                0.000000              0.000000
# 2022-06                0.000000              0.000000
# 2022-07                0.000000              0.000000
#
# [152 rows x 10 columns]

# %%
pre_covid_ym = '2020-02'
covid_ym = '2020-03'
df1 = df [ str(df.year_month[0]) : pre_covid_ym ]
df2 = df [ covid_ym: str(df.year_month[-1]) ]
df1 = df1.reset_index ( drop = True )
df2 = df2.reset_index ( drop = True )

df1.shape, df2.shape
# Out:
# ((123, 10), (29, 10))

# %%
from top_contributors import get_equilibrium_pc, get_pareto_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, len(df1.columns) ):
    print ( f'{df1.columns[idx]} = { get_equilibrium_pc ( list ( df1[df1.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 10
# additions = 8
# deletions = 6
# agg_loc = 9
# agg_complexity = 9
# agg_token_count = 9
# dmm_unit_size = 20
# dmm_unit_complexity = 21
# dmm_unit_interfacing = 23

# %%
print("Post-pandemic equilibrium percentages:")
for idx in range ( 1, len(df2.columns) ):
    print ( f'{df2.columns[idx]} = { get_equilibrium_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Post-pandemic equilibrium percentages:
# commit_count = 10
# additions = 7
# deletions = 7
# agg_loc = 10
# agg_complexity = 10
# agg_token_count = 10
# dmm_unit_size = 7
# dmm_unit_complexity = 10
# dmm_unit_interfacing = 7

# %%
print("Pre-pandemic Pareto percentages:")
for idx in range ( 1, len(df1.columns) ):
    print ( f'{df1.columns[idx]} = { get_pareto_pc ( list ( df1[df1.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic Pareto percentages:
# commit_count = 25
# additions = 16
# deletions = 17
# agg_loc = 23
# agg_complexity = 23
# agg_token_count = 23
# dmm_unit_size = 37
# dmm_unit_complexity = 39
# dmm_unit_interfacing = 42

# %%
print("Post-pandemic Pareto percentages:")
for idx in range ( 1, len(df2.columns) ):
    print ( f'{df2.columns[idx]} = { get_pareto_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Post-pandemic Pareto percentages:
# commit_count = 17
# additions = 10
# deletions = 10
# agg_loc = 13
# agg_complexity = 13
# agg_token_count = 13
# dmm_unit_size = 10
# dmm_unit_complexity = 13
# dmm_unit_interfacing = 10
