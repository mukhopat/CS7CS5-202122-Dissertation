# %%
from pydriller import Repository
from time import time
from datetime import timedelta
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
repo_path = f'./clone/{repo_name}'

commit_data = []

start_time = time()

for commit in Repository(repo_path).traverse_commits():
    for file in commit.modified_files:
        commit_data.append( [
            commit.hash, 
            commit.author.name, 
            commit.author.email,
            commit.committer_date,
            commit.merge,
            commit.dmm_unit_size,
            commit.dmm_unit_complexity,
            commit.dmm_unit_interfacing,
            file.filename, 
            file.change_type, 
            file.added_lines, 
            file.deleted_lines,
            file.nloc,
            file.complexity,
            file.token_count
        ] )
        
print( f'Execution time = { str ( timedelta ( seconds = time() - start_time ) ) }' )
# Out:
# Execution time = 0:01:12.097212

# %%
import pandas as pd

df = pd.DataFrame(commit_data)

df.columns = [
    'commit_hash', 
    'commit_author_name', 
    'commit_author_email',
    'commit_datetime', 
    'commit_merge',
    'dmm_unit_size',
    'dmm_unit_complexity',
    'dmm_unit_interfacing',
    'file_name', 
    'file_change_type', 
    'file_lines_added',
    'file_lines_deleted',
    'file_loc',
    'file_complexity',
    'file_token_count'
]

df
# Out:
#                                    commit_hash commit_author_name  \
# 0     c876efacfb69277173d11dbdafb3fd809b3532b4       Kyle Simpson
# 1     c876efacfb69277173d11dbdafb3fd809b3532b4       Kyle Simpson
# 2     3c9a22974a96dbc794414ecd3376ba2b43a2caa2       Kyle Simpson
# 3     3c9a22974a96dbc794414ecd3376ba2b43a2caa2       Kyle Simpson
# 4     3c9a22974a96dbc794414ecd3376ba2b43a2caa2       Kyle Simpson
# ...                                        ...                ...
# 2739  6668deaa8a6f45c31e5eaf308d92b858fdbf4261       Kyle Simpson
# 2740  6668deaa8a6f45c31e5eaf308d92b858fdbf4261       Kyle Simpson
# 2741  2cb92444a613004fd09a6696a6810f3986a01242       Kyle Simpson
# 2742  2cb92444a613004fd09a6696a6810f3986a01242       Kyle Simpson
# 2743  0a5ffd75f6d5593d55b467e2962daa95a5b8d946       Kyle Simpson
#
#      commit_author_email            commit_datetime  commit_merge  \
# 0       getify@gmail.com  2013-11-16 07:58:12+05:18         False
# 1       getify@gmail.com  2013-11-16 07:58:12+05:18         False
# 2       getify@gmail.com  2013-11-16 08:05:49+05:18         False
# 3       getify@gmail.com  2013-11-16 08:05:49+05:18         False
# 4       getify@gmail.com  2013-11-16 08:05:49+05:18         False
# ...                  ...                        ...           ...
# 2739    getify@gmail.com  2022-08-04 00:07:03-05:00         False
# 2740    getify@gmail.com  2022-08-04 00:07:03-05:00         False
# 2741    getify@gmail.com  2022-08-05 12:13:18-05:00         False
# 2742    getify@gmail.com  2022-08-05 12:13:18-05:00         False
# 2743    getify@gmail.com  2022-08-06 11:27:48-05:00         False
#
#       dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing   file_name  \
# 0               NaN                  NaN                   NaN   README.md
# 1               NaN                  NaN                   NaN  preface.md
# 2               NaN                  NaN                   NaN      apA.md
# 3               NaN                  NaN                   NaN      apB.md
# 4               NaN                  NaN                   NaN      apC.md
# ...             ...                  ...                   ...         ...
# 2739            NaN                  NaN                   NaN      ch1.md
# 2740            NaN                  NaN                   NaN      ch2.md
# 2741            NaN                  NaN                   NaN      ch1.md
# 2742            NaN                  NaN                   NaN      ch2.md
# 2743            NaN                  NaN                   NaN      ch2.md
#
#              file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0        ModificationType.ADD                35                   0       NaN
# 1        ModificationType.ADD                44                   0       NaN
# 2        ModificationType.ADD                56                   0       NaN
# 3        ModificationType.ADD               111                   0       NaN
# 4        ModificationType.ADD               114                   0       NaN
# ...                       ...               ...                 ...       ...
# 2739  ModificationType.MODIFY                25                   2       NaN
# 2740  ModificationType.MODIFY                39                  16       NaN
# 2741  ModificationType.MODIFY                 5                  75       NaN
# 2742  ModificationType.MODIFY               192                   5       NaN
# 2743  ModificationType.MODIFY               143                   5       NaN
#
#       file_complexity  file_token_count
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 2739              NaN               NaN
# 2740              NaN               NaN
# 2741              NaN               NaN
# 2742              NaN               NaN
# 2743              NaN               NaN
#
# [2744 rows x 15 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_modfiles.csv', index = False )
