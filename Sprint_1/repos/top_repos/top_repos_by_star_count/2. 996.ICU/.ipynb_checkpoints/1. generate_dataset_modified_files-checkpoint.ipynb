# %%
from pydriller import Repository
from time import time
from datetime import timedelta
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
repo_path = f'./clone/{repo_name}'

commit_data = []

start_time = time()

for commit in Repository(repo_path).traverse_commits():
    for file in commit.modified_files:
        commit_data.append( [
            commit.hash, 
            commit.author.name, 
            commit.author.email,
            commit.committer_date,
            commit.merge,
            commit.dmm_unit_size,
            commit.dmm_unit_complexity,
            commit.dmm_unit_interfacing,
            file.filename, 
            file.change_type, 
            file.added_lines, 
            file.deleted_lines,
            file.nloc,
            file.complexity,
            file.token_count
        ] )
        
print( f'Execution time = { str ( timedelta ( seconds = time() - start_time ) ) }' )
# Out:
# Execution time = 0:02:01.021587

# %%
import pandas as pd

df = pd.DataFrame(commit_data)

df.columns = [
    'commit_hash', 
    'commit_author_name', 
    'commit_author_email',
    'commit_datetime', 
    'commit_merge',
    'dmm_unit_size',
    'dmm_unit_complexity',
    'dmm_unit_interfacing',
    'file_name', 
    'file_change_type', 
    'file_lines_added',
    'file_lines_deleted',
    'file_loc',
    'file_complexity',
    'file_token_count'
]

df
# Out:
#                                    commit_hash commit_author_name  \
# 0     f57407db93b2bbcf15b59af10e6f689ca8443372             996icu
# 1     80eb8ea2e4462e7c0f83b071545e9b01bcf0e63c             996icu
# 2     87de776ac2c22174cbb3a554e89a0ff2a1fadcc5             996icu
# 3     51881babca2db8a8ef8c066f134216218deada0d             996icu
# 4     e85dda6f6303f60c3ff9a763e0de3ca91fe81009          calvin325
# ...                                        ...                ...
# 2875  6483189681ba935986029982e359376fb70504d3              Z-fly
# 2876  82bfafe1af8fc60cfb3f16e1ca7b067c978d4ddd              Z-fly
# 2877  b0f5287b694f0bd1a07b61e38eaca528915c6563              Z-fly
# 2878  febba5572832053f3bb2d714acc427acdd535624              Z-fly
# 2879  a46869f8d851328a26758489d40931ffcadd6bbc              Z-fly
#
#                            commit_author_email            commit_datetime  \
# 0     48942249+996icu@users.noreply.github.com  2019-03-26 15:31:43+08:00
# 1     48942249+996icu@users.noreply.github.com  2019-03-26 17:47:17+08:00
# 2     48942249+996icu@users.noreply.github.com  2019-03-26 18:08:38+08:00
# 3     48942249+996icu@users.noreply.github.com  2019-03-26 18:10:21+08:00
# 4                          calvin325@gmail.com  2019-03-26 23:29:39+08:00
# ...                                        ...                        ...
# 2875                         2658041579@qq.com  2022-01-25 19:55:34+08:00
# 2876                         2658041579@qq.com  2022-01-25 20:26:05+08:00
# 2877                         2658041579@qq.com  2022-01-25 20:27:07+08:00
# 2878                         2658041579@qq.com  2022-01-25 20:37:59+08:00
# 2879                         2658041579@qq.com  2022-01-25 20:38:21+08:00
#
#       commit_merge  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0            False            NaN                  NaN                   NaN
# 1            False            NaN                  NaN                   NaN
# 2            False            NaN                  NaN                   NaN
# 3            False            NaN                  NaN                   NaN
# 4            False            NaN                  NaN                   NaN
# ...            ...            ...                  ...                   ...
# 2875         False            NaN                  NaN                   NaN
# 2876         False            NaN                  NaN                   NaN
# 2877         False            NaN                  NaN                   NaN
# 2878         False            NaN                  NaN                   NaN
# 2879         False            NaN                  NaN                   NaN
#
#          file_name         file_change_type  file_lines_added  \
# 0        README.md     ModificationType.ADD                 2
# 1        README.md  ModificationType.MODIFY                 2
# 2        README.md  ModificationType.MODIFY                22
# 3        README.md  ModificationType.MODIFY                 0
# 4        README.md  ModificationType.MODIFY                 1
# ...            ...                      ...               ...
# 2875  README_CN.md  ModificationType.MODIFY                 1
# 2876     README.md  ModificationType.MODIFY                 1
# 2877     README.md  ModificationType.MODIFY                 1
# 2878     README.md  ModificationType.MODIFY                 1
# 2879     README.md  ModificationType.MODIFY                 1
#
#       file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                      0       NaN              NaN               NaN
# 1                      0       NaN              NaN               NaN
# 2                      0       NaN              NaN               NaN
# 3                     19       NaN              NaN               NaN
# 4                      1       NaN              NaN               NaN
# ...                  ...       ...              ...               ...
# 2875                   1       NaN              NaN               NaN
# 2876                   1       NaN              NaN               NaN
# 2877                   1       NaN              NaN               NaN
# 2878                   1       NaN              NaN               NaN
# 2879                   1       NaN              NaN               NaN
#
# [2880 rows x 15 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_modfiles.csv', index = False )
