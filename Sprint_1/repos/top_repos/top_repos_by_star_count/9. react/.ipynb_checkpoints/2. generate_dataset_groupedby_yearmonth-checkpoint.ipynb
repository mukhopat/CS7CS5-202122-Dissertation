# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
# 1  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
# 2  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
# 3  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
# 4  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
#
#    commit_author_email            commit_datetime  commit_merge  \
# 0  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 1  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 2  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 3  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 4  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing        file_name  \
# 0       0.606371              0.73698              0.828562    .editorconfig
# 1       0.606371              0.73698              0.828562       .gitignore
# 2       0.606371              0.73698              0.828562        .jshintrc
# 3       0.606371              0.73698              0.828562  CONTRIBUTING.md
# 4       0.606371              0.73698              0.828562     Gruntfile.js
#
#        file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0  ModificationType.ADD                12                   0       NaN
# 1  ModificationType.ADD                21                   0       NaN
# 2  ModificationType.ADD                20                   0       NaN
# 3  ModificationType.ADD                63                   0       NaN
# 4  ModificationType.ADD                99                   0      71.0
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              2.0             463.0

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                     commit_hash year_month  \
# 0      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05
# 1      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05
# 2      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05
# 3      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05
# 4      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05
# ...                                         ...        ...
# 63716  ca990e9a753597768765e71c98fe650789c9ee8b    2022-08
# 63717  ca990e9a753597768765e71c98fe650789c9ee8b    2022-08
# 63718  ca990e9a753597768765e71c98fe650789c9ee8b    2022-08
# 63719  17e2a15bea2df9232411a35c6d967fa18f6e8b25    2022-08
# 63720  17e2a15bea2df9232411a35c6d967fa18f6e8b25    2022-08
#
#             commit_author_name             commit_author_email  \
# 0             Paul O’Shannessy             paul@oshannessy.com
# 1             Paul O’Shannessy             paul@oshannessy.com
# 2             Paul O’Shannessy             paul@oshannessy.com
# 3             Paul O’Shannessy             paul@oshannessy.com
# 4             Paul O’Shannessy             paul@oshannessy.com
# ...                        ...                             ...
# 63716             Andrew Clark              git@andrewclark.io
# 63717             Andrew Clark              git@andrewclark.io
# 63718             Andrew Clark              git@andrewclark.io
# 63719  Krishnamohan Yerrabilli  krishnamohan72452964@gmail.com
# 63720  Krishnamohan Yerrabilli  krishnamohan72452964@gmail.com
#
#                  commit_datetime  commit_merge  dmm_unit_size  \
# 0      2013-05-29 12:54:02-07:00         False       0.606371
# 1      2013-05-29 12:54:02-07:00         False       0.606371
# 2      2013-05-29 12:54:02-07:00         False       0.606371
# 3      2013-05-29 12:54:02-07:00         False       0.606371
# 4      2013-05-29 12:54:02-07:00         False       0.606371
# ...                          ...           ...            ...
# 63716  2022-08-04 21:20:15-04:00         False       0.626761
# 63717  2022-08-04 21:20:15-04:00         False       0.626761
# 63718  2022-08-04 21:20:15-04:00         False       0.626761
# 63719  2022-08-08 07:31:34-04:00         False            NaN
# 63720  2022-08-08 07:31:34-04:00         False            NaN
#
#        dmm_unit_complexity  dmm_unit_interfacing             file_name  \
# 0                  0.73698              0.828562         .editorconfig
# 1                  0.73698              0.828562            .gitignore
# 2                  0.73698              0.828562             .jshintrc
# 3                  0.73698              0.828562       CONTRIBUTING.md
# 4                  0.73698              0.828562          Gruntfile.js
# ...                    ...                   ...                   ...
# 63716              1.00000              1.000000          Scheduler.js
# 63717              1.00000              1.000000      SchedulerMock.js
# 63718              1.00000              1.000000  SchedulerPostTask.js
# 63719                  NaN                   NaN    CODE_OF_CONDUCT.md
# 63720                  NaN                   NaN             README.md
#
#               file_change_type  file_lines_added  file_lines_deleted  \
# 0         ModificationType.ADD                12                   0
# 1         ModificationType.ADD                21                   0
# 2         ModificationType.ADD                20                   0
# 3         ModificationType.ADD                63                   0
# 4         ModificationType.ADD                99                   0
# ...                        ...               ...                 ...
# 63716  ModificationType.MODIFY                 7                   3
# 63717  ModificationType.MODIFY                 6                   0
# 63718  ModificationType.MODIFY                 5                   0
# 63719  ModificationType.MODIFY                 1                   1
# 63720  ModificationType.MODIFY                 1                   1
#
#        file_loc  file_complexity  file_token_count
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4          71.0              2.0             463.0
# ...         ...              ...               ...
# 63716     476.0            101.0            2018.0
# 63717     573.0              3.0            1972.0
# 63718     197.0              5.0             543.0
# 63719       NaN              NaN               NaN
# 63720       NaN              NaN               NaN
#
# [63721 rows x 16 columns]

# %%
df.drop ( df[df.year_month == '2022-08'].index, inplace = True )
df
# Out:
#                                     commit_hash year_month commit_author_name  \
# 0      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 1      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 2      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 3      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 4      75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# ...                                         ...        ...                ...
# 63691  80f3d88190c07c2da11b5cac58a44c3b90fbc296    2022-07       Andrew Clark
# 63692  80f3d88190c07c2da11b5cac58a44c3b90fbc296    2022-07       Andrew Clark
# 63693  80f3d88190c07c2da11b5cac58a44c3b90fbc296    2022-07       Andrew Clark
# 63694  80f3d88190c07c2da11b5cac58a44c3b90fbc296    2022-07       Andrew Clark
# 63695  3f3b46c845333be5d8efcd9acb06e3ff57358189    2022-07      Konpaku Youmu
#
#        commit_author_email            commit_datetime  commit_merge  \
# 0      paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 1      paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 2      paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 3      paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 4      paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# ...                    ...                        ...           ...
# 63691   git@andrewclark.io  2022-07-29 19:34:28-04:00         False
# 63692   git@andrewclark.io  2022-07-29 19:34:28-04:00         False
# 63693   git@andrewclark.io  2022-07-29 19:34:28-04:00         False
# 63694   git@andrewclark.io  2022-07-29 19:34:28-04:00         False
# 63695   saber2pr@gmail.com  2022-07-30 10:57:13+02:00         False
#
#        dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0           0.606371              0.73698              0.828562
# 1           0.606371              0.73698              0.828562
# 2           0.606371              0.73698              0.828562
# 3           0.606371              0.73698              0.828562
# 4           0.606371              0.73698              0.828562
# ...              ...                  ...                   ...
# 63691       0.696721              1.00000              1.000000
# 63692       0.696721              1.00000              1.000000
# 63693       0.696721              1.00000              1.000000
# 63694       0.696721              1.00000              1.000000
# 63695            NaN                  NaN                   NaN
#
#                            file_name         file_change_type  \
# 0                      .editorconfig     ModificationType.ADD
# 1                         .gitignore     ModificationType.ADD
# 2                          .jshintrc     ModificationType.ADD
# 3                    CONTRIBUTING.md     ModificationType.ADD
# 4                       Gruntfile.js     ModificationType.ADD
# ...                              ...                      ...
# 63691    ReactFiberCommitWork.old.js  ModificationType.MODIFY
# 63692  ReactFiberCompleteWork.new.js  ModificationType.MODIFY
# 63693  ReactFiberCompleteWork.old.js  ModificationType.MODIFY
# 63694         ReactOffscreen-test.js  ModificationType.MODIFY
# 63695                      README.md  ModificationType.MODIFY
#
#        file_lines_added  file_lines_deleted  file_loc  file_complexity  \
# 0                    12                   0       NaN              NaN
# 1                    21                   0       NaN              NaN
# 2                    20                   0       NaN              NaN
# 3                    63                   0       NaN              NaN
# 4                    99                   0      71.0              2.0
# ...                 ...                 ...       ...              ...
# 63691               161                  79    3404.0             33.0
# 63692                16                   9    1210.0             97.0
# 63693                16                   9    1210.0             97.0
# 63694               262                   1     990.0            170.0
# 63695                 1                   1       NaN              NaN
#
#        file_token_count
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                 463.0
# ...                 ...
# 63691           12311.0
# 63692            5329.0
# 63693            5329.0
# 63694            4725.0
# 63695               NaN
#
# [63696 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#     year_month  commit_count  additions  deletions   agg_loc  agg_complexity  \
# 0      2013-05            53      43952        523   25918.0         10225.0
# 1      2013-06           213      11390      28035   61790.0         11686.0
# 2      2013-07           205      58995      55867   45952.0         13751.0
# 3      2013-08            53       2784       2284    9986.0          1908.0
# 4      2013-09            75       5394       1966   16589.0          2762.0
# ..         ...           ...        ...        ...       ...             ...
# 106    2022-03            78      11142      15013  299747.0         19363.0
# 107    2022-04            82      14481       6267  374268.0         13718.0
# 108    2022-05            51       6067       2013  130354.0          7434.0
# 109    2022-06            66       9384       3963  344830.0         15783.0
# 110    2022-07            42       7953       6772  255431.0          7296.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0           251334.0       0.582596             0.742723              0.821696
# 1           358919.0       0.515204             0.578879              0.582611
# 2           349160.0       0.502664             0.555284              0.588020
# 3            57123.0       0.606317             0.576510              0.640145
# 4            93146.0       0.545374             0.734521              0.787510
# ..               ...            ...                  ...                   ...
# 106        1255587.0       0.528100             0.765604              0.852136
# 107        1439473.0       0.532105             0.631447              0.598118
# 108         526962.0       0.493065             0.887337              0.936656
# 109        1343876.0       0.522034             0.636599              0.676099
# 110         980495.0       0.509717             0.723127              0.640245
#
# [111 rows x 10 columns]

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
