# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_groupedby_yearmonth.csv'
df = pd.read_csv (dataset_path)
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2019-03           531      12006       2191    435.0            28.0
# 1     2019-04          1000      12846      22386    617.0            76.0
# 2     2019-05            67        465        417      0.0             0.0
# 3     2019-06            10         24          6      0.0             0.0
# 4     2019-07            24         33         19      0.0             0.0
# 5     2019-08            25         96         19      0.0             0.0
# 6     2019-09             6          7          0      0.0             0.0
# 7     2019-10             1          5          5      0.0             0.0
# 8     2019-11             5          3          1      0.0             0.0
# 9     2019-12             2          1          0      0.0             0.0
# 10    2020-01             1          8          8      0.0             0.0
# 11    2020-02             3          3          1      0.0             0.0
# 12    2020-03             3          2          1      0.0             0.0
# 13    2020-04             5          6          1      0.0             0.0
# 14    2020-05             1          2          0      0.0             0.0
# 15    2020-07             4         91         15      0.0             0.0
# 16    2020-08             1          1          1      0.0             0.0
# 17    2020-09            10         52        105      0.0             0.0
# 18    2020-11             1          1          0      0.0             0.0
# 19    2020-12             3          3          1      0.0             0.0
# 20    2021-01            15         14          7      0.0             0.0
# 21    2021-03             1          1          0      0.0             0.0
# 22    2021-04             1          1          0      0.0             0.0
# 23    2021-05             1          1          0      0.0             0.0
# 24    2021-08             8          8          2      0.0             0.0
# 25    2021-09             9          9          7      0.0             0.0
# 26    2021-10             2          7          7      0.0             0.0
# 27    2021-12             2        102          0      0.0             0.0
# 28    2022-01            26      19660         61    676.0            74.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0            2178.0       0.041040             0.558140              1.000000
# 1            3379.0       0.652796             0.325916              0.172932
# 2               0.0            NaN                  NaN                   NaN
# 3               0.0            NaN                  NaN                   NaN
# 4               0.0            NaN                  NaN                   NaN
# 5               0.0            NaN                  NaN                   NaN
# 6               0.0            NaN                  NaN                   NaN
# 7               0.0            NaN                  NaN                   NaN
# 8               0.0            NaN                  NaN                   NaN
# 9               0.0            NaN                  NaN                   NaN
# 10              0.0            NaN                  NaN                   NaN
# 11              0.0            NaN                  NaN                   NaN
# 12              0.0            NaN                  NaN                   NaN
# 13              0.0            NaN                  NaN                   NaN
# 14              0.0            NaN                  NaN                   NaN
# 15              0.0            NaN                  NaN                   NaN
# 16              0.0            NaN                  NaN                   NaN
# 17              0.0            NaN                  NaN                   NaN
# 18              0.0            NaN                  NaN                   NaN
# 19              0.0            NaN                  NaN                   NaN
# 20              0.0            NaN                  NaN                   NaN
# 21              0.0            NaN                  NaN                   NaN
# 22              0.0            NaN                  NaN                   NaN
# 23              0.0            NaN                  NaN                   NaN
# 24              0.0            NaN                  NaN                   NaN
# 25              0.0            NaN                  NaN                   NaN
# 26              0.0            NaN                  NaN                   NaN
# 27              0.0            NaN                  NaN                   NaN
# 28           3789.0       0.379576             0.815029              1.000000

# %%
df['dmm_unit_size'] = df['dmm_unit_size'].fillna(0)
df['dmm_unit_complexity'] = df['dmm_unit_complexity'].fillna(0)
df['dmm_unit_interfacing'] = df['dmm_unit_interfacing'].fillna(0)

# %%
start_date = df.year_month[0][5:7] + '-01-' + df.year_month[0][0:4]
end_date = df.year_month[len(df.year_month) - 1][5:7] + '-01-' + df.year_month[len(df.year_month) - 1][0:4]
dfperiod = pd.period_range(start_date, end_date, freq='M')

def new_zero_row ( year_month ):
    
    new_row = {
        'year_month': year_month,
        'commit_count': 0,
        'additions': 0,
        'deletions': 0,
        'agg_loc': 0,
        'agg_complexity': 0,
        'agg_token_count': 0,
        'dmm_unit_size': 0,
        'dmm_unit_complexity': 0,
        'dmm_unit_interfacing': 0
    }
    
    return new_row

for year_month in dfperiod:
    if df [ ( df['year_month'] == str(year_month) ) ].shape[0] == 0:
        df = df.append ( new_zero_row(year_month), ignore_index = True )

df.shape
# Out:
# (35, 10)

# %%
df['year_month'] = df['year_month'].astype(str)
df = df.sort_values ( by=['year_month'] )
df.reset_index(drop=True, inplace=True)
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2019-03           531      12006       2191    435.0            28.0
# 1     2019-04          1000      12846      22386    617.0            76.0
# 2     2019-05            67        465        417      0.0             0.0
# 3     2019-06            10         24          6      0.0             0.0
# 4     2019-07            24         33         19      0.0             0.0
# 5     2019-08            25         96         19      0.0             0.0
# 6     2019-09             6          7          0      0.0             0.0
# 7     2019-10             1          5          5      0.0             0.0
# 8     2019-11             5          3          1      0.0             0.0
# 9     2019-12             2          1          0      0.0             0.0
# 10    2020-01             1          8          8      0.0             0.0
# 11    2020-02             3          3          1      0.0             0.0
# 12    2020-03             3          2          1      0.0             0.0
# 13    2020-04             5          6          1      0.0             0.0
# 14    2020-05             1          2          0      0.0             0.0
# 15    2020-06             0          0          0      0.0             0.0
# 16    2020-07             4         91         15      0.0             0.0
# 17    2020-08             1          1          1      0.0             0.0
# 18    2020-09            10         52        105      0.0             0.0
# 19    2020-10             0          0          0      0.0             0.0
# 20    2020-11             1          1          0      0.0             0.0
# 21    2020-12             3          3          1      0.0             0.0
# 22    2021-01            15         14          7      0.0             0.0
# 23    2021-02             0          0          0      0.0             0.0
# 24    2021-03             1          1          0      0.0             0.0
# 25    2021-04             1          1          0      0.0             0.0
# 26    2021-05             1          1          0      0.0             0.0
# 27    2021-06             0          0          0      0.0             0.0
# 28    2021-07             0          0          0      0.0             0.0
# 29    2021-08             8          8          2      0.0             0.0
# 30    2021-09             9          9          7      0.0             0.0
# 31    2021-10             2          7          7      0.0             0.0
# 32    2021-11             0          0          0      0.0             0.0
# 33    2021-12             2        102          0      0.0             0.0
# 34    2022-01            26      19660         61    676.0            74.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0            2178.0       0.041040             0.558140              1.000000
# 1            3379.0       0.652796             0.325916              0.172932
# 2               0.0       0.000000             0.000000              0.000000
# 3               0.0       0.000000             0.000000              0.000000
# 4               0.0       0.000000             0.000000              0.000000
# 5               0.0       0.000000             0.000000              0.000000
# 6               0.0       0.000000             0.000000              0.000000
# 7               0.0       0.000000             0.000000              0.000000
# 8               0.0       0.000000             0.000000              0.000000
# 9               0.0       0.000000             0.000000              0.000000
# 10              0.0       0.000000             0.000000              0.000000
# 11              0.0       0.000000             0.000000              0.000000
# 12              0.0       0.000000             0.000000              0.000000
# 13              0.0       0.000000             0.000000              0.000000
# 14              0.0       0.000000             0.000000              0.000000
# 15              0.0       0.000000             0.000000              0.000000
# 16              0.0       0.000000             0.000000              0.000000
# 17              0.0       0.000000             0.000000              0.000000
# 18              0.0       0.000000             0.000000              0.000000
# 19              0.0       0.000000             0.000000              0.000000
# 20              0.0       0.000000             0.000000              0.000000
# 21              0.0       0.000000             0.000000              0.000000
# 22              0.0       0.000000             0.000000              0.000000
# 23              0.0       0.000000             0.000000              0.000000
# 24              0.0       0.000000             0.000000              0.000000
# 25              0.0       0.000000             0.000000              0.000000
# 26              0.0       0.000000             0.000000              0.000000
# 27              0.0       0.000000             0.000000              0.000000
# 28              0.0       0.000000             0.000000              0.000000
# 29              0.0       0.000000             0.000000              0.000000
# 30              0.0       0.000000             0.000000              0.000000
# 31              0.0       0.000000             0.000000              0.000000
# 32              0.0       0.000000             0.000000              0.000000
# 33              0.0       0.000000             0.000000              0.000000
# 34           3789.0       0.379576             0.815029              1.000000

# %%
df.to_csv ( f'datasets/{repo_name}_final.csv', index = False )

# %% [markdown]
# # Analysis

# %%
for idx in range(1, 10):
    ma_prefix = 'ma_'
    df[ma_prefix + df.columns[idx]] = df[df.columns[idx]].rolling ( window = 5 ).mean()
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2019-03           531      12006       2191    435.0            28.0
# 1     2019-04          1000      12846      22386    617.0            76.0
# 2     2019-05            67        465        417      0.0             0.0
# 3     2019-06            10         24          6      0.0             0.0
# 4     2019-07            24         33         19      0.0             0.0
# 5     2019-08            25         96         19      0.0             0.0
# 6     2019-09             6          7          0      0.0             0.0
# 7     2019-10             1          5          5      0.0             0.0
# 8     2019-11             5          3          1      0.0             0.0
# 9     2019-12             2          1          0      0.0             0.0
# 10    2020-01             1          8          8      0.0             0.0
# 11    2020-02             3          3          1      0.0             0.0
# 12    2020-03             3          2          1      0.0             0.0
# 13    2020-04             5          6          1      0.0             0.0
# 14    2020-05             1          2          0      0.0             0.0
# 15    2020-06             0          0          0      0.0             0.0
# 16    2020-07             4         91         15      0.0             0.0
# 17    2020-08             1          1          1      0.0             0.0
# 18    2020-09            10         52        105      0.0             0.0
# 19    2020-10             0          0          0      0.0             0.0
# 20    2020-11             1          1          0      0.0             0.0
# 21    2020-12             3          3          1      0.0             0.0
# 22    2021-01            15         14          7      0.0             0.0
# 23    2021-02             0          0          0      0.0             0.0
# 24    2021-03             1          1          0      0.0             0.0
# 25    2021-04             1          1          0      0.0             0.0
# 26    2021-05             1          1          0      0.0             0.0
# 27    2021-06             0          0          0      0.0             0.0
# 28    2021-07             0          0          0      0.0             0.0
# 29    2021-08             8          8          2      0.0             0.0
# 30    2021-09             9          9          7      0.0             0.0
# 31    2021-10             2          7          7      0.0             0.0
# 32    2021-11             0          0          0      0.0             0.0
# 33    2021-12             2        102          0      0.0             0.0
# 34    2022-01            26      19660         61    676.0            74.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0            2178.0       0.041040             0.558140              1.000000
# 1            3379.0       0.652796             0.325916              0.172932
# 2               0.0       0.000000             0.000000              0.000000
# 3               0.0       0.000000             0.000000              0.000000
# 4               0.0       0.000000             0.000000              0.000000
# 5               0.0       0.000000             0.000000              0.000000
# 6               0.0       0.000000             0.000000              0.000000
# 7               0.0       0.000000             0.000000              0.000000
# 8               0.0       0.000000             0.000000              0.000000
# 9               0.0       0.000000             0.000000              0.000000
# 10              0.0       0.000000             0.000000              0.000000
# 11              0.0       0.000000             0.000000              0.000000
# 12              0.0       0.000000             0.000000              0.000000
# 13              0.0       0.000000             0.000000              0.000000
# 14              0.0       0.000000             0.000000              0.000000
# 15              0.0       0.000000             0.000000              0.000000
# 16              0.0       0.000000             0.000000              0.000000
# 17              0.0       0.000000             0.000000              0.000000
# 18              0.0       0.000000             0.000000              0.000000
# 19              0.0       0.000000             0.000000              0.000000
# 20              0.0       0.000000             0.000000              0.000000
# 21              0.0       0.000000             0.000000              0.000000
# 22              0.0       0.000000             0.000000              0.000000
# 23              0.0       0.000000             0.000000              0.000000
# 24              0.0       0.000000             0.000000              0.000000
# 25              0.0       0.000000             0.000000              0.000000
# 26              0.0       0.000000             0.000000              0.000000
# 27              0.0       0.000000             0.000000              0.000000
# 28              0.0       0.000000             0.000000              0.000000
# 29              0.0       0.000000             0.000000              0.000000
# 30              0.0       0.000000             0.000000              0.000000
# 31              0.0       0.000000             0.000000              0.000000
# 32              0.0       0.000000             0.000000              0.000000
# 33              0.0       0.000000             0.000000              0.000000
# 34           3789.0       0.379576             0.815029              1.000000
#
#     ma_commit_count  ma_additions  ma_deletions  ma_agg_loc  \
# 0               NaN           NaN           NaN         NaN
# 1               NaN           NaN           NaN         NaN
# 2               NaN           NaN           NaN         NaN
# 3               NaN           NaN           NaN         NaN
# 4             326.4        5074.8        5003.8       210.4
# 5             225.2        2692.8        4569.4       123.4
# 6              26.4         125.0          92.2         0.0
# 7              13.2          33.0           9.8         0.0
# 8              12.2          28.8           8.8         0.0
# 9               7.8          22.4           5.0         0.0
# 10              3.0           4.8           2.8         0.0
# 11              2.4           4.0           3.0         0.0
# 12              2.8           3.4           2.2         0.0
# 13              2.8           4.0           2.2         0.0
# 14              2.6           4.2           2.2         0.0
# 15              2.4           2.6           0.6         0.0
# 16              2.6          20.2           3.4         0.0
# 17              2.2          20.0           3.4         0.0
# 18              3.2          29.2          24.2         0.0
# 19              3.0          28.8          24.2         0.0
# 20              3.2          29.0          24.2         0.0
# 21              3.0          11.4          21.4         0.0
# 22              5.8          14.0          22.6         0.0
# 23              3.8           3.6           1.6         0.0
# 24              4.0           3.8           1.6         0.0
# 25              4.0           3.8           1.6         0.0
# 26              3.6           3.4           1.4         0.0
# 27              0.6           0.6           0.0         0.0
# 28              0.6           0.6           0.0         0.0
# 29              2.0           2.0           0.4         0.0
# 30              3.6           3.6           1.8         0.0
# 31              3.8           4.8           3.2         0.0
# 32              3.8           4.8           3.2         0.0
# 33              4.2          25.2           3.2         0.0
# 34              7.8        3955.6          15.0       135.2
#
#     ma_agg_complexity  ma_agg_token_count  ma_dmm_unit_size  \
# 0                 NaN                 NaN               NaN
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4                20.8              1111.4          0.138767
# 5                15.2               675.8          0.130559
# 6                 0.0                 0.0          0.000000
# 7                 0.0                 0.0          0.000000
# 8                 0.0                 0.0          0.000000
# 9                 0.0                 0.0          0.000000
# 10                0.0                 0.0          0.000000
# 11                0.0                 0.0          0.000000
# 12                0.0                 0.0          0.000000
# 13                0.0                 0.0          0.000000
# 14                0.0                 0.0          0.000000
# 15                0.0                 0.0          0.000000
# 16                0.0                 0.0          0.000000
# 17                0.0                 0.0          0.000000
# 18                0.0                 0.0          0.000000
# 19                0.0                 0.0          0.000000
# 20                0.0                 0.0          0.000000
# 21                0.0                 0.0          0.000000
# 22                0.0                 0.0          0.000000
# 23                0.0                 0.0          0.000000
# 24                0.0                 0.0          0.000000
# 25                0.0                 0.0          0.000000
# 26                0.0                 0.0          0.000000
# 27                0.0                 0.0          0.000000
# 28                0.0                 0.0          0.000000
# 29                0.0                 0.0          0.000000
# 30                0.0                 0.0          0.000000
# 31                0.0                 0.0          0.000000
# 32                0.0                 0.0          0.000000
# 33                0.0                 0.0          0.000000
# 34               14.8               757.8          0.075915
#
#     ma_dmm_unit_complexity  ma_dmm_unit_interfacing
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                 0.176811                 0.234586
# 5                 0.065183                 0.034586
# 6                 0.000000                 0.000000
# 7                 0.000000                 0.000000
# 8                 0.000000                 0.000000
# 9                 0.000000                 0.000000
# 10                0.000000                 0.000000
# 11                0.000000                 0.000000
# 12                0.000000                 0.000000
# 13                0.000000                 0.000000
# 14                0.000000                 0.000000
# 15                0.000000                 0.000000
# 16                0.000000                 0.000000
# 17                0.000000                 0.000000
# 18                0.000000                 0.000000
# 19                0.000000                 0.000000
# 20                0.000000                 0.000000
# 21                0.000000                 0.000000
# 22                0.000000                 0.000000
# 23                0.000000                 0.000000
# 24                0.000000                 0.000000
# 25                0.000000                 0.000000
# 26                0.000000                 0.000000
# 27                0.000000                 0.000000
# 28                0.000000                 0.000000
# 29                0.000000                 0.000000
# 30                0.000000                 0.000000
# 31                0.000000                 0.000000
# 32                0.000000                 0.000000
# 33                0.000000                 0.000000
# 34                0.163006                 0.200000

# %%
from plot_line_lib import plot_line

for idx in range ( 1, 7 ):
    
    images_path = f'images/'
    plot_line ( df.columns[idx], idx, df, images_path, repo_name, major_locator = False )

# %%
from analysis_lib import year_pre_covid_ym, pre_covid_ym, covid_ym, year_post_covid_ym

df = df.set_index(df['year_month'])

df1 = df [ year_pre_covid_ym : pre_covid_ym ]
df2 = df [ covid_ym : year_post_covid_ym ]
df1 = df1.reset_index ( drop = True )
df2 = df2.reset_index ( drop = True )

df1.shape, df2.shape
# Out:
# ((12, 19), (12, 19))

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( df1, df2 )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  140  vs  4  ->  Down (97.1%)
# additions :  2125  vs  14  ->  Down (99.3%)
# deletions :  2088  vs  11  ->  Down (99.5%)
# agg loc :  88  vs  0  ->  Down (100.0%)
# agg complexity :  9  vs  0  ->  Down (100.0%)
# agg token count :  463  vs  0  ->  Down (100.0%)

# %% [markdown]
# # Distribution

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_equilibrium_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_equilibrium_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 8.3
# additions = 8.3
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
#
# Post-pandemic equilibrium percentages:
# commit_count = 16.7
# additions = 8.3
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_pareto_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_pareto_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 16.7
# additions = 16.7
# deletions = 8.3
# agg_loc = 16.7
# agg_complexity = 16.7
# agg_token_count = 16.7
#
# Post-pandemic pareto percentages:
# commit_count = 41.7
# additions = 16.7
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
