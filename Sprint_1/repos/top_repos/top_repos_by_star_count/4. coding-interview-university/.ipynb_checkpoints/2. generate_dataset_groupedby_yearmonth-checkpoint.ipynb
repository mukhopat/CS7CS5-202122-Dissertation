# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  d239d7b97c726981c6e2a959a921d51184846a5b        John Washam
# 1  34219525fbcb64f960e0bc9a0e6a10f6e125513c        John Washam
# 2  34219525fbcb64f960e0bc9a0e6a10f6e125513c        John Washam
# 3  c950b208933c4f6ff7a681d9870405e633dfe84a        John Washam
# 4  c950b208933c4f6ff7a681d9870405e633dfe84a        John Washam
#
#     commit_author_email            commit_datetime  commit_merge  \
# 0  john@readyprompt.com  2016-06-05 19:34:12-07:00         False
# 1  john@readyprompt.com  2016-06-05 19:41:26-07:00         False
# 2  john@readyprompt.com  2016-06-05 19:41:26-07:00         False
# 3  john@readyprompt.com  2016-06-05 19:46:49-07:00         False
# 4  john@readyprompt.com  2016-06-05 19:46:49-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing   file_name  \
# 0            NaN                  NaN                   NaN   README.md
# 1            NaN                  NaN                   NaN  .gitignore
# 2            NaN                  NaN                   NaN   README.md
# 3            NaN                  NaN                   NaN   README.md
# 4            NaN                  NaN                   NaN    plan.txt
#
#           file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0     ModificationType.ADD                 2                   0       NaN
# 1     ModificationType.ADD                 2                   0       NaN
# 2  ModificationType.MODIFY                 2                   1       NaN
# 3  ModificationType.MODIFY                 1                   1       NaN
# 4     ModificationType.ADD               382                   0       NaN
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                    commit_hash year_month commit_author_name  \
# 0     d239d7b97c726981c6e2a959a921d51184846a5b    2016-06        John Washam
# 1     34219525fbcb64f960e0bc9a0e6a10f6e125513c    2016-06        John Washam
# 2     34219525fbcb64f960e0bc9a0e6a10f6e125513c    2016-06        John Washam
# 3     c950b208933c4f6ff7a681d9870405e633dfe84a    2016-06        John Washam
# 4     c950b208933c4f6ff7a681d9870405e633dfe84a    2016-06        John Washam
# ...                                        ...        ...                ...
# 2098  694157e8afaee5167959fe0976114258b9832823    2022-07       Anri Lombard
# 2099  d97574ecd42b30df2efa7b0a3edef9a5bd2e8a76    2022-07     Sandeep Mishra
# 2100  0187f27018eaef1d51b6523c0ff3669cc874abc3    2022-07        John Washam
# 2101  c7f69947f4033c8be258bb6c6f7372b57a286ce5    2022-08        John Washam
# 2102  6001497deffd2acdd47e0c48160907edeea47956    2022-08          anmolp476
#
#                                     commit_author_email  \
# 0                                  john@readyprompt.com
# 1                                  john@readyprompt.com
# 2                                  john@readyprompt.com
# 3                                  john@readyprompt.com
# 4                                  john@readyprompt.com
# ...                                                 ...
# 2098                           anri.m.lombard@gmail.com
# 2099  87706790+sandeepmishratech@users.noreply.githu...
# 2100                                   washam@gmail.com
# 2101                               john@readyprompt.com
# 2102        99687931+anmolp476@users.noreply.github.com
#
#                 commit_datetime  commit_merge  dmm_unit_size  \
# 0     2016-06-05 19:34:12-07:00         False            NaN
# 1     2016-06-05 19:41:26-07:00         False            NaN
# 2     2016-06-05 19:41:26-07:00         False            NaN
# 3     2016-06-05 19:46:49-07:00         False            NaN
# 4     2016-06-05 19:46:49-07:00         False            NaN
# ...                         ...           ...            ...
# 2098  2022-07-21 11:45:53+02:00         False            NaN
# 2099  2022-07-22 09:30:33+05:18         False            NaN
# 2100  2022-07-25 09:29:59-07:00         False            NaN
# 2101  2022-07-31 19:02:57-07:00         False            NaN
# 2102  2022-08-02 13:39:35-04:00         False            NaN
#
#       dmm_unit_complexity  dmm_unit_interfacing  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 2098                  NaN                   NaN
# 2099                  NaN                   NaN
# 2100                  NaN                   NaN
# 2101                  NaN                   NaN
# 2102                  NaN                   NaN
#
#                               file_name         file_change_type  \
# 0                             README.md     ModificationType.ADD
# 1                            .gitignore     ModificationType.ADD
# 2                             README.md  ModificationType.MODIFY
# 3                             README.md  ModificationType.MODIFY
# 4                              plan.txt     ModificationType.ADD
# ...                                 ...                      ...
# 2098                       README-af.md  ModificationType.MODIFY
# 2099  programming-language-resources.md  ModificationType.MODIFY
# 2100                          README.md  ModificationType.MODIFY
# 2101                  links_checker.yml  ModificationType.MODIFY
# 2102                          README.md  ModificationType.MODIFY
#
#       file_lines_added  file_lines_deleted  file_loc  file_complexity  \
# 0                    2                   0       NaN              NaN
# 1                    2                   0       NaN              NaN
# 2                    2                   1       NaN              NaN
# 3                    1                   1       NaN              NaN
# 4                  382                   0       NaN              NaN
# ...                ...                 ...       ...              ...
# 2098               128                   2       NaN              NaN
# 2099                 1                   0       NaN              NaN
# 2100                 0                  28       NaN              NaN
# 2101                 2                   2       NaN              NaN
# 2102                 2                   0       NaN              NaN
#
#       file_token_count
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 2098               NaN
# 2099               NaN
# 2100               NaN
# 2101               NaN
# 2102               NaN
#
# [2103 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2016-06            65       4005       2390      0.0             0.0
# 1     2016-07            79       2147        622     53.0             0.0
# 2     2016-08            57        578        414      0.0             0.0
# 3     2016-09            84        871        624      0.0             0.0
# 4     2016-10           155       7618       5413      0.0             0.0
# ..        ...           ...        ...        ...      ...             ...
# 66    2022-04             5         31        693      0.0             0.0
# 67    2022-05            10         35         42      0.0             0.0
# 68    2022-06             4          8          3      0.0             0.0
# 69    2022-07           170       2555        579      0.0             0.0
# 70    2022-08             2          4          2      0.0             0.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0               0.0            NaN                  NaN                   NaN
# 1              84.0            NaN                  NaN                   NaN
# 2               0.0            NaN                  NaN                   NaN
# 3               0.0            NaN                  NaN                   NaN
# 4               0.0            NaN                  NaN                   NaN
# ..              ...            ...                  ...                   ...
# 66              0.0            NaN                  NaN                   NaN
# 67              0.0            NaN                  NaN                   NaN
# 68              0.0            NaN                  NaN                   NaN
# 69              0.0            NaN                  NaN                   NaN
# 70              0.0            NaN                  NaN                   NaN
#
# [71 rows x 10 columns]

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
