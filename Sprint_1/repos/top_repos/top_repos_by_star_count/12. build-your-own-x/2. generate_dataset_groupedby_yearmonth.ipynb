# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  4b6d12ecbc71d4d346ec9a325e54150c16b0c933  Daniel Stefanovic
# 1  4b6d12ecbc71d4d346ec9a325e54150c16b0c933  Daniel Stefanovic
# 2  4b6d12ecbc71d4d346ec9a325e54150c16b0c933  Daniel Stefanovic
# 3  f81138e3b7dffe6201cdb4f0b76c2960efb3b511  Daniel Stefanovic
# 4  3530d916df2c6ec8dd162a03bc1bab64ef587774  Daniel Stefanovic
#
#            commit_author_email            commit_datetime  commit_merge  \
# 0  daniel.stefanovic@gmail.com  2018-05-09 14:03:45+02:00         False
# 1  daniel.stefanovic@gmail.com  2018-05-09 14:03:45+02:00         False
# 2  daniel.stefanovic@gmail.com  2018-05-09 14:03:45+02:00         False
# 3  daniel.stefanovic@gmail.com  2018-05-09 14:07:35+02:00         False
# 4  daniel.stefanovic@gmail.com  2018-05-09 14:19:44+02:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing       file_name  \
# 0            NaN                  NaN                   NaN  ISSUE_TEMPLATE
# 1            NaN                  NaN                   NaN       README.md
# 2            NaN                  NaN                   NaN     feynman.png
# 3            NaN                  NaN                   NaN       README.md
# 4            NaN                  NaN                   NaN       README.md
#
#           file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0     ModificationType.ADD                 8                   0       NaN
# 1     ModificationType.ADD               167                   0       NaN
# 2     ModificationType.ADD                 0                   0       NaN
# 3  ModificationType.MODIFY                 3                   0       NaN
# 4  ModificationType.MODIFY                 2                   2       NaN
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                   commit_hash year_month   commit_author_name  \
# 0    4b6d12ecbc71d4d346ec9a325e54150c16b0c933    2018-05    Daniel Stefanovic
# 1    4b6d12ecbc71d4d346ec9a325e54150c16b0c933    2018-05    Daniel Stefanovic
# 2    4b6d12ecbc71d4d346ec9a325e54150c16b0c933    2018-05    Daniel Stefanovic
# 3    f81138e3b7dffe6201cdb4f0b76c2960efb3b511    2018-05    Daniel Stefanovic
# 4    3530d916df2c6ec8dd162a03bc1bab64ef587774    2018-05    Daniel Stefanovic
# ..                                        ...        ...                  ...
# 342  bec43eace2798c8e8013c0f60e4f84fd8cb4f287    2022-06              Paulden
# 343  b32f410e1cdbd4b0cbff45d0f6b5fcd8bdbb015b    2022-07       Sarup Banskota
# 344  35a45d6e9a8b25e732832ed23882f39dfba0d5ff    2022-07    Jeffrey Milberger
# 345  3090fb2ce21a53c3ea952f7731ecfe168ed63c6d    2022-07            ajohn5960
# 346  8b1492ee134edd0a86d914656cd2a0006eb4e4b7    2022-07  Akashsingh Sisodiya
#
#                              commit_author_email            commit_datetime  \
# 0                    daniel.stefanovic@gmail.com  2018-05-09 14:03:45+02:00
# 1                    daniel.stefanovic@gmail.com  2018-05-09 14:03:45+02:00
# 2                    daniel.stefanovic@gmail.com  2018-05-09 14:03:45+02:00
# 3                    daniel.stefanovic@gmail.com  2018-05-09 14:07:35+02:00
# 4                    daniel.stefanovic@gmail.com  2018-05-09 14:19:44+02:00
# ..                                           ...                        ...
# 342     67539676+guuzaa@users.noreply.github.com  2022-06-18 09:56:13+08:00
# 343                        sbanskota08@gmail.com  2022-07-02 01:09:17+08:00
# 344                  jeffrey.milberger@gmail.com  2022-07-07 17:55:19-05:00
# 345  61067907+ajohn5960@users.noreply.github.com  2022-07-10 16:26:58-04:00
# 346                 akashsinghsisodiya@gmail.com  2022-07-16 17:00:45+05:18
#
#      commit_merge  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0           False            NaN                  NaN                   NaN
# 1           False            NaN                  NaN                   NaN
# 2           False            NaN                  NaN                   NaN
# 3           False            NaN                  NaN                   NaN
# 4           False            NaN                  NaN                   NaN
# ..            ...            ...                  ...                   ...
# 342         False            NaN                  NaN                   NaN
# 343         False            NaN                  NaN                   NaN
# 344         False            NaN                  NaN                   NaN
# 345         False            NaN                  NaN                   NaN
# 346         False            NaN                  NaN                   NaN
#
#           file_name         file_change_type  file_lines_added  \
# 0    ISSUE_TEMPLATE     ModificationType.ADD                 8
# 1         README.md     ModificationType.ADD               167
# 2       feynman.png     ModificationType.ADD                 0
# 3         README.md  ModificationType.MODIFY                 3
# 4         README.md  ModificationType.MODIFY                 2
# ..              ...                      ...               ...
# 342       README.md  ModificationType.MODIFY                 1
# 343       README.md  ModificationType.MODIFY                 1
# 344       README.md  ModificationType.MODIFY                 0
# 345       README.md  ModificationType.MODIFY                 0
# 346       README.md  ModificationType.MODIFY                 1
#
#      file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                     0       NaN              NaN               NaN
# 1                     0       NaN              NaN               NaN
# 2                     0       NaN              NaN               NaN
# 3                     0       NaN              NaN               NaN
# 4                     2       NaN              NaN               NaN
# ..                  ...       ...              ...               ...
# 342                   0       NaN              NaN               NaN
# 343                   1       NaN              NaN               NaN
# 344                   1       NaN              NaN               NaN
# 345                   1       NaN              NaN               NaN
# 346                   1       NaN              NaN               NaN
#
# [347 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2018-05           152        929        527      0.0             0.0
# 1     2018-06            38         41         19      0.0             0.0
# 2     2018-07            32         46         11      0.0             0.0
# 3     2018-08            15         19          8      0.0             0.0
# 4     2018-09             6         13          8      0.0             0.0
# 5     2018-10            12         12          5      0.0             0.0
# 6     2018-11             7          6          1      0.0             0.0
# 7     2018-12             7          9          6      0.0             0.0
# 8     2019-01             3          3          0      0.0             0.0
# 9     2019-02             3          4          3      0.0             0.0
# 10    2019-03            10          8          4      0.0             0.0
# 11    2019-04             2          2          1      0.0             0.0
# 12    2019-06             1          1          1      0.0             0.0
# 13    2019-07             2          2          1      0.0             0.0
# 14    2019-08             2          2         10      0.0             0.0
# 15    2019-09             2          1          1      0.0             0.0
# 16    2019-10             2          2          2      0.0             0.0
# 17    2019-11             4          4          0      0.0             0.0
# 18    2020-02             2          2          2      0.0             0.0
# 19    2020-04             6          5          4      0.0             0.0
# 20    2020-05             1          0          1      0.0             0.0
# 21    2020-06             4          5          4      0.0             0.0
# 22    2020-07             2          2          1      0.0             0.0
# 23    2020-09             1          0          1      0.0             0.0
# 24    2020-12             1          1          1      0.0             0.0
# 25    2021-01             2          0          2      0.0             0.0
# 26    2021-03             5          4         10      0.0             0.0
# 27    2021-06             1          1          1      0.0             0.0
# 28    2021-11             1          0          1      0.0             0.0
# 29    2022-02             1          1          1      0.0             0.0
# 30    2022-05            10         24         22      0.0             0.0
# 31    2022-06             2          2          5      0.0             0.0
# 32    2022-07             4          2          4      0.0             0.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0               0.0            NaN                  NaN                   NaN
# 1               0.0            NaN                  NaN                   NaN
# 2               0.0            NaN                  NaN                   NaN
# 3               0.0            NaN                  NaN                   NaN
# 4               0.0            NaN                  NaN                   NaN
# 5               0.0            NaN                  NaN                   NaN
# 6               0.0            NaN                  NaN                   NaN
# 7               0.0            NaN                  NaN                   NaN
# 8               0.0            NaN                  NaN                   NaN
# 9               0.0            NaN                  NaN                   NaN
# 10              0.0            NaN                  NaN                   NaN
# 11              0.0            NaN                  NaN                   NaN
# 12              0.0            NaN                  NaN                   NaN
# 13              0.0            NaN                  NaN                   NaN
# 14              0.0            NaN                  NaN                   NaN
# 15              0.0            NaN                  NaN                   NaN
# 16              0.0            NaN                  NaN                   NaN
# 17              0.0            NaN                  NaN                   NaN
# 18              0.0            NaN                  NaN                   NaN
# 19              0.0            NaN                  NaN                   NaN
# 20              0.0            NaN                  NaN                   NaN
# 21              0.0            NaN                  NaN                   NaN
# 22              0.0            NaN                  NaN                   NaN
# 23              0.0            NaN                  NaN                   NaN
# 24              0.0            NaN                  NaN                   NaN
# 25              0.0            NaN                  NaN                   NaN
# 26              0.0            NaN                  NaN                   NaN
# 27              0.0            NaN                  NaN                   NaN
# 28              0.0            NaN                  NaN                   NaN
# 29              0.0            NaN                  NaN                   NaN
# 30              0.0            NaN                  NaN                   NaN
# 31              0.0            NaN                  NaN                   NaN
# 32              0.0            NaN                  NaN                   NaN

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
