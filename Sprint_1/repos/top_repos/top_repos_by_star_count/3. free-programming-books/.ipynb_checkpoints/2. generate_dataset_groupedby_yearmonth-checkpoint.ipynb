# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash   commit_author_name  \
# 0  9d12a9c3f4ec059a3685c232ad179016fd35f909  vhf / victor felder
# 1  9d12a9c3f4ec059a3685c232ad179016fd35f909  vhf / victor felder
# 2  ee7b4d46e525096b26c1cc8f96a615751dc3ec48  vhf / victor felder
# 3  023fa674cbe907b4de8210dbe8b563ffd3a151a4  vhf / victor felder
# 4  6100b03a385ac9700558f6100414fa5d2178d09e        Victor Felder
#
#       commit_author_email            commit_datetime  commit_merge  \
# 0  victorfelder@gmail.com  2013-10-10 23:50:37-07:00         False
# 1  victorfelder@gmail.com  2013-10-10 23:50:37-07:00         False
# 2  victorfelder@gmail.com  2013-10-11 08:53:59+02:00         False
# 3  victorfelder@gmail.com  2013-10-11 08:59:11+02:00         False
# 4  victorfelder@gmail.com  2013-10-11 09:04:49+02:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  file_name  \
# 0            NaN                  NaN                   NaN    LICENSE
# 1            NaN                  NaN                   NaN  README.md
# 2            NaN                  NaN                   NaN  README.md
# 3            NaN                  NaN                   NaN  README.md
# 4            NaN                  NaN                   NaN  README.md
#
#           file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0     ModificationType.ADD                24                   0       NaN
# 1     ModificationType.ADD                 2                   0       NaN
# 2  ModificationType.MODIFY               563                   0       NaN
# 3  ModificationType.MODIFY                 3                   2       NaN
# 4  ModificationType.MODIFY                 5                 560       NaN
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                    commit_hash year_month  \
# 0     9d12a9c3f4ec059a3685c232ad179016fd35f909    2013-10
# 1     9d12a9c3f4ec059a3685c232ad179016fd35f909    2013-10
# 2     ee7b4d46e525096b26c1cc8f96a615751dc3ec48    2013-10
# 3     023fa674cbe907b4de8210dbe8b563ffd3a151a4    2013-10
# 4     6100b03a385ac9700558f6100414fa5d2178d09e    2013-10
# ...                                        ...        ...
# 7194  c76522acfe632dbde7588a182aef01a03aa1aec9    2022-08
# 7195  ad4ef13bd7c2129f1579129a41ead1990c02973f    2022-08
# 7196  ad4ef13bd7c2129f1579129a41ead1990c02973f    2022-08
# 7197  70f2730805aa4797e89877ea9ead479b391c91df    2022-08
# 7198  04cf8c84ed096caa02aaf9fd1d37db097e8e237a    2022-08
#
#         commit_author_name                                commit_author_email  \
# 0      vhf / victor felder                             victorfelder@gmail.com
# 1      vhf / victor felder                             victorfelder@gmail.com
# 2      vhf / victor felder                             victorfelder@gmail.com
# 3      vhf / victor felder                             victorfelder@gmail.com
# 4            Victor Felder                             victorfelder@gmail.com
# ...                    ...                                                ...
# 7194           David Ordás           3125580+davorpa@users.noreply.github.com
# 7195           Toms Grants  75024514+klappscheinwerfer@users.noreply.githu...
# 7196           Toms Grants  75024514+klappscheinwerfer@users.noreply.githu...
# 7197  Vaishnavi Amira Yada  108050528+Vaishnaviamirayada@users.noreply.git...
# 7198          Reza Yazdani                            mrrezayazdani@yahoo.com
#
#                 commit_datetime  commit_merge  dmm_unit_size  \
# 0     2013-10-10 23:50:37-07:00         False            NaN
# 1     2013-10-10 23:50:37-07:00         False            NaN
# 2     2013-10-11 08:53:59+02:00         False            NaN
# 3     2013-10-11 08:59:11+02:00         False            NaN
# 4     2013-10-11 09:04:49+02:00         False            NaN
# ...                         ...           ...            ...
# 7194  2022-08-03 22:49:28+02:00         False            NaN
# 7195  2022-08-03 22:58:04+02:00         False            NaN
# 7196  2022-08-03 22:58:04+02:00         False            NaN
# 7197  2022-08-03 23:00:44+02:00         False            NaN
# 7198  2022-08-05 15:34:14+02:00         False            NaN
#
#       dmm_unit_complexity  dmm_unit_interfacing  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 7194                  NaN                   NaN
# 7195                  NaN                   NaN
# 7196                  NaN                   NaN
# 7197                  NaN                   NaN
# 7198                  NaN                   NaN
#
#                                          file_name         file_change_type  \
# 0                                          LICENSE     ModificationType.ADD
# 1                                        README.md     ModificationType.ADD
# 2                                        README.md  ModificationType.MODIFY
# 3                                        README.md  ModificationType.MODIFY
# 4                                        README.md  ModificationType.MODIFY
# ...                                            ...                      ...
# 7194                                     README.md  ModificationType.MODIFY
# 7195                                     README.md  ModificationType.MODIFY
# 7196                  free-programming-books-lv.md     ModificationType.ADD
# 7197  free-programming-interactive-tutorials-en.md  ModificationType.MODIFY
# 7198               free-programming-books-fa_IR.md  ModificationType.MODIFY
#
#       file_lines_added  file_lines_deleted  file_loc  file_complexity  \
# 0                   24                   0       NaN              NaN
# 1                    2                   0       NaN              NaN
# 2                  563                   0       NaN              NaN
# 3                    3                   2       NaN              NaN
# 4                    5                 560       NaN              NaN
# ...                ...                 ...       ...              ...
# 7194                 1                   1       NaN              NaN
# 7195                 1                   0       NaN              NaN
# 7196                14                   0       NaN              NaN
# 7197                 8                   0       NaN              NaN
# 7198                 7                   1       NaN              NaN
#
#       file_token_count
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 7194               NaN
# 7195               NaN
# 7196               NaN
# 7197               NaN
# 7198               NaN
#
# [7199 rows x 16 columns]

# %%
df.drop ( df[df.year_month == '2022-08'].index, inplace = True )
df
# Out:
#                                    commit_hash year_month  \
# 0     9d12a9c3f4ec059a3685c232ad179016fd35f909    2013-10
# 1     9d12a9c3f4ec059a3685c232ad179016fd35f909    2013-10
# 2     ee7b4d46e525096b26c1cc8f96a615751dc3ec48    2013-10
# 3     023fa674cbe907b4de8210dbe8b563ffd3a151a4    2013-10
# 4     6100b03a385ac9700558f6100414fa5d2178d09e    2013-10
# ...                                        ...        ...
# 7187  44579d337313231546e23de676e03475abc1a85f    2022-07
# 7188  44579d337313231546e23de676e03475abc1a85f    2022-07
# 7189  44579d337313231546e23de676e03475abc1a85f    2022-07
# 7190  1cd2a6acf73fa42f777d54974651d8af6f5f0c48    2022-07
# 7191  cd695d7a343a49fb54e6997773c47728bb19a855    2022-07
#
#        commit_author_name                              commit_author_email  \
# 0     vhf / victor felder                           victorfelder@gmail.com
# 1     vhf / victor felder                           victorfelder@gmail.com
# 2     vhf / victor felder                           victorfelder@gmail.com
# 3     vhf / victor felder                           victorfelder@gmail.com
# 4           Victor Felder                           victorfelder@gmail.com
# ...                   ...                                              ...
# 7187          David Ordás         3125580+davorpa@users.noreply.github.com
# 7188          David Ordás         3125580+davorpa@users.noreply.github.com
# 7189          David Ordás         3125580+davorpa@users.noreply.github.com
# 7190             ImVector  59611597+LuigiImVector@users.noreply.github.com
# 7191        CleanMachine1  78213164+CleanMachine1@users.noreply.github.com
#
#                 commit_datetime  commit_merge  dmm_unit_size  \
# 0     2013-10-10 23:50:37-07:00         False            NaN
# 1     2013-10-10 23:50:37-07:00         False            NaN
# 2     2013-10-11 08:53:59+02:00         False            NaN
# 3     2013-10-11 08:59:11+02:00         False            NaN
# 4     2013-10-11 09:04:49+02:00         False            NaN
# ...                         ...           ...            ...
# 7187  2022-07-29 12:46:20+02:00         False            NaN
# 7188  2022-07-29 12:46:20+02:00         False            NaN
# 7189  2022-07-29 12:46:20+02:00         False            NaN
# 7190  2022-07-29 12:47:37+02:00         False            NaN
# 7191  2022-07-29 12:49:11+02:00         False            NaN
#
#       dmm_unit_complexity  dmm_unit_interfacing  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 7187                  NaN                   NaN
# 7188                  NaN                   NaN
# 7189                  NaN                   NaN
# 7190                  NaN                   NaN
# 7191                  NaN                   NaN
#
#                                          file_name         file_change_type  \
# 0                                          LICENSE     ModificationType.ADD
# 1                                        README.md     ModificationType.ADD
# 2                                        README.md  ModificationType.MODIFY
# 3                                        README.md  ModificationType.MODIFY
# 4                                        README.md  ModificationType.MODIFY
# ...                                            ...                      ...
# 7187  free-programming-interactive-tutorials-en.md  ModificationType.MODIFY
# 7188  free-programming-interactive-tutorials-ja.md  ModificationType.MODIFY
# 7189               free-programming-playgrounds.md  ModificationType.MODIFY
# 7190                  free-programming-books-tr.md  ModificationType.MODIFY
# 7191                      PULL_REQUEST_TEMPLATE.md  ModificationType.MODIFY
#
#       file_lines_added  file_lines_deleted  file_loc  file_complexity  \
# 0                   24                   0       NaN              NaN
# 1                    2                   0       NaN              NaN
# 2                  563                   0       NaN              NaN
# 3                    3                   2       NaN              NaN
# 4                    5                 560       NaN              NaN
# ...                ...                 ...       ...              ...
# 7187                 2                   2       NaN              NaN
# 7188                 2                   2       NaN              NaN
# 7189                10                  10       NaN              NaN
# 7190                 3                   3       NaN              NaN
# 7191                 3                   2       NaN              NaN
#
#       file_token_count
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 7187               NaN
# 7188               NaN
# 7189               NaN
# 7190               NaN
# 7191               NaN
#
# [7192 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#     year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0      2013-10           418       6421       3379      0.0             0.0
# 1      2013-11           234       1920       1242      0.0             0.0
# 2      2013-12           175        645       1158      0.0             0.0
# 3      2014-01           239       3279       2270      0.0             0.0
# 4      2014-02            72        235        132      0.0             0.0
# ..         ...           ...        ...        ...      ...             ...
# 101    2022-03            43        369        148      0.0             0.0
# 102    2022-04            16         73         44      0.0             0.0
# 103    2022-05            12         88          7      0.0             0.0
# 104    2022-06            21         81         32      0.0             0.0
# 105    2022-07            49        725        563      0.0             0.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0                0.0            NaN                  NaN                   NaN
# 1                0.0            NaN                  NaN                   NaN
# 2                0.0            NaN                  NaN                   NaN
# 3                0.0            NaN                  NaN                   NaN
# 4                0.0            NaN                  NaN                   NaN
# ..               ...            ...                  ...                   ...
# 101              0.0            NaN                  NaN                   NaN
# 102              0.0            NaN                  NaN                   NaN
# 103              0.0            NaN                  NaN                   NaN
# 104              0.0            NaN                  NaN                   NaN
# 105              0.0            NaN                  NaN                   NaN
#
# [106 rows x 10 columns]

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
