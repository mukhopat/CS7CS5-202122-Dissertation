# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
# 1  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
# 2  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
# 3  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
# 4  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
#
#    commit_author_email            commit_datetime  commit_merge  \
# 0  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 1  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 2  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 3  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 4  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0       0.627007             0.660057              0.774315
# 1       0.627007             0.660057              0.774315
# 2       0.627007             0.660057              0.774315
# 3       0.627007             0.660057              0.774315
# 4       0.627007             0.660057              0.774315
#
#                     file_name      file_change_type  file_lines_added  \
# 0           baseline-20px.png  ModificationType.ADD                 0
# 1          blueprint-icon.png  ModificationType.ADD                 0
# 2               grid-20px.png  ModificationType.ADD                 0
# 3              grid-940px.png  ModificationType.ADD                 0
# 4  tablesorter-indicators.png  ModificationType.ADD                 0
#
#    file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                   0       NaN              NaN               NaN
# 1                   0       NaN              NaN               NaN
# 2                   0       NaN              NaN               NaN
# 3                   0       NaN              NaN               NaN
# 4                   0       NaN              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df.head()
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                 commit_hash year_month commit_author_name  \
# 0  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 1  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 2  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 3  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 4  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
#
#    commit_author_email            commit_datetime  commit_merge  \
# 0  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 1  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 2  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 3  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 4  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0       0.627007             0.660057              0.774315
# 1       0.627007             0.660057              0.774315
# 2       0.627007             0.660057              0.774315
# 3       0.627007             0.660057              0.774315
# 4       0.627007             0.660057              0.774315
#
#                     file_name      file_change_type  file_lines_added  \
# 0           baseline-20px.png  ModificationType.ADD                 0
# 1          blueprint-icon.png  ModificationType.ADD                 0
# 2               grid-20px.png  ModificationType.ADD                 0
# 3              grid-940px.png  ModificationType.ADD                 0
# 4  tablesorter-indicators.png  ModificationType.ADD                 0
#
#    file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                   0       NaN              NaN               NaN
# 1                   0       NaN              NaN               NaN
# 2                   0       NaN              NaN               NaN
# 3                   0       NaN              NaN               NaN
# 4                   0       NaN              NaN               NaN

# %%
from analysis_lib import generate_ordinal_encoding_map

enc_map = generate_ordinal_encoding_map ( df["commit_author_email"] )
df["commit_author_enc"] = df["commit_author_email"].replace(enc_map)
df.head()
# Out:
#                                 commit_hash year_month commit_author_name  \
# 0  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 1  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 2  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 3  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 4  eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
#
#    commit_author_email            commit_datetime  commit_merge  \
# 0  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 1  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 2  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 3  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 4  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0       0.627007             0.660057              0.774315
# 1       0.627007             0.660057              0.774315
# 2       0.627007             0.660057              0.774315
# 3       0.627007             0.660057              0.774315
# 4       0.627007             0.660057              0.774315
#
#                     file_name      file_change_type  file_lines_added  \
# 0           baseline-20px.png  ModificationType.ADD                 0
# 1          blueprint-icon.png  ModificationType.ADD                 0
# 2               grid-20px.png  ModificationType.ADD                 0
# 3              grid-940px.png  ModificationType.ADD                 0
# 4  tablesorter-indicators.png  ModificationType.ADD                 0
#
#    file_lines_deleted  file_loc  file_complexity  file_token_count  \
# 0                   0       NaN              NaN               NaN
# 1                   0       NaN              NaN               NaN
# 2                   0       NaN              NaN               NaN
# 3                   0       NaN              NaN               NaN
# 4                   0       NaN              NaN               NaN
#
#    commit_author_enc
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %%
df[df['commit_author_enc'] == 0].shape[0] # checking if there are any zeroes in author code
# Out:
# 0

# %%
from analysis_lib import covid_ym

pre_df = df [ df['year_month'] < covid_ym ]
post_df = df [ df['year_month'] >= covid_ym ]

# %%
pre_df = pre_df.groupby(['commit_author_enc']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum'
} ).reset_index(level=[0])

pre_df.rename(columns = {
     
    'commit_author_enc':'author_code',
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count'
}, inplace = True)

pre_df
# Out:
#       author_code  commit_count  additions  deletions   agg_loc  \
# 0               1          2035     171799     151696  766136.0
# 1               2           783     151220      87524  483228.0
# 2               3           262      20760      13854     454.0
# 3               4             6        361        214       0.0
# 4               5             1          3          0       0.0
# ...           ...           ...        ...        ...       ...
# 1103         1104             2         23          0       0.0
# 1104         1105             1          9          1       0.0
# 1105         1106             1          2          0       0.0
# 1106         1107             1          2          2     124.0
# 1107         1108             2          1         19       0.0
#
#       agg_complexity  agg_token_count
# 0           368983.0        9549204.0
# 1           309125.0        6720656.0
# 2              127.0           3452.0
# 3                0.0              0.0
# 4                0.0              0.0
# ...              ...              ...
# 1103             0.0              0.0
# 1104             0.0              0.0
# 1105             0.0              0.0
# 1106            24.0            822.0
# 1107             0.0              0.0
#
# [1108 rows x 7 columns]

# %%
post_df = post_df.groupby(['commit_author_enc']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum'
} ).reset_index(level=[0])

post_df.rename(columns = {
     
    'commit_author_enc':'author_code',
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count'
}, inplace = True)

post_df
# Out:
#      author_code  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0              1           180       6312       4458  26021.0          9206.0
# 1             15           170      12470       7075  47223.0         13815.0
# 2            115             2         14         11      0.0             0.0
# 3            223             7         63        103      0.0             0.0
# 4            236             4          5          5      0.0             0.0
# ..           ...           ...        ...        ...      ...             ...
# 264         1334             3         24         24    571.0           148.0
# 265         1335             1          1          1      0.0             0.0
# 266         1336             1          2          2      0.0             0.0
# 267         1337             1          1          1      0.0             0.0
# 268         1338             2          5          2      0.0             0.0
#
#      agg_token_count
# 0           228345.0
# 1           337211.0
# 2                0.0
# 3                0.0
# 4                0.0
# ..               ...
# 264           3246.0
# 265              0.0
# 266              0.0
# 267              0.0
# 268              0.0
#
# [269 rows x 7 columns]

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( pre_df, post_df )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  11  vs  9  ->  Down (18.2%)
# additions :  1007  vs  781  ->  Down (22.4%)
# deletions :  925  vs  609  ->  Down (34.2%)
# agg loc :  2328  vs  3945  ->  Up (69.5%)
# agg complexity :  1399  vs  1111  ->  Down (20.6%)
# agg token count :  33476  vs  29352  ->  Down (12.3%)

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{pre_df.columns[idx]} = { get_equilibrium_pc ( list ( pre_df[pre_df.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{post_df.columns[idx]} = { get_equilibrium_pc ( list ( post_df[post_df.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 0.5
# additions = 0.3
# deletions = 0.3
# agg_loc = 0.3
# agg_complexity = 0.3
# agg_token_count = 0.3
#
# Post-pandemic equilibrium percentages:
# commit_count = 1.5
# additions = 0.4
# deletions = 0.4
# agg_loc = 0.4
# agg_complexity = 0.4
# agg_token_count = 0.4

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{pre_df.columns[idx]} = { get_pareto_pc ( list ( pre_df[pre_df.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{post_df.columns[idx]} = { get_pareto_pc ( list ( post_df[post_df.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 2.0
# additions = 0.5
# deletions = 0.5
# agg_loc = 0.5
# agg_complexity = 0.5
# agg_token_count = 0.5
#
# Post-pandemic pareto percentages:
# commit_count = 4.8
# additions = 1.5
# deletions = 1.1
# agg_loc = 1.5
# agg_complexity = 1.1
# agg_token_count = 1.5
