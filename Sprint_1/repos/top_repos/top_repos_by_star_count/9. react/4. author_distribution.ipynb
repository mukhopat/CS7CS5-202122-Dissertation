# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
# 1  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
# 2  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
# 3  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
# 4  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4   Paul O’Shannessy
#
#    commit_author_email            commit_datetime  commit_merge  \
# 0  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 1  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 2  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 3  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 4  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing        file_name  \
# 0       0.606371              0.73698              0.828562    .editorconfig
# 1       0.606371              0.73698              0.828562       .gitignore
# 2       0.606371              0.73698              0.828562        .jshintrc
# 3       0.606371              0.73698              0.828562  CONTRIBUTING.md
# 4       0.606371              0.73698              0.828562     Gruntfile.js
#
#        file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0  ModificationType.ADD                12                   0       NaN
# 1  ModificationType.ADD                21                   0       NaN
# 2  ModificationType.ADD                20                   0       NaN
# 3  ModificationType.ADD                63                   0       NaN
# 4  ModificationType.ADD                99                   0      71.0
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              2.0             463.0

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df.head()
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                 commit_hash year_month commit_author_name  \
# 0  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 1  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 2  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 3  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 4  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
#
#    commit_author_email            commit_datetime  commit_merge  \
# 0  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 1  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 2  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 3  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 4  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing        file_name  \
# 0       0.606371              0.73698              0.828562    .editorconfig
# 1       0.606371              0.73698              0.828562       .gitignore
# 2       0.606371              0.73698              0.828562        .jshintrc
# 3       0.606371              0.73698              0.828562  CONTRIBUTING.md
# 4       0.606371              0.73698              0.828562     Gruntfile.js
#
#        file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0  ModificationType.ADD                12                   0       NaN
# 1  ModificationType.ADD                21                   0       NaN
# 2  ModificationType.ADD                20                   0       NaN
# 3  ModificationType.ADD                63                   0       NaN
# 4  ModificationType.ADD                99                   0      71.0
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              2.0             463.0

# %%
from analysis_lib import generate_ordinal_encoding_map

enc_map = generate_ordinal_encoding_map ( df["commit_author_email"] )
df["commit_author_enc"] = df["commit_author_email"].replace(enc_map)
df.head()
# Out:
#                                 commit_hash year_month commit_author_name  \
# 0  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 1  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 2  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 3  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
# 4  75897c2dcd1dd3a6ca46284dd37e13d22b4b16b4    2013-05   Paul O’Shannessy
#
#    commit_author_email            commit_datetime  commit_merge  \
# 0  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 1  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 2  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 3  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
# 4  paul@oshannessy.com  2013-05-29 12:54:02-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing        file_name  \
# 0       0.606371              0.73698              0.828562    .editorconfig
# 1       0.606371              0.73698              0.828562       .gitignore
# 2       0.606371              0.73698              0.828562        .jshintrc
# 3       0.606371              0.73698              0.828562  CONTRIBUTING.md
# 4       0.606371              0.73698              0.828562     Gruntfile.js
#
#        file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0  ModificationType.ADD                12                   0       NaN
# 1  ModificationType.ADD                21                   0       NaN
# 2  ModificationType.ADD                20                   0       NaN
# 3  ModificationType.ADD                63                   0       NaN
# 4  ModificationType.ADD                99                   0      71.0
#
#    file_complexity  file_token_count  commit_author_enc
# 0              NaN               NaN                  1
# 1              NaN               NaN                  1
# 2              NaN               NaN                  1
# 3              NaN               NaN                  1
# 4              2.0             463.0                  1

# %%
df[df['commit_author_enc'] == 0].shape[0] # checking if there are any zeroes in author code
# Out:
# 0

# %%
from analysis_lib import covid_ym

pre_df = df [ df['year_month'] < covid_ym ]
post_df = df [ df['year_month'] >= covid_ym ]

# %%
pre_df = pre_df.groupby(['commit_author_enc']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum'
} ).reset_index(level=[0])

pre_df.rename(columns = {
     
    'commit_author_enc':'author_code',
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count'
}, inplace = True)

pre_df
# Out:
#       author_code  commit_count  additions  deletions   agg_loc  \
# 0               1           785      80596     125330  443243.0
# 1               2           111      54719       2644   21792.0
# 2               3             7        100         29      27.0
# 3               4            70       3819       2322   34996.0
# 4               5             3          5          5     111.0
# ...           ...           ...        ...        ...       ...
# 1582         1583             2        204        105      76.0
# 1583         1584             2        577        217    2060.0
# 1584         1585             1          1          1      43.0
# 1585         1586             1          1          1     452.0
# 1586         1587             1         12          1    1452.0
#
#       agg_complexity  agg_token_count
# 0           100069.0        2809556.0
# 1             9915.0         223871.0
# 2                0.0             20.0
# 3             6061.0         193046.0
# 4               19.0            580.0
# ...              ...              ...
# 1582             8.0            502.0
# 1583           177.0           6440.0
# 1584             1.0            254.0
# 1585            18.0           1619.0
# 1586           133.0           6726.0
#
# [1587 rows x 7 columns]

# %%
post_df = post_df.groupby(['commit_author_enc']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum'
} ).reset_index(level=[0])

post_df.rename(columns = {
     
    'commit_author_enc':'author_code',
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count'
}, inplace = True)

post_df
# Out:
#      author_code  commit_count  additions  deletions   agg_loc  \
# 0              1             1          4          0       0.0
# 1              4            10        818        656   11182.0
# 2             22           208      42886      19156  824146.0
# 3             72             2         16          6    2603.0
# 4            102             1        188        274     814.0
# ..           ...           ...        ...        ...       ...
# 260         1800             1          1          1     190.0
# 261         1801             1        346         48    2373.0
# 262         1802             1          1          1       0.0
# 263         1803             1          1          1       0.0
# 264         1804             1          2          2       0.0
#
#      agg_complexity  agg_token_count
# 0               0.0              0.0
# 1            1066.0          52342.0
# 2           60378.0        3544082.0
# 3              33.0           9337.0
# 4             111.0           4368.0
# ..              ...              ...
# 260            23.0            904.0
# 261           281.0           9789.0
# 262             0.0              0.0
# 263             0.0              0.0
# 264             0.0              0.0
#
# [265 rows x 7 columns]

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( pre_df, post_df )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  6  vs  8  ->  Up (33.3%)
# additions :  858  vs  1852  ->  Up (115.9%)
# deletions :  612  vs  1038  ->  Up (69.6%)
# agg loc :  6640  vs  32853  ->  Up (394.8%)
# agg complexity :  770  vs  2014  ->  Up (161.6%)
# agg token count :  32755  vs  136383  ->  Up (316.4%)

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{pre_df.columns[idx]} = { get_equilibrium_pc ( list ( pre_df[pre_df.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{post_df.columns[idx]} = { get_equilibrium_pc ( list ( post_df[post_df.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 0.7
# additions = 0.4
# deletions = 0.3
# agg_loc = 0.4
# agg_complexity = 0.4
# agg_token_count = 0.4
#
# Post-pandemic equilibrium percentages:
# commit_count = 1.5
# additions = 1.1
# deletions = 0.8
# agg_loc = 0.8
# agg_complexity = 1.1
# agg_token_count = 0.8

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{pre_df.columns[idx]} = { get_pareto_pc ( list ( pre_df[pre_df.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{post_df.columns[idx]} = { get_pareto_pc ( list ( post_df[post_df.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 8.3
# additions = 1.2
# deletions = 0.9
# agg_loc = 1.4
# agg_complexity = 1.8
# agg_token_count = 1.6
#
# Post-pandemic pareto percentages:
# commit_count = 4.5
# additions = 2.6
# deletions = 1.9
# agg_loc = 2.6
# agg_complexity = 3.0
# agg_token_count = 2.6
