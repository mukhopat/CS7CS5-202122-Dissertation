# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_groupedby_yearmonth.csv'
df = pd.read_csv (dataset_path)
df
# Out:
#    year_month  commit_count  additions  deletions   agg_loc  agg_complexity  \
# 0     2016-04           380      37122       8192  115204.0         34937.0
# 1     2016-05           192      12271       3826   62991.0         10566.0
# 2     2016-06           207      24235      18906  204456.0         67578.0
# 3     2016-07           157      19362      15144  135788.0         45842.0
# 4     2016-08           126      20474      15579  166532.0         60105.0
# ..        ...           ...        ...        ...       ...             ...
# 69    2022-02             4         37        965       0.0             0.0
# 70    2022-04             6      44417      47679   82634.0         32599.0
# 71    2022-05            83     162463     262472  295860.0         63219.0
# 72    2022-06            85      13542       2977   50684.0          7015.0
# 73    2022-07            63       3423        638   28730.0          4137.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0          706296.0       0.598250             0.659186              0.677440
# 1          343274.0       0.605187             0.663728              0.614487
# 2         1526481.0       0.571804             0.678278              0.702376
# 3         1021427.0       0.477950             0.509817              0.631036
# 4         1284082.0       0.473997             0.583280              0.630723
# ..              ...            ...                  ...                   ...
# 69              0.0            NaN                  NaN                   NaN
# 70         694613.0       0.122351             0.054201              0.160173
# 71        1867341.0       0.561628             0.730672              0.651047
# 72         270980.0       0.573109             0.736625              0.841592
# 73         160785.0       0.638751             0.649282              0.737836
#
# [74 rows x 10 columns]

# %%
df['dmm_unit_size'] = df['dmm_unit_size'].fillna(0)
df['dmm_unit_complexity'] = df['dmm_unit_complexity'].fillna(0)
df['dmm_unit_interfacing'] = df['dmm_unit_interfacing'].fillna(0)

# %%
start_date = df.year_month[0][5:7] + '-01-' + df.year_month[0][0:4]
end_date = df.year_month[len(df.year_month) - 1][5:7] + '-01-' + df.year_month[len(df.year_month) - 1][0:4]
dfperiod = pd.period_range(start_date, end_date, freq='M')

def new_zero_row ( year_month ):
    
    new_row = {
        'year_month': year_month,
        'commit_count': 0,
        'additions': 0,
        'deletions': 0,
        'agg_loc': 0,
        'agg_complexity': 0,
        'agg_token_count': 0,
        'dmm_unit_size': 0,
        'dmm_unit_complexity': 0,
        'dmm_unit_interfacing': 0
    }
    
    return new_row

for year_month in dfperiod:
    if df [ ( df['year_month'] == str(year_month) ) ].shape[0] == 0:
        df = df.append ( new_zero_row(year_month), ignore_index = True )

df.shape
# Out:
# (76, 10)

# %%
df['year_month'] = df['year_month'].astype(str)
df = df.sort_values ( by=['year_month'] )
df.reset_index(drop=True, inplace=True)
df
# Out:
#    year_month  commit_count  additions  deletions   agg_loc  agg_complexity  \
# 0     2016-04           380      37122       8192  115204.0         34937.0
# 1     2016-05           192      12271       3826   62991.0         10566.0
# 2     2016-06           207      24235      18906  204456.0         67578.0
# 3     2016-07           157      19362      15144  135788.0         45842.0
# 4     2016-08           126      20474      15579  166532.0         60105.0
# ..        ...           ...        ...        ...       ...             ...
# 71    2022-03             0          0          0       0.0             0.0
# 72    2022-04             6      44417      47679   82634.0         32599.0
# 73    2022-05            83     162463     262472  295860.0         63219.0
# 74    2022-06            85      13542       2977   50684.0          7015.0
# 75    2022-07            63       3423        638   28730.0          4137.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0          706296.0       0.598250             0.659186              0.677440
# 1          343274.0       0.605187             0.663728              0.614487
# 2         1526481.0       0.571804             0.678278              0.702376
# 3         1021427.0       0.477950             0.509817              0.631036
# 4         1284082.0       0.473997             0.583280              0.630723
# ..              ...            ...                  ...                   ...
# 71              0.0       0.000000             0.000000              0.000000
# 72         694613.0       0.122351             0.054201              0.160173
# 73        1867341.0       0.561628             0.730672              0.651047
# 74         270980.0       0.573109             0.736625              0.841592
# 75         160785.0       0.638751             0.649282              0.737836
#
# [76 rows x 10 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_final.csv', index = False )

# %% [markdown]
# # Analysis

# %%
for idx in range(1, 10):
    ma_prefix = 'ma_'
    df[ma_prefix + df.columns[idx]] = df[df.columns[idx]].rolling ( window = 3 ).mean()
df
# Out:
#    year_month  commit_count  additions  deletions   agg_loc  agg_complexity  \
# 0     2016-04           380      37122       8192  115204.0         34937.0
# 1     2016-05           192      12271       3826   62991.0         10566.0
# 2     2016-06           207      24235      18906  204456.0         67578.0
# 3     2016-07           157      19362      15144  135788.0         45842.0
# 4     2016-08           126      20474      15579  166532.0         60105.0
# ..        ...           ...        ...        ...       ...             ...
# 71    2022-03             0          0          0       0.0             0.0
# 72    2022-04             6      44417      47679   82634.0         32599.0
# 73    2022-05            83     162463     262472  295860.0         63219.0
# 74    2022-06            85      13542       2977   50684.0          7015.0
# 75    2022-07            63       3423        638   28730.0          4137.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0          706296.0       0.598250             0.659186              0.677440
# 1          343274.0       0.605187             0.663728              0.614487
# 2         1526481.0       0.571804             0.678278              0.702376
# 3         1021427.0       0.477950             0.509817              0.631036
# 4         1284082.0       0.473997             0.583280              0.630723
# ..              ...            ...                  ...                   ...
# 71              0.0       0.000000             0.000000              0.000000
# 72         694613.0       0.122351             0.054201              0.160173
# 73        1867341.0       0.561628             0.730672              0.651047
# 74         270980.0       0.573109             0.736625              0.841592
# 75         160785.0       0.638751             0.649282              0.737836
#
#     ma_commit_count  ma_additions   ma_deletions     ma_agg_loc  \
# 0               NaN           NaN            NaN            NaN
# 1               NaN           NaN            NaN            NaN
# 2        259.666667  24542.666667   10308.000000  127550.333333
# 3        185.333333  18622.666667   12625.333333  134411.666667
# 4        163.333333  21357.000000   16543.000000  168925.333333
# ..              ...           ...            ...            ...
# 71         2.333333     24.000000     330.666667       0.000000
# 72         3.333333  14818.000000   16214.666667   27544.666667
# 73        29.666667  68960.000000  103383.666667  126164.666667
# 74        58.000000  73474.000000  104376.000000  143059.333333
# 75        77.000000  59809.333333   88695.666667  125091.333333
#
#     ma_agg_complexity  ma_agg_token_count  ma_dmm_unit_size  \
# 0                 NaN                 NaN               NaN
# 1                 NaN                 NaN               NaN
# 2        37693.666667        8.586837e+05          0.591747
# 3        41328.666667        9.637273e+05          0.551647
# 4        57841.666667        1.277330e+06          0.507917
# ..                ...                 ...               ...
# 71           0.000000        0.000000e+00          0.000000
# 72       10866.333333        2.315377e+05          0.040784
# 73       31939.333333        8.539847e+05          0.227993
# 74       34277.666667        9.443113e+05          0.419029
# 75       24790.333333        7.663687e+05          0.591163
#
#     ma_dmm_unit_complexity  ma_dmm_unit_interfacing
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                 0.667064                 0.664768
# 3                 0.617274                 0.649300
# 4                 0.590458                 0.654712
# ..                     ...                      ...
# 71                0.000000                 0.000000
# 72                0.018067                 0.053391
# 73                0.261624                 0.270407
# 74                0.507166                 0.550938
# 75                0.705526                 0.743492
#
# [76 rows x 19 columns]

# %%
from plot_line_lib import plot_line

for idx in range ( 1, 7 ):
    
    images_path = f'images/'
    plot_line ( df.columns[idx], idx, df, images_path, repo_name, major_locator = True )

# %%
from analysis_lib import year_pre_covid_ym, pre_covid_ym, covid_ym, year_post_covid_ym

df = df.set_index(df['year_month'])

df1 = df [ year_pre_covid_ym : pre_covid_ym ]
df2 = df [ covid_ym : year_post_covid_ym ]
df1 = df1.reset_index ( drop = True )
df2 = df2.reset_index ( drop = True )

df1.shape, df2.shape
# Out:
# ((12, 19), (12, 19))

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( df1, df2 )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  11  vs  4  ->  Down (63.6%)
# additions :  553  vs  56  ->  Down (89.9%)
# deletions :  392  vs  41  ->  Down (89.5%)
# agg loc :  30471  vs  7470  ->  Down (75.5%)
# agg complexity :  10936  vs  2622  ->  Down (76.0%)
# agg token count :  241460  vs  58792  ->  Down (75.7%)

# %% [markdown]
# # Distribution

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_equilibrium_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_equilibrium_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 25.0
# additions = 8.3
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
#
# Post-pandemic equilibrium percentages:
# commit_count = 25.0
# additions = 25.0
# deletions = 16.7
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_pareto_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_pareto_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 66.7
# additions = 16.7
# deletions = 16.7
# agg_loc = 16.7
# agg_complexity = 16.7
# agg_token_count = 16.7
#
# Post-pandemic pareto percentages:
# commit_count = 58.3
# additions = 50.0
# deletions = 41.7
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
