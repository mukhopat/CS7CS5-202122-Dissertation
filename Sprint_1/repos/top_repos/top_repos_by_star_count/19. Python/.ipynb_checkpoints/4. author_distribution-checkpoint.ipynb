# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  2636f3c62f1a407b2996da6e3fe6fdc5d1ccd764     Chetan Kaushik
# 1  e58c46237bdb8949bf063b6ec399ba24cec16eba  Anup Kumar Panwar
# 2  5e3a0d49d0544f5cc98212e1130ab01ee21b135e  Anup Kumar Panwar
# 3  b1b4bdaecddde492a9cca441b9c236ba16ee1d01     Chetan Kaushik
# 4  b1b4bdaecddde492a9cca441b9c236ba16ee1d01     Chetan Kaushik
#
#         commit_author_email            commit_datetime  commit_merge  \
# 0  dynamitechetan@gmail.com  2016-07-16 15:02:01+05:18         False
# 1         mylnext@gmail.com  2016-07-16 16:19:51+05:18         False
# 2         mylnext@gmail.com  2016-07-19 12:22:43+05:18         False
# 3  dynamitechetan@gmail.com  2016-07-19 22:22:17+05:18         False
# 4  dynamitechetan@gmail.com  2016-07-19 22:22:17+05:18         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0            NaN                  NaN                   NaN
# 1            NaN                  NaN                   NaN
# 2            NaN                  NaN                   NaN
# 3            1.0                  1.0              0.636364
# 4            1.0                  1.0              0.636364
#
#               file_name         file_change_type  file_lines_added  \
# 0             README.md     ModificationType.ADD                 2
# 1     BubbleSort.python     ModificationType.ADD                26
# 2  InsertionSort.python     ModificationType.ADD                27
# 3         BubbleSort.py  ModificationType.RENAME                 0
# 4      InsertionSort.py  ModificationType.RENAME                 0
#
#    file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                   0       NaN              NaN               NaN
# 1                   0       NaN              NaN               NaN
# 2                   0       NaN              NaN               NaN
# 3                   0       NaN              NaN               NaN
# 4                   2      15.0              0.0             119.0

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df.head()
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                 commit_hash year_month commit_author_name  \
# 0  2636f3c62f1a407b2996da6e3fe6fdc5d1ccd764    2016-07     Chetan Kaushik
# 1  e58c46237bdb8949bf063b6ec399ba24cec16eba    2016-07  Anup Kumar Panwar
# 2  5e3a0d49d0544f5cc98212e1130ab01ee21b135e    2016-07  Anup Kumar Panwar
# 3  b1b4bdaecddde492a9cca441b9c236ba16ee1d01    2016-07     Chetan Kaushik
# 4  b1b4bdaecddde492a9cca441b9c236ba16ee1d01    2016-07     Chetan Kaushik
#
#         commit_author_email            commit_datetime  commit_merge  \
# 0  dynamitechetan@gmail.com  2016-07-16 15:02:01+05:18         False
# 1         mylnext@gmail.com  2016-07-16 16:19:51+05:18         False
# 2         mylnext@gmail.com  2016-07-19 12:22:43+05:18         False
# 3  dynamitechetan@gmail.com  2016-07-19 22:22:17+05:18         False
# 4  dynamitechetan@gmail.com  2016-07-19 22:22:17+05:18         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0            NaN                  NaN                   NaN
# 1            NaN                  NaN                   NaN
# 2            NaN                  NaN                   NaN
# 3            1.0                  1.0              0.636364
# 4            1.0                  1.0              0.636364
#
#               file_name         file_change_type  file_lines_added  \
# 0             README.md     ModificationType.ADD                 2
# 1     BubbleSort.python     ModificationType.ADD                26
# 2  InsertionSort.python     ModificationType.ADD                27
# 3         BubbleSort.py  ModificationType.RENAME                 0
# 4      InsertionSort.py  ModificationType.RENAME                 0
#
#    file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                   0       NaN              NaN               NaN
# 1                   0       NaN              NaN               NaN
# 2                   0       NaN              NaN               NaN
# 3                   0       NaN              NaN               NaN
# 4                   2      15.0              0.0             119.0

# %%
from analysis_lib import generate_ordinal_encoding_map

enc_map = generate_ordinal_encoding_map ( df["commit_author_email"] )
df["commit_author_enc"] = df["commit_author_email"].replace(enc_map)
df.head()
# Out:
#                                 commit_hash year_month commit_author_name  \
# 0  2636f3c62f1a407b2996da6e3fe6fdc5d1ccd764    2016-07     Chetan Kaushik
# 1  e58c46237bdb8949bf063b6ec399ba24cec16eba    2016-07  Anup Kumar Panwar
# 2  5e3a0d49d0544f5cc98212e1130ab01ee21b135e    2016-07  Anup Kumar Panwar
# 3  b1b4bdaecddde492a9cca441b9c236ba16ee1d01    2016-07     Chetan Kaushik
# 4  b1b4bdaecddde492a9cca441b9c236ba16ee1d01    2016-07     Chetan Kaushik
#
#         commit_author_email            commit_datetime  commit_merge  \
# 0  dynamitechetan@gmail.com  2016-07-16 15:02:01+05:18         False
# 1         mylnext@gmail.com  2016-07-16 16:19:51+05:18         False
# 2         mylnext@gmail.com  2016-07-19 12:22:43+05:18         False
# 3  dynamitechetan@gmail.com  2016-07-19 22:22:17+05:18         False
# 4  dynamitechetan@gmail.com  2016-07-19 22:22:17+05:18         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0            NaN                  NaN                   NaN
# 1            NaN                  NaN                   NaN
# 2            NaN                  NaN                   NaN
# 3            1.0                  1.0              0.636364
# 4            1.0                  1.0              0.636364
#
#               file_name         file_change_type  file_lines_added  \
# 0             README.md     ModificationType.ADD                 2
# 1     BubbleSort.python     ModificationType.ADD                26
# 2  InsertionSort.python     ModificationType.ADD                27
# 3         BubbleSort.py  ModificationType.RENAME                 0
# 4      InsertionSort.py  ModificationType.RENAME                 0
#
#    file_lines_deleted  file_loc  file_complexity  file_token_count  \
# 0                   0       NaN              NaN               NaN
# 1                   0       NaN              NaN               NaN
# 2                   0       NaN              NaN               NaN
# 3                   0       NaN              NaN               NaN
# 4                   2      15.0              0.0             119.0
#
#    commit_author_enc
# 0                  1
# 1                  2
# 2                  2
# 3                  1
# 4                  1

# %%
df[df['commit_author_enc'] == 0].shape[0] # checking if there are any zeroes in author code
# Out:
# 0

# %%
from analysis_lib import covid_ym

pre_df = df [ df['year_month'] < covid_ym ]
post_df = df [ df['year_month'] >= covid_ym ]

# %%
pre_df = pre_df.groupby(['commit_author_enc']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum'
} ).reset_index(level=[0])

pre_df.rename(columns = {
     
    'commit_author_enc':'author_code',
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count'
}, inplace = True)

pre_df
# Out:
#      author_code  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0              1             8        144        123    121.0            31.0
# 1              2             3         86          0     22.0             4.0
# 2              3            58     290192        581   2071.0           503.0
# 3              4             1         29          0     23.0             5.0
# 4              5             8        677        341    428.0            66.0
# ..           ...           ...        ...        ...      ...             ...
# 457          458             2        139          0    103.0             2.0
# 458          459             1         45          0     35.0             8.0
# 459          460             3        167         81    196.0            21.0
# 460          461             1         88          0     71.0            13.0
# 461          462             1        105          0     71.0            15.0
#
#      agg_token_count
# 0              771.0
# 1              155.0
# 2            14263.0
# 3              177.0
# 4             1828.0
# ..               ...
# 457            433.0
# 458            176.0
# 459            888.0
# 460            539.0
# 461            322.0
#
# [462 rows x 7 columns]

# %%
post_df = post_df.groupby(['commit_author_enc']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum'
} ).reset_index(level=[0])

post_df.rename(columns = {
     
    'commit_author_enc':'author_code',
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count'
}, inplace = True)

post_df
# Out:
#      author_code  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0             13             2          1         13      0.0             0.0
# 1            162             3        291         32    249.0            38.0
# 2            197            10        327        198    386.0            78.0
# 3            232             8        187        186   1063.0           128.0
# 4            248           108       4388       3481  69602.0         11683.0
# ..           ...           ...        ...        ...      ...             ...
# 413          858             1         86         52    425.0           128.0
# 414          859             1         87          0     69.0            11.0
# 415          860             1         51          0     46.0             6.0
# 416          861             1          9          9     64.0             5.0
# 417          862             1          1          1    122.0            10.0
#
#      agg_token_count
# 0                0.0
# 1              826.0
# 2             1882.0
# 3             3881.0
# 4           329110.0
# ..               ...
# 413           2151.0
# 414            257.0
# 415            178.0
# 416            101.0
# 417            336.0
#
# [418 rows x 7 columns]

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( pre_df, post_df )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  2  vs  2  ->  No change
# additions :  1464  vs  234  ->  Down (84.0%)
# deletions :  110  vs  43  ->  Down (60.9%)
# agg loc :  287  vs  435  ->  Up (51.6%)
# agg complexity :  65  vs  69  ->  Up (6.2%)
# agg token count :  1837  vs  1908  ->  Up (3.9%)

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{pre_df.columns[idx]} = { get_equilibrium_pc ( list ( pre_df[pre_df.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{post_df.columns[idx]} = { get_equilibrium_pc ( list ( post_df[post_df.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 12.3
# additions = 0.4
# deletions = 0.4
# agg_loc = 1.3
# agg_complexity = 1.3
# agg_token_count = 1.3
#
# Post-pandemic equilibrium percentages:
# commit_count = 9.3
# additions = 1.2
# deletions = 0.7
# agg_loc = 1.0
# agg_complexity = 0.7
# agg_token_count = 0.7

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{pre_df.columns[idx]} = { get_pareto_pc ( list ( pre_df[pre_df.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{post_df.columns[idx]} = { get_pareto_pc ( list ( post_df[post_df.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 51.9
# additions = 0.4
# deletions = 1.5
# agg_loc = 11.9
# agg_complexity = 11.0
# agg_token_count = 11.3
#
# Post-pandemic pareto percentages:
# commit_count = 51.7
# additions = 16.7
# deletions = 5.0
# agg_loc = 12.7
# agg_complexity = 9.1
# agg_token_count = 9.1
