# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  b7cc33a99b02fada900d0e4ba6b7bd38a142f064    Chris Wanstrath
# 1  b7cc33a99b02fada900d0e4ba6b7bd38a142f064    Chris Wanstrath
# 2  b7cc33a99b02fada900d0e4ba6b7bd38a142f064    Chris Wanstrath
# 3  bd6cd2d41b1cd11cafbd49cd4ec0ef5d841aefc0    Chris Wanstrath
# 4  281c121d69baac362e3b6b3f3a8517f762c2689a    Chris Wanstrath
#
#   commit_author_email            commit_datetime  commit_merge  dmm_unit_size  \
# 0      chris@ozmm.org  2010-11-08 12:21:45-08:00         False            NaN
# 1      chris@ozmm.org  2010-11-08 12:21:45-08:00         False            NaN
# 2      chris@ozmm.org  2010-11-08 12:21:45-08:00         False            NaN
# 3      chris@ozmm.org  2010-11-08 12:43:25-08:00         False            NaN
# 4      chris@ozmm.org  2010-11-08 12:46:40-08:00         False            NaN
#
#    dmm_unit_complexity  dmm_unit_interfacing              file_name  \
# 0                  NaN                   NaN  Objective-C.gitignore
# 1                  NaN                   NaN              README.md
# 2                  NaN                   NaN        Rails.gitignore
# 3                  NaN                   NaN              README.md
# 4                  NaN                   NaN              README.md
#
#           file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0     ModificationType.ADD                 8                   0       NaN
# 1     ModificationType.ADD                 3                   0       NaN
# 2     ModificationType.ADD                 5                   0       NaN
# 3  ModificationType.MODIFY                 5                   1       NaN
# 4  ModificationType.MODIFY                 3                   0       NaN
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                    commit_hash year_month  \
# 0     b7cc33a99b02fada900d0e4ba6b7bd38a142f064    2010-11
# 1     b7cc33a99b02fada900d0e4ba6b7bd38a142f064    2010-11
# 2     b7cc33a99b02fada900d0e4ba6b7bd38a142f064    2010-11
# 3     bd6cd2d41b1cd11cafbd49cd4ec0ef5d841aefc0    2010-11
# 4     281c121d69baac362e3b6b3f3a8517f762c2689a    2010-11
# ...                                        ...        ...
# 2260  a4a6c5c9c2fb0e7d309586877ac15fc8d09332bf    2022-02
# 2261  0481f3bda81ec0f25b634be18f27885130df7e46    2022-02
# 2262  35b656aa850665b922834c9b635b154dca207e33    2022-02
# 2263  8e67b9420cb6796e5eeca72682babdb06627ec8c    2022-02
# 2264  aa4079ebec8451687964cd01f417b4e2da6e1c5e    2022-05
#
#             commit_author_name                 commit_author_email  \
# 0              Chris Wanstrath                      chris@ozmm.org
# 1              Chris Wanstrath                      chris@ozmm.org
# 2              Chris Wanstrath                      chris@ozmm.org
# 3              Chris Wanstrath                      chris@ozmm.org
# 4              Chris Wanstrath                      chris@ozmm.org
# ...                        ...                                 ...
# 2260                    Deepak                    iapain@gmail.com
# 2261  Juan Luis Cano Rodríguez                  hello@juanlu.space
# 2262  Juan Luis Cano Rodríguez                  hello@juanlu.space
# 2263  Juan Luis Cano Rodríguez                  hello@juanlu.space
# 2264      Chriztian Steinmeier  greystate@users.noreply.github.com
#
#                 commit_datetime  commit_merge  dmm_unit_size  \
# 0     2010-11-08 12:21:45-08:00         False            NaN
# 1     2010-11-08 12:21:45-08:00         False            NaN
# 2     2010-11-08 12:21:45-08:00         False            NaN
# 3     2010-11-08 12:43:25-08:00         False            NaN
# 4     2010-11-08 12:46:40-08:00         False            NaN
# ...                         ...           ...            ...
# 2260  2022-02-10 23:11:32+01:00         False            NaN
# 2261  2022-02-16 23:43:19+01:00         False            NaN
# 2262  2022-02-18 18:54:31+01:00         False            NaN
# 2263  2022-02-20 11:29:55+01:00         False            NaN
# 2264  2022-05-06 11:23:14+02:00         False            NaN
#
#       dmm_unit_complexity  dmm_unit_interfacing              file_name  \
# 0                     NaN                   NaN  Objective-C.gitignore
# 1                     NaN                   NaN              README.md
# 2                     NaN                   NaN        Rails.gitignore
# 3                     NaN                   NaN              README.md
# 4                     NaN                   NaN              README.md
# ...                   ...                   ...                    ...
# 2260                  NaN                   NaN    Terraform.gitignore
# 2261                  NaN                   NaN       Python.gitignore
# 2262                  NaN                   NaN       Python.gitignore
# 2263                  NaN                   NaN       Python.gitignore
# 2264                  NaN                   NaN      Umbraco.gitignore
#
#              file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0        ModificationType.ADD                 8                   0       NaN
# 1        ModificationType.ADD                 3                   0       NaN
# 2        ModificationType.ADD                 5                   0       NaN
# 3     ModificationType.MODIFY                 5                   1       NaN
# 4     ModificationType.MODIFY                 3                   0       NaN
# ...                       ...               ...                 ...       ...
# 2260  ModificationType.MODIFY                 1                   0       NaN
# 2261  ModificationType.MODIFY                 7                   1       NaN
# 2262  ModificationType.MODIFY                 8                   0       NaN
# 2263  ModificationType.MODIFY                 0                   6       NaN
# 2264  ModificationType.MODIFY                 4                   1       NaN
#
#       file_complexity  file_token_count
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 2260              NaN               NaN
# 2261              NaN               NaN
# 2262              NaN               NaN
# 2263              NaN               NaN
# 2264              NaN               NaN
#
# [2265 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#     year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0      2010-11           134        758        102      0.0             0.0
# 1      2011-01            11         30          6      0.0             0.0
# 2      2011-02            18        129         11      0.0             0.0
# 3      2011-03            12        196         86      0.0             0.0
# 4      2011-04            10         36         16      0.0             0.0
# ..         ...           ...        ...        ...      ...             ...
# 128    2021-11            13         60          4      0.0             0.0
# 129    2021-12            26        111         45      0.0             0.0
# 130    2022-01             6         12          5      0.0             0.0
# 131    2022-02             9         29         10      0.0             0.0
# 132    2022-05             1          4          1      0.0             0.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0                0.0            NaN                  NaN                   NaN
# 1                0.0            NaN                  NaN                   NaN
# 2                0.0            NaN                  NaN                   NaN
# 3                0.0            NaN                  NaN                   NaN
# 4                0.0            NaN                  NaN                   NaN
# ..               ...            ...                  ...                   ...
# 128              0.0            NaN                  NaN                   NaN
# 129              0.0            NaN                  NaN                   NaN
# 130              0.0            NaN                  NaN                   NaN
# 131              0.0            NaN                  NaN                   NaN
# 132              0.0            NaN                  NaN                   NaN
#
# [133 rows x 10 columns]

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
