# %%
from pydriller import Repository
from time import time
from datetime import timedelta
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
repo_path = f'./clone/{repo_name}'

commit_data = []

start_time = time()

for commit in Repository(repo_path).traverse_commits():
    for file in commit.modified_files:
        commit_data.append( [
            commit.hash, 
            commit.author.name, 
            commit.author.email,
            commit.committer_date,
            commit.merge,
            commit.dmm_unit_size,
            commit.dmm_unit_complexity,
            commit.dmm_unit_interfacing,
            file.filename, 
            file.change_type, 
            file.added_lines, 
            file.deleted_lines,
            file.nloc,
            file.complexity,
            file.token_count
        ] )
        
print( f'Execution time = { str ( timedelta ( seconds = time() - start_time ) ) }' )
# Out:
# Execution time = 0:01:05.680236

# %%
import pandas as pd

df = pd.DataFrame(commit_data)

df.columns = [
    'commit_hash', 
    'commit_author_name', 
    'commit_author_email',
    'commit_datetime', 
    'commit_merge',
    'dmm_unit_size',
    'dmm_unit_complexity',
    'dmm_unit_interfacing',
    'file_name', 
    'file_change_type', 
    'file_lines_added',
    'file_lines_deleted',
    'file_loc',
    'file_complexity',
    'file_token_count'
]

df
# Out:
#                                    commit_hash commit_author_name  \
# 0     17735297206222cf06b106ec1953645dc621f4fa   Oleksii Trekhleb
# 1     e9a3b9d30c506af37b0bdd7137bc1cbc576cefb5   Oleksii Trekhleb
# 2     83b3a35834fcf2c776e508e228a3b698bb216a06   Oleksii Trekhleb
# 3     83b3a35834fcf2c776e508e228a3b698bb216a06   Oleksii Trekhleb
# 4     83b3a35834fcf2c776e508e228a3b698bb216a06   Oleksii Trekhleb
# ...                                        ...                ...
# 2672  3d2cfb99b78dde8da9342a47affa8b09b2210b38   Oleksii Trekhleb
# 2673  3d2cfb99b78dde8da9342a47affa8b09b2210b38   Oleksii Trekhleb
# 2674  3d2cfb99b78dde8da9342a47affa8b09b2210b38   Oleksii Trekhleb
# 2675  3d2cfb99b78dde8da9342a47affa8b09b2210b38   Oleksii Trekhleb
# 2676  3d2cfb99b78dde8da9342a47affa8b09b2210b38   Oleksii Trekhleb
#
#      commit_author_email            commit_datetime  commit_merge  \
# 0      trehleb@gmail.com  2018-03-24 09:48:50+02:00         False
# 1      trehleb@gmail.com  2018-03-24 09:49:25+02:00         False
# 2      trehleb@gmail.com  2018-03-25 23:28:32+03:00         False
# 3      trehleb@gmail.com  2018-03-25 23:28:32+03:00         False
# 4      trehleb@gmail.com  2018-03-25 23:28:32+03:00         False
# ...                  ...                        ...           ...
# 2672   trehleb@gmail.com  2022-07-29 21:47:38+02:00         False
# 2673   trehleb@gmail.com  2022-07-29 21:47:38+02:00         False
# 2674   trehleb@gmail.com  2022-07-29 21:47:38+02:00         False
# 2675   trehleb@gmail.com  2022-07-29 21:47:38+02:00         False
# 2676   trehleb@gmail.com  2022-07-29 21:47:38+02:00         False
#
#       dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0               NaN                  NaN                   NaN
# 1               NaN                  NaN                   NaN
# 2               1.0                  1.0                   1.0
# 3               1.0                  1.0                   1.0
# 4               1.0                  1.0                   1.0
# ...             ...                  ...                   ...
# 2672            NaN                  NaN                   NaN
# 2673            NaN                  NaN                   NaN
# 2674            NaN                  NaN                   NaN
# 2675            NaN                  NaN                   NaN
# 2676            NaN                  NaN                   NaN
#
#                       file_name         file_change_type  file_lines_added  \
# 0                    .gitignore     ModificationType.ADD                 1
# 1                     README.md     ModificationType.ADD                 1
# 2                      .babelrc     ModificationType.ADD                11
# 3                 .editorconfig     ModificationType.ADD                 8
# 4                    .gitignore  ModificationType.MODIFY                 2
# ...                         ...                      ...               ...
# 2672            README.tr-TR.md  ModificationType.MODIFY                 8
# 2673            README.zh-CN.md  ModificationType.MODIFY                23
# 2674  array-representation.jpeg     ModificationType.ADD                 0
# 2675              max-heap.jpeg     ModificationType.ADD                 0
# 2676              min-heap.jpeg     ModificationType.ADD                 0
#
#       file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                      0       NaN              NaN               NaN
# 1                      0       NaN              NaN               NaN
# 2                      0       NaN              NaN               NaN
# 3                      0       NaN              NaN               NaN
# 4                      0       NaN              NaN               NaN
# ...                  ...       ...              ...               ...
# 2672                   4       NaN              NaN               NaN
# 2673                  19       NaN              NaN               NaN
# 2674                   0       NaN              NaN               NaN
# 2675                   0       NaN              NaN               NaN
# 2676                   0       NaN              NaN               NaN
#
# [2677 rows x 15 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_modfiles.csv', index = False )

# %%
import winsound
winsound.MessageBeep ( type = -1 )
