# %%
from pydriller import Repository
from time import time
from datetime import timedelta
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
repo_path = f'./clone/{repo_name}'

commit_data = []

start_time = time()

for commit in Repository(repo_path).traverse_commits():
    for file in commit.modified_files:
        commit_data.append( [
            commit.hash, 
            commit.author.name, 
            commit.author.email,
            commit.committer_date,
            commit.merge,
            commit.dmm_unit_size,
            commit.dmm_unit_complexity,
            commit.dmm_unit_interfacing,
            file.filename, 
            file.change_type, 
            file.added_lines, 
            file.deleted_lines,
            file.nloc,
            file.complexity,
            file.token_count
        ] )
        
print( f'Execution time = { str ( timedelta ( seconds = time() - start_time ) ) }' )
# Out:
# Execution time = 0:01:22.185393

# %%
import pandas as pd

df = pd.DataFrame(commit_data)

df.columns = [
    'commit_hash', 
    'commit_author_name', 
    'commit_author_email',
    'commit_datetime', 
    'commit_merge',
    'dmm_unit_size',
    'dmm_unit_complexity',
    'dmm_unit_interfacing',
    'file_name', 
    'file_change_type', 
    'file_lines_added',
    'file_lines_deleted',
    'file_loc',
    'file_complexity',
    'file_token_count'
]

df
# Out:
#                                    commit_hash commit_author_name  \
# 0     d239d7b97c726981c6e2a959a921d51184846a5b        John Washam
# 1     34219525fbcb64f960e0bc9a0e6a10f6e125513c        John Washam
# 2     34219525fbcb64f960e0bc9a0e6a10f6e125513c        John Washam
# 3     c950b208933c4f6ff7a681d9870405e633dfe84a        John Washam
# 4     c950b208933c4f6ff7a681d9870405e633dfe84a        John Washam
# ...                                        ...                ...
# 2098  694157e8afaee5167959fe0976114258b9832823       Anri Lombard
# 2099  d97574ecd42b30df2efa7b0a3edef9a5bd2e8a76     Sandeep Mishra
# 2100  0187f27018eaef1d51b6523c0ff3669cc874abc3        John Washam
# 2101  c7f69947f4033c8be258bb6c6f7372b57a286ce5        John Washam
# 2102  6001497deffd2acdd47e0c48160907edeea47956          anmolp476
#
#                                     commit_author_email  \
# 0                                  john@readyprompt.com
# 1                                  john@readyprompt.com
# 2                                  john@readyprompt.com
# 3                                  john@readyprompt.com
# 4                                  john@readyprompt.com
# ...                                                 ...
# 2098                           anri.m.lombard@gmail.com
# 2099  87706790+sandeepmishratech@users.noreply.githu...
# 2100                                   washam@gmail.com
# 2101                               john@readyprompt.com
# 2102        99687931+anmolp476@users.noreply.github.com
#
#                 commit_datetime  commit_merge dmm_unit_size  \
# 0     2016-06-05 19:34:12-07:00         False          None
# 1     2016-06-05 19:41:26-07:00         False          None
# 2     2016-06-05 19:41:26-07:00         False          None
# 3     2016-06-05 19:46:49-07:00         False          None
# 4     2016-06-05 19:46:49-07:00         False          None
# ...                         ...           ...           ...
# 2098  2022-07-21 11:45:53+02:00         False          None
# 2099  2022-07-22 09:30:33+05:18         False          None
# 2100  2022-07-25 09:29:59-07:00         False          None
# 2101  2022-07-31 19:02:57-07:00         False          None
# 2102  2022-08-02 13:39:35-04:00         False          None
#
#      dmm_unit_complexity dmm_unit_interfacing  \
# 0                   None                 None
# 1                   None                 None
# 2                   None                 None
# 3                   None                 None
# 4                   None                 None
# ...                  ...                  ...
# 2098                None                 None
# 2099                None                 None
# 2100                None                 None
# 2101                None                 None
# 2102                None                 None
#
#                               file_name         file_change_type  \
# 0                             README.md     ModificationType.ADD
# 1                            .gitignore     ModificationType.ADD
# 2                             README.md  ModificationType.MODIFY
# 3                             README.md  ModificationType.MODIFY
# 4                              plan.txt     ModificationType.ADD
# ...                                 ...                      ...
# 2098                       README-af.md  ModificationType.MODIFY
# 2099  programming-language-resources.md  ModificationType.MODIFY
# 2100                          README.md  ModificationType.MODIFY
# 2101                  links_checker.yml  ModificationType.MODIFY
# 2102                          README.md  ModificationType.MODIFY
#
#       file_lines_added  file_lines_deleted  file_loc  file_complexity  \
# 0                    2                   0       NaN              NaN
# 1                    2                   0       NaN              NaN
# 2                    2                   1       NaN              NaN
# 3                    1                   1       NaN              NaN
# 4                  382                   0       NaN              NaN
# ...                ...                 ...       ...              ...
# 2098               128                   2       NaN              NaN
# 2099                 1                   0       NaN              NaN
# 2100                 0                  28       NaN              NaN
# 2101                 2                   2       NaN              NaN
# 2102                 2                   0       NaN              NaN
#
#       file_token_count
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 2098               NaN
# 2099               NaN
# 2100               NaN
# 2101               NaN
# 2102               NaN
#
# [2103 rows x 15 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_modfiles.csv', index = False )

# %%
import winsound
winsound.MessageBeep(-1)
