# %%
from pydriller import Repository
from time import time
from datetime import timedelta
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
repo_path = f'./clone/{repo_name}'

commit_data = []

start_time = time()

for commit in Repository(repo_path).traverse_commits():
    for file in commit.modified_files:
        commit_data.append( [
            commit.hash, 
            commit.author.name, 
            commit.author.email,
            commit.committer_date,
            commit.merge,
            commit.dmm_unit_size,
            commit.dmm_unit_complexity,
            commit.dmm_unit_interfacing,
            file.filename, 
            file.change_type, 
            file.added_lines, 
            file.deleted_lines,
            file.nloc,
            file.complexity,
            file.token_count
        ] )
        
print( f'Execution time = { str ( timedelta ( seconds = time() - start_time ) ) }' )
# Out:
# Execution time = 0:01:38.588640

# %%
import pandas as pd

df = pd.DataFrame(commit_data)

df.columns = [
    'commit_hash', 
    'commit_author_name', 
    'commit_author_email',
    'commit_datetime', 
    'commit_merge',
    'dmm_unit_size',
    'dmm_unit_complexity',
    'dmm_unit_interfacing',
    'file_name', 
    'file_change_type', 
    'file_lines_added',
    'file_lines_deleted',
    'file_loc',
    'file_complexity',
    'file_token_count'
]

df
# Out:
#                                    commit_hash        commit_author_name  \
# 0     b7cc33a99b02fada900d0e4ba6b7bd38a142f064           Chris Wanstrath
# 1     b7cc33a99b02fada900d0e4ba6b7bd38a142f064           Chris Wanstrath
# 2     b7cc33a99b02fada900d0e4ba6b7bd38a142f064           Chris Wanstrath
# 3     bd6cd2d41b1cd11cafbd49cd4ec0ef5d841aefc0           Chris Wanstrath
# 4     281c121d69baac362e3b6b3f3a8517f762c2689a           Chris Wanstrath
# ...                                        ...                       ...
# 2260  a4a6c5c9c2fb0e7d309586877ac15fc8d09332bf                    Deepak
# 2261  0481f3bda81ec0f25b634be18f27885130df7e46  Juan Luis Cano Rodríguez
# 2262  35b656aa850665b922834c9b635b154dca207e33  Juan Luis Cano Rodríguez
# 2263  8e67b9420cb6796e5eeca72682babdb06627ec8c  Juan Luis Cano Rodríguez
# 2264  aa4079ebec8451687964cd01f417b4e2da6e1c5e      Chriztian Steinmeier
#
#                      commit_author_email            commit_datetime  \
# 0                         chris@ozmm.org  2010-11-08 12:21:45-08:00
# 1                         chris@ozmm.org  2010-11-08 12:21:45-08:00
# 2                         chris@ozmm.org  2010-11-08 12:21:45-08:00
# 3                         chris@ozmm.org  2010-11-08 12:43:25-08:00
# 4                         chris@ozmm.org  2010-11-08 12:46:40-08:00
# ...                                  ...                        ...
# 2260                    iapain@gmail.com  2022-02-10 23:11:32+01:00
# 2261                  hello@juanlu.space  2022-02-16 23:43:19+01:00
# 2262                  hello@juanlu.space  2022-02-18 18:54:31+01:00
# 2263                  hello@juanlu.space  2022-02-20 11:29:55+01:00
# 2264  greystate@users.noreply.github.com  2022-05-06 11:23:14+02:00
#
#       commit_merge dmm_unit_size dmm_unit_complexity dmm_unit_interfacing  \
# 0            False          None                None                 None
# 1            False          None                None                 None
# 2            False          None                None                 None
# 3            False          None                None                 None
# 4            False          None                None                 None
# ...            ...           ...                 ...                  ...
# 2260         False          None                None                 None
# 2261         False          None                None                 None
# 2262         False          None                None                 None
# 2263         False          None                None                 None
# 2264         False          None                None                 None
#
#                   file_name         file_change_type  file_lines_added  \
# 0     Objective-C.gitignore     ModificationType.ADD                 8
# 1                 README.md     ModificationType.ADD                 3
# 2           Rails.gitignore     ModificationType.ADD                 5
# 3                 README.md  ModificationType.MODIFY                 5
# 4                 README.md  ModificationType.MODIFY                 3
# ...                     ...                      ...               ...
# 2260    Terraform.gitignore  ModificationType.MODIFY                 1
# 2261       Python.gitignore  ModificationType.MODIFY                 7
# 2262       Python.gitignore  ModificationType.MODIFY                 8
# 2263       Python.gitignore  ModificationType.MODIFY                 0
# 2264      Umbraco.gitignore  ModificationType.MODIFY                 4
#
#       file_lines_deleted file_loc file_complexity file_token_count
# 0                      0     None            None             None
# 1                      0     None            None             None
# 2                      0     None            None             None
# 3                      1     None            None             None
# 4                      0     None            None             None
# ...                  ...      ...             ...              ...
# 2260                   0     None            None             None
# 2261                   1     None            None             None
# 2262                   0     None            None             None
# 2263                   6     None            None             None
# 2264                   1     None            None             None
#
# [2265 rows x 15 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_modfiles.csv', index = False )
