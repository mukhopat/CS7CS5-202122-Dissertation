# %%
from pydriller import Repository

repo_path = './clone/flutter'

commit_data = []

for commit in Repository(repo_path).traverse_commits():
    for file in commit.modified_files:
        commit_data.append( [
            commit.hash, 
            commit.author.name, 
            commit.committer_date,
            commit.merge,
            file.filename, 
            file.change_type, 
            file.added_lines,
            file.deleted_lines,
            file.nloc,
            file.complexity,
            file.token_count
        ] )

# %%
import pandas as pd

df = pd.DataFrame(commit_data)

# %%
df.columns = [
    'commit_hash', 
    'commit_author_name', 
    'commit_date', 
    'commit_merge', 
    'file_name', 
    'file_change_type', 
    'file_lines_added',
    'file_lines_deleted',
    'file_loc',
    'file_complexity',
    'file_token_count'
]

df
# Out:
#                                      commit_hash       commit_author_name  \
# 0       00882d626a478a3ce391b736234a768b762c853a               Adam Barth
# 1       00882d626a478a3ce391b736234a768b762c853a               Adam Barth
# 2       928524947acf841d84f92dd595618d8bddb1bc06                    Hixie
# 3       86cd8beee788acec7abb668b7ad7bb7cef62523c              Eric Seidel
# 4       3f008050a23d5f0506a00461353073eebbe8a2a7                    Hixie
# ...                                          ...                      ...
# 172751  b1881487beb238bb1f1153a3183b21b5d9b88bcd  engine-flutter-autoroll
# 172752  0cc7db54ce5cd07c7dd91a2b64e6a8ad85f45cf7                Dan Field
# 172753  0cc7db54ce5cd07c7dd91a2b64e6a8ad85f45cf7                Dan Field
# 172754  0cc7db54ce5cd07c7dd91a2b64e6a8ad85f45cf7                Dan Field
# 172755  058d27242222d86184f1d99011bc904e40fd060c  engine-flutter-autoroll
#
#                       commit_date  commit_merge                 file_name  \
# 0       2014-10-23 11:17:19-07:00         False                 README.md
# 1       2014-10-23 11:17:19-07:00         False                 radio.sky
# 2       2014-10-23 13:42:24-07:00         False                  home.sky
# 3       2014-10-23 14:56:44-07:00         False                  home.sky
# 4       2014-10-24 16:23:03-07:00         False                 radio.sky
# ...                           ...           ...                       ...
# 172751  2022-07-28 18:34:05+00:00         False            engine.version
# 172752  2022-07-28 18:36:04+00:00         False        platform_view.dart
# 172753  2022-07-28 18:36:04+00:00         False   platform_view_test.dart
# 172754  2022-07-28 18:36:04+00:00         False  fake_platform_views.dart
# 172755  2022-07-28 19:23:06+00:00         False            engine.version
#
#                file_change_type  file_lines_added  file_lines_deleted  \
# 0          ModificationType.ADD                 2                   0
# 1          ModificationType.ADD                78                   0
# 2          ModificationType.ADD                 7                   0
# 3       ModificationType.MODIFY                 2                   0
# 4       ModificationType.MODIFY                 1                   1
# ...                         ...               ...                 ...
# 172751  ModificationType.MODIFY                 1                   1
# 172752  ModificationType.MODIFY                 9                   0
# 172753  ModificationType.MODIFY                39                   0
# 172754  ModificationType.MODIFY                 1                   3
# 172755  ModificationType.MODIFY                 1                   1
#
#         file_loc  file_complexity  file_token_count
# 0            NaN              NaN               NaN
# 1            NaN              NaN               NaN
# 2            NaN              NaN               NaN
# 3            NaN              NaN               NaN
# 4            NaN              NaN               NaN
# ...          ...              ...               ...
# 172751       NaN              NaN               NaN
# 172752       NaN              NaN               NaN
# 172753       NaN              NaN               NaN
# 172754       NaN              NaN               NaN
# 172755       NaN              NaN               NaN
#
# [172756 rows x 11 columns]

# %%
df.to_csv('datasets/flutter.csv', index=False)
