# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  00882d626a478a3ce391b736234a768b762c853a         Adam Barth
# 1  00882d626a478a3ce391b736234a768b762c853a         Adam Barth
# 2  928524947acf841d84f92dd595618d8bddb1bc06              Hixie
# 3  86cd8beee788acec7abb668b7ad7bb7cef62523c        Eric Seidel
# 4  3f008050a23d5f0506a00461353073eebbe8a2a7              Hixie
#
#         commit_author_email            commit_datetime  commit_merge  \
# 0       abarth@chromium.org  2014-10-23 11:17:19-07:00         False
# 1       abarth@chromium.org  2014-10-23 11:17:19-07:00         False
# 2  github.com@spam.hixie.ch  2014-10-23 13:42:24-07:00         False
# 3      eseidel@chromium.org  2014-10-23 14:56:44-07:00         False
# 4  github.com@spam.hixie.ch  2014-10-24 16:23:03-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  file_name  \
# 0            NaN                  NaN                   NaN  README.md
# 1            NaN                  NaN                   NaN  radio.sky
# 2            NaN                  NaN                   NaN   home.sky
# 3            NaN                  NaN                   NaN   home.sky
# 4            NaN                  NaN                   NaN  radio.sky
#
#           file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0     ModificationType.ADD                 2                   0       NaN
# 1     ModificationType.ADD                78                   0       NaN
# 2     ModificationType.ADD                 7                   0       NaN
# 3  ModificationType.MODIFY                 2                   0       NaN
# 4  ModificationType.MODIFY                 1                   1       NaN
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                      commit_hash year_month  \
# 0       00882d626a478a3ce391b736234a768b762c853a    2014-10
# 1       00882d626a478a3ce391b736234a768b762c853a    2014-10
# 2       928524947acf841d84f92dd595618d8bddb1bc06    2014-10
# 3       86cd8beee788acec7abb668b7ad7bb7cef62523c    2014-10
# 4       3f008050a23d5f0506a00461353073eebbe8a2a7    2014-10
# ...                                          ...        ...
# 173450  f3d182f4b4e3c5e5cde322f5a14e49e9a50cc083    2022-08
# 173451  e7c867c916798d04cb83abb5b88d10c32fadedb3    2022-08
# 173452  e7c867c916798d04cb83abb5b88d10c32fadedb3    2022-08
# 173453  87f1684476a3e4a6f0433a3d894ae71c7dad2036    2022-08
# 173454  87f1684476a3e4a6f0433a3d894ae71c7dad2036    2022-08
#
#        commit_author_name                        commit_author_email  \
# 0              Adam Barth                        abarth@chromium.org
# 1              Adam Barth                        abarth@chromium.org
# 2                   Hixie                   github.com@spam.hixie.ch
# 3             Eric Seidel                       eseidel@chromium.org
# 4                   Hixie                   github.com@spam.hixie.ch
# ...                   ...                                        ...
# 173450         Dillon Nys    24740863+dnys1@users.noreply.github.com
# 173451       Pierre-Louis  6655696+guidezpl@users.noreply.github.com
# 173452       Pierre-Louis  6655696+guidezpl@users.noreply.github.com
# 173453      Casey Hillers                        chillers@google.com
# 173454      Casey Hillers                        chillers@google.com
#
#                   commit_datetime  commit_merge  dmm_unit_size  \
# 0       2014-10-23 11:17:19-07:00         False            NaN
# 1       2014-10-23 11:17:19-07:00         False            NaN
# 2       2014-10-23 13:42:24-07:00         False            NaN
# 3       2014-10-23 14:56:44-07:00         False            NaN
# 4       2014-10-24 16:23:03-07:00         False            NaN
# ...                           ...           ...            ...
# 173450  2022-08-09 05:51:06+00:00         False            NaN
# 173451  2022-08-09 05:59:14+00:00         False            NaN
# 173452  2022-08-09 05:59:14+00:00         False            NaN
# 173453  2022-08-08 23:00:11-07:00         False            NaN
# 173454  2022-08-08 23:00:11-07:00         False            NaN
#
#         dmm_unit_complexity  dmm_unit_interfacing               file_name  \
# 0                       NaN                   NaN               README.md
# 1                       NaN                   NaN               radio.sky
# 2                       NaN                   NaN                home.sky
# 3                       NaN                   NaN                home.sky
# 4                       NaN                   NaN               radio.sky
# ...                     ...                   ...                     ...
# 173450                  NaN                   NaN       pub_get_test.dart
# 173451                  NaN                   NaN               icon.dart
# 173452                  NaN                   NaN          icon_test.dart
# 173453                  NaN                   NaN       color_scheme.dart
# 173454                  NaN                   NaN  color_scheme_test.dart
#
#                file_change_type  file_lines_added  file_lines_deleted  \
# 0          ModificationType.ADD                 2                   0
# 1          ModificationType.ADD                78                   0
# 2          ModificationType.ADD                 7                   0
# 3       ModificationType.MODIFY                 2                   0
# 4       ModificationType.MODIFY                 1                   1
# ...                         ...               ...                 ...
# 173450  ModificationType.MODIFY                47                   0
# 173451  ModificationType.MODIFY                12                   4
# 173452  ModificationType.MODIFY                57                   1
# 173453  ModificationType.MODIFY                 1                  46
# 173454  ModificationType.MODIFY                 0                  18
#
#         file_loc  file_complexity  file_token_count
# 0            NaN              NaN               NaN
# 1            NaN              NaN               NaN
# 2            NaN              NaN               NaN
# 3            NaN              NaN               NaN
# 4            NaN              NaN               NaN
# ...          ...              ...               ...
# 173450       NaN              NaN               NaN
# 173451       NaN              NaN               NaN
# 173452       NaN              NaN               NaN
# 173453       NaN              NaN               NaN
# 173454       NaN              NaN               NaN
#
# [173455 rows x 16 columns]

# %%
df.drop ( df[df.year_month == '2022-08'].index, inplace = True )
df
# Out:
#                                      commit_hash year_month  \
# 0       00882d626a478a3ce391b736234a768b762c853a    2014-10
# 1       00882d626a478a3ce391b736234a768b762c853a    2014-10
# 2       928524947acf841d84f92dd595618d8bddb1bc06    2014-10
# 3       86cd8beee788acec7abb668b7ad7bb7cef62523c    2014-10
# 4       3f008050a23d5f0506a00461353073eebbe8a2a7    2014-10
# ...                                          ...        ...
# 173042  52d69c4d0f69c880dbb7371f0ff9c0e7d5dcbbf0    2022-07
# 173043  d1a4e1a295b4df49de86030581c5350fa9efb929    2022-07
# 173044  d1a4e1a295b4df49de86030581c5350fa9efb929    2022-07
# 173045  11a9939005e189ac3efe12d7f9032436618ca362    2022-07
# 173046  11a9939005e189ac3efe12d7f9032436618ca362    2022-07
#
#              commit_author_name               commit_author_email  \
# 0                    Adam Barth               abarth@chromium.org
# 1                    Adam Barth               abarth@chromium.org
# 2                         Hixie          github.com@spam.hixie.ch
# 3                   Eric Seidel              eseidel@chromium.org
# 4                         Hixie          github.com@spam.hixie.ch
# ...                         ...                               ...
# 173042  engine-flutter-autoroll  engine-flutter-autoroll@skia.org
# 173043  engine-flutter-autoroll  engine-flutter-autoroll@skia.org
# 173044  engine-flutter-autoroll  engine-flutter-autoroll@skia.org
# 173045  engine-flutter-autoroll  engine-flutter-autoroll@skia.org
# 173046  engine-flutter-autoroll  engine-flutter-autoroll@skia.org
#
#                   commit_datetime  commit_merge  dmm_unit_size  \
# 0       2014-10-23 11:17:19-07:00         False            NaN
# 1       2014-10-23 11:17:19-07:00         False            NaN
# 2       2014-10-23 13:42:24-07:00         False            NaN
# 3       2014-10-23 14:56:44-07:00         False            NaN
# 4       2014-10-24 16:23:03-07:00         False            NaN
# ...                           ...           ...            ...
# 173042  2022-07-31 09:51:06+00:00         False            NaN
# 173043  2022-07-31 12:51:06+00:00         False            NaN
# 173044  2022-07-31 12:51:06+00:00         False            NaN
# 173045  2022-07-31 17:52:06+00:00         False            NaN
# 173046  2022-07-31 17:52:06+00:00         False            NaN
#
#         dmm_unit_complexity  dmm_unit_interfacing              file_name  \
# 0                       NaN                   NaN              README.md
# 1                       NaN                   NaN              radio.sky
# 2                       NaN                   NaN               home.sky
# 3                       NaN                   NaN               home.sky
# 4                       NaN                   NaN              radio.sky
# ...                     ...                   ...                    ...
# 173042                  NaN                   NaN         engine.version
# 173043                  NaN                   NaN         engine.version
# 173044                  NaN                   NaN  fuchsia-linux.version
# 173045                  NaN                   NaN         engine.version
# 173046                  NaN                   NaN    fuchsia-mac.version
#
#                file_change_type  file_lines_added  file_lines_deleted  \
# 0          ModificationType.ADD                 2                   0
# 1          ModificationType.ADD                78                   0
# 2          ModificationType.ADD                 7                   0
# 3       ModificationType.MODIFY                 2                   0
# 4       ModificationType.MODIFY                 1                   1
# ...                         ...               ...                 ...
# 173042  ModificationType.MODIFY                 1                   1
# 173043  ModificationType.MODIFY                 1                   1
# 173044  ModificationType.MODIFY                 1                   1
# 173045  ModificationType.MODIFY                 1                   1
# 173046  ModificationType.MODIFY                 1                   1
#
#         file_loc  file_complexity  file_token_count
# 0            NaN              NaN               NaN
# 1            NaN              NaN               NaN
# 2            NaN              NaN               NaN
# 3            NaN              NaN               NaN
# 4            NaN              NaN               NaN
# ...          ...              ...               ...
# 173042       NaN              NaN               NaN
# 173043       NaN              NaN               NaN
# 173044       NaN              NaN               NaN
# 173045       NaN              NaN               NaN
# 173046       NaN              NaN               NaN
#
# [173047 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2014-10             9       5903         62      0.0             0.0
# 1     2014-11            32       2219        559      0.0             0.0
# 2     2014-12             5        193         85      0.0             0.0
# 3     2015-01            36       5510       5289      0.0             0.0
# 4     2015-02            33       4101        616      0.0             0.0
# ..        ...           ...        ...        ...      ...             ...
# 89    2022-03           429      54443      20812    483.0           110.0
# 90    2022-04           490      44561      31597    545.0           105.0
# 91    2022-05           573      45699      29223    466.0            99.0
# 92    2022-06           434      25626      10404   1542.0           295.0
# 93    2022-07           545      37304      16719    265.0            59.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0               0.0            NaN                  NaN                   NaN
# 1               0.0            NaN                  NaN                   NaN
# 2               0.0            NaN                  NaN                   NaN
# 3               0.0            NaN                  NaN                   NaN
# 4               0.0            NaN                  NaN                   NaN
# ..              ...            ...                  ...                   ...
# 89           3440.0       0.714286             0.714286              0.285714
# 90           4352.0       0.533470             0.190789              0.293750
# 91           3517.0       0.728723             0.757979              0.757979
# 92           9411.0       0.499072             0.835993              0.760297
# 93           1827.0       0.666667             0.666667              1.000000
#
# [94 rows x 10 columns]

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
