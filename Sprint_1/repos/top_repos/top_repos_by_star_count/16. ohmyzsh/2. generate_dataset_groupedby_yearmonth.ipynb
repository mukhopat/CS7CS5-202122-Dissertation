# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  e20401e04e057a39c228dbb99dda68ec7fa4235a      Robby Russell
# 1  5da20b9dddb1f7a9110675ded5df59c4c3ed1b83      Robby Russell
# 2  5da20b9dddb1f7a9110675ded5df59c4c3ed1b83      Robby Russell
# 3  5da20b9dddb1f7a9110675ded5df59c4c3ed1b83      Robby Russell
# 4  5da20b9dddb1f7a9110675ded5df59c4c3ed1b83      Robby Russell
#
#      commit_author_email            commit_datetime  commit_merge  \
# 0  robby@planetargon.com  2009-08-28 11:14:03-07:00         False
# 1  robby@planetargon.com  2009-08-28 11:14:17-07:00         False
# 2  robby@planetargon.com  2009-08-28 11:14:17-07:00         False
# 3  robby@planetargon.com  2009-08-28 11:14:17-07:00         False
# 4  robby@planetargon.com  2009-08-28 11:14:17-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing       file_name  \
# 0            NaN                  NaN                   NaN      .gitignore
# 1            NaN                  NaN                   NaN  README.textile
# 2            NaN                  NaN                   NaN     aliases.zsh
# 3            NaN                  NaN                   NaN      colors.zsh
# 4            NaN                  NaN                   NaN  completion.zsh
#
#        file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0  ModificationType.ADD                 3                   0       NaN
# 1  ModificationType.ADD                 8                   0       NaN
# 2  ModificationType.ADD                44                   0       NaN
# 3  ModificationType.ADD                 4                   0       NaN
# 4  ModificationType.ADD                27                   0       NaN
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                    commit_hash year_month commit_author_name  \
# 0     e20401e04e057a39c228dbb99dda68ec7fa4235a    2009-08      Robby Russell
# 1     5da20b9dddb1f7a9110675ded5df59c4c3ed1b83    2009-08      Robby Russell
# 2     5da20b9dddb1f7a9110675ded5df59c4c3ed1b83    2009-08      Robby Russell
# 3     5da20b9dddb1f7a9110675ded5df59c4c3ed1b83    2009-08      Robby Russell
# 4     5da20b9dddb1f7a9110675ded5df59c4c3ed1b83    2009-08      Robby Russell
# ...                                        ...        ...                ...
# 6874  4fcf52c2b1e086596d96b04f9c1ff3d742194857    2022-08      Marc Cornellà
# 6875  4fcf52c2b1e086596d96b04f9c1ff3d742194857    2022-08      Marc Cornellà
# 6876  0346cdf7f63bcddc704cc0551f260d31adb8fc9d    2022-08      Marc Cornellà
# 6877  0346cdf7f63bcddc704cc0551f260d31adb8fc9d    2022-08      Marc Cornellà
# 6878  97134d1eed19b72a9c4bf90a2effa847221608bf    2022-08         Ben Walton
#
#         commit_author_email            commit_datetime  commit_merge  \
# 0     robby@planetargon.com  2009-08-28 11:14:03-07:00         False
# 1     robby@planetargon.com  2009-08-28 11:14:17-07:00         False
# 2     robby@planetargon.com  2009-08-28 11:14:17-07:00         False
# 3     robby@planetargon.com  2009-08-28 11:14:17-07:00         False
# 4     robby@planetargon.com  2009-08-28 11:14:17-07:00         False
# ...                     ...                        ...           ...
# 6874    hello@mcornella.com  2022-08-01 20:54:45+02:00         False
# 6875    hello@mcornella.com  2022-08-01 20:54:45+02:00         False
# 6876    hello@mcornella.com  2022-08-02 19:27:54+02:00         False
# 6877    hello@mcornella.com  2022-08-02 19:27:54+02:00         False
# 6878     bdwalton@gmail.com  2022-08-02 19:28:44+02:00         False
#
#       dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0               NaN                  NaN                   NaN
# 1               NaN                  NaN                   NaN
# 2               NaN                  NaN                   NaN
# 3               NaN                  NaN                   NaN
# 4               NaN                  NaN                   NaN
# ...             ...                  ...                   ...
# 6874            NaN                  NaN                   NaN
# 6875            NaN                  NaN                   NaN
# 6876            NaN                  NaN                   NaN
# 6877            NaN                  NaN                   NaN
# 6878            NaN                  NaN                   NaN
#
#                      file_name         file_change_type  file_lines_added  \
# 0                   .gitignore     ModificationType.ADD                 3
# 1               README.textile     ModificationType.ADD                 8
# 2                  aliases.zsh     ModificationType.ADD                44
# 3                   colors.zsh     ModificationType.ADD                 4
# 4               completion.zsh     ModificationType.ADD                27
# ...                        ...                      ...               ...
# 6874        aliases.plugin.zsh  ModificationType.MODIFY                13
# 6875    shell-proxy.plugin.zsh  ModificationType.MODIFY                33
# 6876  PULL_REQUEST_TEMPLATE.md  ModificationType.MODIFY                 1
# 6877           CONTRIBUTING.md  ModificationType.MODIFY                21
# 6878                   cli.zsh  ModificationType.MODIFY                15
#
#       file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                      0       NaN              NaN               NaN
# 1                      0       NaN              NaN               NaN
# 2                      0       NaN              NaN               NaN
# 3                      0       NaN              NaN               NaN
# 4                      0       NaN              NaN               NaN
# ...                  ...       ...              ...               ...
# 6874                  10       NaN              NaN               NaN
# 6875                  26       NaN              NaN               NaN
# 6876                   0       NaN              NaN               NaN
# 6877                   0       NaN              NaN               NaN
# 6878                  15       NaN              NaN               NaN
#
# [6879 rows x 16 columns]

# %%
df.drop ( df[df.year_month == '2022-08'].index, inplace = True )
df
# Out:
#                                    commit_hash year_month commit_author_name  \
# 0     e20401e04e057a39c228dbb99dda68ec7fa4235a    2009-08      Robby Russell
# 1     5da20b9dddb1f7a9110675ded5df59c4c3ed1b83    2009-08      Robby Russell
# 2     5da20b9dddb1f7a9110675ded5df59c4c3ed1b83    2009-08      Robby Russell
# 3     5da20b9dddb1f7a9110675ded5df59c4c3ed1b83    2009-08      Robby Russell
# 4     5da20b9dddb1f7a9110675ded5df59c4c3ed1b83    2009-08      Robby Russell
# ...                                        ...        ...                ...
# 6869  bb6c14cdfd0b7d543d0d9c2e5f0c0a9409a82084    2022-07       Brian Wright
# 6870  af2daa7ab7dde3674f4861ef684773410b9cccd4    2022-07   Christopher Boyd
# 6871  af2daa7ab7dde3674f4861ef684773410b9cccd4    2022-07   Christopher Boyd
# 6872  8362ae285a5c227cb20387543483a3597fa31931    2022-07        Felix Stupp
# 6873  aa75eeea3348b906f2016be0e44335889e0faed1    2022-07    Anatoli Babenia
#
#                                 commit_author_email  \
# 0                             robby@planetargon.com
# 1                             robby@planetargon.com
# 2                             robby@planetargon.com
# 3                             robby@planetargon.com
# 4                             robby@planetargon.com
# ...                                             ...
# 6869  4408242+PennRobotics@users.noreply.github.com
# 6870        6323077+cpboyd@users.noreply.github.com
# 6871        6323077+cpboyd@users.noreply.github.com
# 6872                       me+github@banananet.work
# 6873                          anatoli@rainforce.org
#
#                 commit_datetime  commit_merge  dmm_unit_size  \
# 0     2009-08-28 11:14:03-07:00         False            NaN
# 1     2009-08-28 11:14:17-07:00         False            NaN
# 2     2009-08-28 11:14:17-07:00         False            NaN
# 3     2009-08-28 11:14:17-07:00         False            NaN
# 4     2009-08-28 11:14:17-07:00         False            NaN
# ...                         ...           ...            ...
# 6869  2022-07-26 11:46:10+02:00         False            NaN
# 6870  2022-07-27 18:06:28+02:00         False            NaN
# 6871  2022-07-27 18:06:28+02:00         False            NaN
# 6872  2022-07-27 18:07:53+02:00         False            NaN
# 6873  2022-07-29 13:05:34+02:00         False            NaN
#
#       dmm_unit_complexity  dmm_unit_interfacing                  file_name  \
# 0                     NaN                   NaN                 .gitignore
# 1                     NaN                   NaN             README.textile
# 2                     NaN                   NaN                aliases.zsh
# 3                     NaN                   NaN                 colors.zsh
# 4                     NaN                   NaN             completion.zsh
# ...                   ...                   ...                        ...
# 6869                  NaN                   NaN       check_for_upgrade.sh
# 6870                  NaN                   NaN                   _flutter
# 6871                  NaN                   NaN         flutter.plugin.zsh
# 6872                  NaN                   NaN  git-auto-fetch.plugin.zsh
# 6873                  NaN                   NaN                  README.md
#
#              file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0        ModificationType.ADD                 3                   0       NaN
# 1        ModificationType.ADD                 8                   0       NaN
# 2        ModificationType.ADD                44                   0       NaN
# 3        ModificationType.ADD                 4                   0       NaN
# 4        ModificationType.ADD                27                   0       NaN
# ...                       ...               ...                 ...       ...
# 6869  ModificationType.MODIFY                 1                   1       NaN
# 6870  ModificationType.DELETE                 0                  37       NaN
# 6871  ModificationType.MODIFY                15                   0       NaN
# 6872  ModificationType.MODIFY                 2                   1       NaN
# 6873  ModificationType.MODIFY                 2                   2       NaN
#
#       file_complexity  file_token_count
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 6869              NaN               NaN
# 6870              NaN               NaN
# 6871              NaN               NaN
# 6872              NaN               NaN
# 6873              NaN               NaN
#
# [6874 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#     year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0      2009-08            49        488         85      0.0             0.0
# 1      2009-09            40        331        102      0.0             0.0
# 2      2009-10            27        171         45      0.0             0.0
# 3      2009-11            29        212        151      0.0             0.0
# 4      2009-12            12         74         35      0.0             0.0
# ..         ...           ...        ...        ...      ...             ...
# 146    2022-03            33       1188       5084      0.0             0.0
# 147    2022-04            18        183        191    152.0            35.0
# 148    2022-05             6         44         41      0.0             0.0
# 149    2022-06             9         46         85      0.0             0.0
# 150    2022-07            12         77         70      0.0             0.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0                0.0            NaN                  NaN                   NaN
# 1                0.0            NaN                  NaN                   NaN
# 2                0.0            NaN                  NaN                   NaN
# 3                0.0            NaN                  NaN                   NaN
# 4                0.0            NaN                  NaN                   NaN
# ..               ...            ...                  ...                   ...
# 146              0.0            NaN                  NaN                   NaN
# 147           1365.0            1.0                  1.0                   1.0
# 148              0.0            NaN                  NaN                   NaN
# 149              0.0            NaN                  NaN                   NaN
# 150              0.0            NaN                  NaN                   NaN
#
# [151 rows x 10 columns]

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
