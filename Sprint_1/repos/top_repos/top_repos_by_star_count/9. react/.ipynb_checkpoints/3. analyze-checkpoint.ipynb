# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_groupedby_yearmonth.csv'
df = pd.read_csv (dataset_path)
df
# Out:
#     year_month  commit_count  additions  deletions   agg_loc  agg_complexity  \
# 0      2013-05            53      43952        523   25918.0         10225.0
# 1      2013-06           213      11390      28035   61790.0         11686.0
# 2      2013-07           205      58995      55867   45952.0         13751.0
# 3      2013-08            53       2784       2284    9986.0          1908.0
# 4      2013-09            75       5394       1966   16589.0          2762.0
# ..         ...           ...        ...        ...       ...             ...
# 106    2022-03            78      11142      15013  299747.0         19363.0
# 107    2022-04            82      14481       6267  374268.0         13718.0
# 108    2022-05            51       6067       2013  130354.0          7434.0
# 109    2022-06            66       9384       3963  344830.0         15783.0
# 110    2022-07            42       7953       6772  255431.0          7296.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0           251334.0       0.582596             0.742723              0.821696
# 1           358919.0       0.515204             0.578879              0.582611
# 2           349160.0       0.502664             0.555284              0.588020
# 3            57123.0       0.606317             0.576510              0.640145
# 4            93146.0       0.545374             0.734521              0.787510
# ..               ...            ...                  ...                   ...
# 106        1255587.0       0.528100             0.765604              0.852136
# 107        1439473.0       0.532105             0.631447              0.598118
# 108         526962.0       0.493065             0.887337              0.936656
# 109        1343876.0       0.522034             0.636599              0.676099
# 110         980495.0       0.509717             0.723127              0.640245
#
# [111 rows x 10 columns]

# %%
df['dmm_unit_size'] = df['dmm_unit_size'].fillna(0)
df['dmm_unit_complexity'] = df['dmm_unit_complexity'].fillna(0)
df['dmm_unit_interfacing'] = df['dmm_unit_interfacing'].fillna(0)

# %%
start_date = df.year_month[0][5:7] + '-01-' + df.year_month[0][0:4]
end_date = df.year_month[len(df.year_month) - 1][5:7] + '-01-' + df.year_month[len(df.year_month) - 1][0:4]
dfperiod = pd.period_range(start_date, end_date, freq='M')

def new_zero_row ( year_month ):
    
    new_row = {
        'year_month': year_month,
        'commit_count': 0,
        'additions': 0,
        'deletions': 0,
        'agg_loc': 0,
        'agg_complexity': 0,
        'agg_token_count': 0,
        'dmm_unit_size': 0,
        'dmm_unit_complexity': 0,
        'dmm_unit_interfacing': 0
    }
    
    return new_row

for year_month in dfperiod:
    if df [ ( df['year_month'] == str(year_month) ) ].shape[0] == 0:
        df = df.append ( new_zero_row(year_month), ignore_index = True )

df.shape
# Out:
# (111, 10)

# %%
df['year_month'] = df['year_month'].astype(str)
df = df.sort_values ( by=['year_month'] )
df.reset_index(drop=True, inplace=True)
df
# Out:
#     year_month  commit_count  additions  deletions   agg_loc  agg_complexity  \
# 0      2013-05            53      43952        523   25918.0         10225.0
# 1      2013-06           213      11390      28035   61790.0         11686.0
# 2      2013-07           205      58995      55867   45952.0         13751.0
# 3      2013-08            53       2784       2284    9986.0          1908.0
# 4      2013-09            75       5394       1966   16589.0          2762.0
# ..         ...           ...        ...        ...       ...             ...
# 106    2022-03            78      11142      15013  299747.0         19363.0
# 107    2022-04            82      14481       6267  374268.0         13718.0
# 108    2022-05            51       6067       2013  130354.0          7434.0
# 109    2022-06            66       9384       3963  344830.0         15783.0
# 110    2022-07            42       7953       6772  255431.0          7296.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0           251334.0       0.582596             0.742723              0.821696
# 1           358919.0       0.515204             0.578879              0.582611
# 2           349160.0       0.502664             0.555284              0.588020
# 3            57123.0       0.606317             0.576510              0.640145
# 4            93146.0       0.545374             0.734521              0.787510
# ..               ...            ...                  ...                   ...
# 106        1255587.0       0.528100             0.765604              0.852136
# 107        1439473.0       0.532105             0.631447              0.598118
# 108         526962.0       0.493065             0.887337              0.936656
# 109        1343876.0       0.522034             0.636599              0.676099
# 110         980495.0       0.509717             0.723127              0.640245
#
# [111 rows x 10 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_final.csv', index = False )

# %% [markdown]
# # Analysis

# %%
for idx in range(1, 10):
    ma_prefix = 'ma_'
    df[ma_prefix + df.columns[idx]] = df[df.columns[idx]].rolling ( window = 5 ).mean()
df
# Out:
#     year_month  commit_count  additions  deletions   agg_loc  agg_complexity  \
# 0      2013-05            53      43952        523   25918.0         10225.0
# 1      2013-06           213      11390      28035   61790.0         11686.0
# 2      2013-07           205      58995      55867   45952.0         13751.0
# 3      2013-08            53       2784       2284    9986.0          1908.0
# 4      2013-09            75       5394       1966   16589.0          2762.0
# ..         ...           ...        ...        ...       ...             ...
# 106    2022-03            78      11142      15013  299747.0         19363.0
# 107    2022-04            82      14481       6267  374268.0         13718.0
# 108    2022-05            51       6067       2013  130354.0          7434.0
# 109    2022-06            66       9384       3963  344830.0         15783.0
# 110    2022-07            42       7953       6772  255431.0          7296.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  \
# 0           251334.0       0.582596             0.742723
# 1           358919.0       0.515204             0.578879
# 2           349160.0       0.502664             0.555284
# 3            57123.0       0.606317             0.576510
# 4            93146.0       0.545374             0.734521
# ..               ...            ...                  ...
# 106        1255587.0       0.528100             0.765604
# 107        1439473.0       0.532105             0.631447
# 108         526962.0       0.493065             0.887337
# 109        1343876.0       0.522034             0.636599
# 110         980495.0       0.509717             0.723127
#
#      dmm_unit_interfacing  ma_commit_count  ma_additions  ma_deletions  \
# 0                0.821696              NaN           NaN           NaN
# 1                0.582611              NaN           NaN           NaN
# 2                0.588020              NaN           NaN           NaN
# 3                0.640145              NaN           NaN           NaN
# 4                0.787510            119.8       24503.0       17735.0
# ..                    ...              ...           ...           ...
# 106              0.852136             52.8        8885.2        6133.2
# 107              0.598118             57.2       10663.0        6573.2
# 108              0.936656             59.4       10960.0        6793.0
# 109              0.676099             66.8        9489.4        5924.8
# 110              0.640245             63.8        9805.4        6805.6
#
#      ma_agg_loc  ma_agg_complexity  ma_agg_token_count  ma_dmm_unit_size  \
# 0           NaN                NaN                 NaN               NaN
# 1           NaN                NaN                 NaN               NaN
# 2           NaN                NaN                 NaN               NaN
# 3           NaN                NaN                 NaN               NaN
# 4       32047.0             8066.4            221936.4          0.550431
# ..          ...                ...                 ...               ...
# 106    197216.6            11621.4            810433.0          0.557500
# 107    238452.6            12133.4            959159.8          0.556641
# 108    245522.6            12377.4            984477.6          0.529837
# 109    292493.0            14563.4           1166239.2          0.525368
# 110    280926.0            12718.8           1109278.6          0.517004
#
#      ma_dmm_unit_complexity  ma_dmm_unit_interfacing
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                  0.637583                 0.683996
# ..                      ...                      ...
# 106                0.746342                 0.724605
# 107                0.742838                 0.721530
# 108                0.754862                 0.774486
# 109                0.717573                 0.722940
# 110                0.728823                 0.740651
#
# [111 rows x 19 columns]

# %%
from plot_line_lib import plot_line

for idx in range ( 1, 7 ):
    
    images_path = f'images/'
    plot_line ( df.columns[idx], idx, df, images_path, repo_name, major_locator = True)

# %%
from analysis_lib import year_pre_covid_ym, pre_covid_ym, covid_ym, year_post_covid_ym

df = df.set_index(df['year_month'])

df1 = df [ year_pre_covid_ym : pre_covid_ym ]
df2 = df [ covid_ym : year_post_covid_ym ]
df1 = df1.reset_index ( drop = True )
df2 = df2.reset_index ( drop = True )

df1.shape, df2.shape
# Out:
# ((12, 19), (12, 19))

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( df1, df2 )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  158  vs  84  ->  Down (46.8%)
# additions :  30098  vs  20307  ->  Down (32.5%)
# deletions :  20761  vs  11064  ->  Down (46.7%)
# agg loc :  311740  vs  340932  ->  Up (9.4%)
# agg complexity :  25083  vs  22543  ->  Down (10.1%)
# agg token count :  1398945  vs  1442752  ->  Up (3.1%)

# %% [markdown]
# # Distribution

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_equilibrium_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_equilibrium_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 33.3
# additions = 25.0
# deletions = 16.7
# agg_loc = 41.7
# agg_complexity = 41.7
# agg_token_count = 41.7
#
# Post-pandemic equilibrium percentages:
# commit_count = 33.3
# additions = 25.0
# deletions = 33.3
# agg_loc = 33.3
# agg_complexity = 33.3
# agg_token_count = 33.3

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_pareto_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_pareto_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 66.7
# additions = 58.3
# deletions = 58.3
# agg_loc = 66.7
# agg_complexity = 66.7
# agg_token_count = 66.7
#
# Post-pandemic pareto percentages:
# commit_count = 66.7
# additions = 58.3
# deletions = 58.3
# agg_loc = 66.7
# agg_complexity = 66.7
# agg_token_count = 66.7
