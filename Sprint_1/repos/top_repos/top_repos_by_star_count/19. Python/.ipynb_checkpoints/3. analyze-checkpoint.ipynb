# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_groupedby_yearmonth.csv'
df = pd.read_csv (dataset_path)
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2016-07            23        845        284    803.0           186.0
# 1     2016-08            42      54049        476   1727.0           371.0
# 2     2016-09            14     236406         53   1046.0           205.0
# 3     2016-10            14        266         32    504.0           109.0
# 4     2016-11             5        137         21    153.0            47.0
# ..        ...           ...        ...        ...      ...             ...
# 66    2022-03             2          2          2      0.0             0.0
# 67    2022-04             4        347         67    755.0            79.0
# 68    2022-05            21       1275        252   3757.0           509.0
# 69    2022-06             7       1396        887    570.0            88.0
# 70    2022-07            18        812        224  10375.0          1664.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0            4815.0       0.656250             0.843750              0.887784
# 1            9842.0       0.497393             0.444129              0.703988
# 2            6446.0       0.665110             0.867870              0.881715
# 3            2807.0       0.923077             0.769231              0.760725
# 4             965.0       1.000000             0.666667              1.000000
# ..              ...            ...                  ...                   ...
# 66              0.0            NaN                  NaN                   NaN
# 67           2113.0       0.070175             0.957895              0.833333
# 68          14436.0       0.500589             0.685755              0.815789
# 69           2422.0       0.194859             0.427192              0.650912
# 70          45629.0       0.562689             0.422222              0.552161
#
# [71 rows x 10 columns]

# %%
df['dmm_unit_size'] = df['dmm_unit_size'].fillna(0)
df['dmm_unit_complexity'] = df['dmm_unit_complexity'].fillna(0)
df['dmm_unit_interfacing'] = df['dmm_unit_interfacing'].fillna(0)

# %%
start_date = df.year_month[0][5:7] + '-01-' + df.year_month[0][0:4]
end_date = df.year_month[len(df.year_month) - 1][5:7] + '-01-' + df.year_month[len(df.year_month) - 1][0:4]
dfperiod = pd.period_range(start_date, end_date, freq='M')

def new_zero_row ( year_month ):
    
    new_row = {
        'year_month': year_month,
        'commit_count': 0,
        'additions': 0,
        'deletions': 0,
        'agg_loc': 0,
        'agg_complexity': 0,
        'agg_token_count': 0,
        'dmm_unit_size': 0,
        'dmm_unit_complexity': 0,
        'dmm_unit_interfacing': 0
    }
    
    return new_row

for year_month in dfperiod:
    if df [ ( df['year_month'] == str(year_month) ) ].shape[0] == 0:
        df = df.append ( new_zero_row(year_month), ignore_index = True )

df.shape
# Out:
# (73, 10)

# %%
df['year_month'] = df['year_month'].astype(str)
df = df.sort_values ( by=['year_month'] )
df.reset_index(drop=True, inplace=True)
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2016-07            23        845        284    803.0           186.0
# 1     2016-08            42      54049        476   1727.0           371.0
# 2     2016-09            14     236406         53   1046.0           205.0
# 3     2016-10            14        266         32    504.0           109.0
# 4     2016-11             5        137         21    153.0            47.0
# ..        ...           ...        ...        ...      ...             ...
# 68    2022-03             2          2          2      0.0             0.0
# 69    2022-04             4        347         67    755.0            79.0
# 70    2022-05            21       1275        252   3757.0           509.0
# 71    2022-06             7       1396        887    570.0            88.0
# 72    2022-07            18        812        224  10375.0          1664.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0            4815.0       0.656250             0.843750              0.887784
# 1            9842.0       0.497393             0.444129              0.703988
# 2            6446.0       0.665110             0.867870              0.881715
# 3            2807.0       0.923077             0.769231              0.760725
# 4             965.0       1.000000             0.666667              1.000000
# ..              ...            ...                  ...                   ...
# 68              0.0       0.000000             0.000000              0.000000
# 69           2113.0       0.070175             0.957895              0.833333
# 70          14436.0       0.500589             0.685755              0.815789
# 71           2422.0       0.194859             0.427192              0.650912
# 72          45629.0       0.562689             0.422222              0.552161
#
# [73 rows x 10 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_final.csv', index = False )

# %% [markdown]
# # Analysis

# %%
for idx in range(1, 10):
    ma_prefix = 'ma_'
    df[ma_prefix + df.columns[idx]] = df[df.columns[idx]].rolling ( window = 5 ).mean()
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2016-07            23        845        284    803.0           186.0
# 1     2016-08            42      54049        476   1727.0           371.0
# 2     2016-09            14     236406         53   1046.0           205.0
# 3     2016-10            14        266         32    504.0           109.0
# 4     2016-11             5        137         21    153.0            47.0
# ..        ...           ...        ...        ...      ...             ...
# 68    2022-03             2          2          2      0.0             0.0
# 69    2022-04             4        347         67    755.0            79.0
# 70    2022-05            21       1275        252   3757.0           509.0
# 71    2022-06             7       1396        887    570.0            88.0
# 72    2022-07            18        812        224  10375.0          1664.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0            4815.0       0.656250             0.843750              0.887784
# 1            9842.0       0.497393             0.444129              0.703988
# 2            6446.0       0.665110             0.867870              0.881715
# 3            2807.0       0.923077             0.769231              0.760725
# 4             965.0       1.000000             0.666667              1.000000
# ..              ...            ...                  ...                   ...
# 68              0.0       0.000000             0.000000              0.000000
# 69           2113.0       0.070175             0.957895              0.833333
# 70          14436.0       0.500589             0.685755              0.815789
# 71           2422.0       0.194859             0.427192              0.650912
# 72          45629.0       0.562689             0.422222              0.552161
#
#     ma_commit_count  ma_additions  ma_deletions  ma_agg_loc  \
# 0               NaN           NaN           NaN         NaN
# 1               NaN           NaN           NaN         NaN
# 2               NaN           NaN           NaN         NaN
# 3               NaN           NaN           NaN         NaN
# 4              19.6       58340.6         173.2       846.6
# ..              ...           ...           ...         ...
# 68             13.8        7479.8         192.2      3024.4
# 69              3.6         205.8          72.2      1871.8
# 70              7.4         455.2         117.8      2560.4
# 71              8.0         684.6         249.0      1116.8
# 72             10.4         766.4         286.4      3091.4
#
#     ma_agg_complexity  ma_agg_token_count  ma_dmm_unit_size  \
# 0                 NaN                 NaN               NaN
# 1                 NaN                 NaN               NaN
# 2                 NaN                 NaN               NaN
# 3                 NaN                 NaN               NaN
# 4               183.6              4975.0          0.748366
# ..                ...                 ...               ...
# 68              425.6             12217.8          0.300036
# 69              247.4              7356.2          0.208395
# 70              336.2              9974.4          0.208512
# 71              143.0              4190.2          0.160101
# 72              468.0             12920.0          0.265662
#
#     ma_dmm_unit_complexity  ma_dmm_unit_interfacing
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                      NaN                      NaN
# 3                      NaN                      NaN
# 4                 0.718329                 0.846842
# ..                     ...                      ...
# 68                0.294057                 0.485514
# 69                0.351579                 0.514950
# 70                0.488730                 0.503108
# 71                0.574168                 0.630852
# 72                0.498613                 0.570439
#
# [73 rows x 19 columns]

# %%
from plot_line_lib import plot_line

for idx in range ( 1, 7 ):
    
    images_path = f'images/'
    plot_line ( df.columns[idx], idx, df, images_path, repo_name, major_locator = True )

# %%
from analysis_lib import year_pre_covid_ym, pre_covid_ym, covid_ym, year_post_covid_ym

df = df.set_index(df['year_month'])

df1 = df [ year_pre_covid_ym : pre_covid_ym ]
df2 = df [ covid_ym : year_post_covid_ym ]
df1 = df1.reset_index ( drop = True )
df2 = df2.reset_index ( drop = True )

df1.shape, df2.shape
# Out:
# ((12, 19), (12, 19))

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( df1, df2 )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  42  vs  52  ->  Up (23.8%)
# additions :  4114  vs  3690  ->  Down (10.3%)
# deletions :  2319  vs  970  ->  Down (58.2%)
# agg loc :  6933  vs  8480  ->  Up (22.3%)
# agg complexity :  1547  vs  1434  ->  Down (7.3%)
# agg token count :  41775  vs  39124  ->  Down (6.3%)

# %% [markdown]
# # Distribution

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_equilibrium_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_equilibrium_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 25.0
# additions = 16.7
# deletions = 16.7
# agg_loc = 25.0
# agg_complexity = 25.0
# agg_token_count = 25.0
#
# Post-pandemic equilibrium percentages:
# commit_count = 33.3
# additions = 25.0
# deletions = 16.7
# agg_loc = 25.0
# agg_complexity = 25.0
# agg_token_count = 33.3

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_pareto_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_pareto_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 58.3
# additions = 50.0
# deletions = 25.0
# agg_loc = 41.7
# agg_complexity = 41.7
# agg_token_count = 41.7
#
# Post-pandemic pareto percentages:
# commit_count = 58.3
# additions = 50.0
# deletions = 41.7
# agg_loc = 58.3
# agg_complexity = 50.0
# agg_token_count = 50.0
