# %%
from pydriller import Repository
from time import time
from datetime import timedelta
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
repo_path = f'./clone/{repo_name}'

commit_data = []

start_time = time()

for commit in Repository(repo_path).traverse_commits():
    for file in commit.modified_files:
        commit_data.append( [
            commit.hash, 
            commit.author.name, 
            commit.author.email,
            commit.committer_date,
            commit.merge,
            commit.dmm_unit_size,
            commit.dmm_unit_complexity,
            commit.dmm_unit_interfacing,
            file.filename, 
            file.change_type, 
            file.added_lines, 
            file.deleted_lines,
            file.nloc,
            file.complexity,
            file.token_count
        ] )
        
print( f'Execution time = { str ( timedelta ( seconds = time() - start_time ) ) }' )
# Out:
# Execution time = 0:02:40.976227

# %%
import pandas as pd

df = pd.DataFrame(commit_data)

df.columns = [
    'commit_hash', 
    'commit_author_name', 
    'commit_author_email',
    'commit_datetime', 
    'commit_merge',
    'dmm_unit_size',
    'dmm_unit_complexity',
    'dmm_unit_interfacing',
    'file_name', 
    'file_change_type', 
    'file_lines_added',
    'file_lines_deleted',
    'file_loc',
    'file_complexity',
    'file_token_count'
]

df
# Out:
#                                    commit_hash commit_author_name  \
# 0     d288f8a184ca48c918cb8e4f133d5b539a90a768         Todd Motto
# 1     bed017596cc7d54cc16f9d7737251dd75ba766c7         Todd Motto
# 2     d1ae7865fd482a55f3a7b9e467ff0d49304c3634         Todd Motto
# 3     72285d1e11ac8349546bcd1adfe02cc69e7370cb    Ryan Christiani
# 4     fe082c9a58a5ce0154ec08d55a48d8aef7c3bf65       Pete Redmond
# ...                                        ...                ...
# 3303  ab16db658dcc5a443292d2ce0325d98ad0538226           APILayer
# 3304  53b16cfd0c322c573998ac416073b0c1a2857b60           APILayer
# 3305  831ff0378fb0ba5a779e6caaa89b73766c59449e           APILayer
# 3306  b269b3e1e2c0322ed36a3859233a57f6cd325ae6           APILayer
# 3307  055f7b0580490a89e8f7e6e61690e5c52f0e8181           APILayer
#
#                                    commit_author_email  \
# 0                                   todd@toddmotto.com
# 1                                   todd@toddmotto.com
# 2                                   todd@toddmotto.com
# 3                              ryan@ryanchristiani.com
# 4                                   redmondp@gmail.com
# ...                                                ...
# 3303  75280960+apilayer-admin@users.noreply.github.com
# 3304  75280960+apilayer-admin@users.noreply.github.com
# 3305  75280960+apilayer-admin@users.noreply.github.com
# 3306  75280960+apilayer-admin@users.noreply.github.com
# 3307  75280960+apilayer-admin@users.noreply.github.com
#
#                 commit_datetime  commit_merge  dmm_unit_size  \
# 0     2016-03-20 23:49:43+00:00         False            NaN
# 1     2016-03-21 00:05:16+00:00         False            NaN
# 2     2016-03-21 00:07:44+00:00         False            NaN
# 3     2016-03-20 21:01:13-04:00         False            NaN
# 4     2016-03-21 01:08:13+00:00         False            NaN
# ...                         ...           ...            ...
# 3303  2022-03-16 16:32:07+08:00         False            NaN
# 3304  2022-03-16 16:35:59+08:00         False            NaN
# 3305  2022-03-16 16:41:44+08:00         False            NaN
# 3306  2022-05-18 21:48:17+08:00         False            NaN
# 3307  2022-07-19 21:39:16+08:00         False            NaN
#
#       dmm_unit_complexity  dmm_unit_interfacing  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 3303                  NaN                   NaN
# 3304                  NaN                   NaN
# 3305                  NaN                   NaN
# 3306                  NaN                   NaN
# 3307                  NaN                   NaN
#
#                                             file_name  \
# 0                                           README.md
# 1                                           README.md
# 2                                           README.md
# 3                                           README.md
# 4                                           README.md
# ...                                               ...
# 3303                                        README.md
# 3304  cs1586-APILayerLogoUpdate2022-LJ_v2-HighRes.png
# 3305                                        README.md
# 3306                                        README.md
# 3307                                        README.md
#
#              file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0        ModificationType.ADD                 2                   0       NaN
# 1     ModificationType.MODIFY                13                   2       NaN
# 2     ModificationType.MODIFY                 1                   1       NaN
# 3     ModificationType.MODIFY                52                   9       NaN
# 4     ModificationType.MODIFY                 3                   1       NaN
# ...                       ...               ...                 ...       ...
# 3303  ModificationType.MODIFY                 1                   0       NaN
# 3304     ModificationType.ADD                 0                   0       NaN
# 3305  ModificationType.MODIFY                 5                  12       NaN
# 3306  ModificationType.MODIFY                 1                   0       NaN
# 3307  ModificationType.MODIFY                 4                   0       NaN
#
#       file_complexity  file_token_count
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 3303              NaN               NaN
# 3304              NaN               NaN
# 3305              NaN               NaN
# 3306              NaN               NaN
# 3307              NaN               NaN
#
# [3308 rows x 15 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_modfiles.csv', index = False )
