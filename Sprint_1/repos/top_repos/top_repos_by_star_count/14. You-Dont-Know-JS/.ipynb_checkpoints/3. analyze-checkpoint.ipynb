# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_groupedby_yearmonth.csv'
df = pd.read_csv (dataset_path)
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2013-11            21       3028         51      0.0             0.0
# 1     2013-12            13        660         45      0.0             0.0
# 2     2014-01            14       3299         91   3079.0          1686.0
# 3     2014-02            29       1465        481      0.0             0.0
# 4     2014-03            50       2102        520      0.0             0.0
# ..        ...           ...        ...        ...      ...             ...
# 65    2022-01            11       1620        338      0.0             0.0
# 66    2022-02             4        155         15      0.0             0.0
# 67    2022-03             1          6          6      0.0             0.0
# 68    2022-04             2         14         13      0.0             0.0
# 69    2022-07            39       4654        884      0.0             0.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0               0.0            NaN                  NaN                   NaN
# 1               0.0            NaN                  NaN                   NaN
# 2           39555.0       0.665134               0.7773              0.944937
# 3               0.0            NaN                  NaN                   NaN
# 4               0.0            NaN                  NaN                   NaN
# ..              ...            ...                  ...                   ...
# 65              0.0            NaN                  NaN                   NaN
# 66              0.0            NaN                  NaN                   NaN
# 67              0.0            NaN                  NaN                   NaN
# 68              0.0            NaN                  NaN                   NaN
# 69              0.0            NaN                  NaN                   NaN
#
# [70 rows x 10 columns]

# %%
df['dmm_unit_size'] = df['dmm_unit_size'].fillna(0)
df['dmm_unit_complexity'] = df['dmm_unit_complexity'].fillna(0)
df['dmm_unit_interfacing'] = df['dmm_unit_interfacing'].fillna(0)

# %%
start_date = df.year_month[0][5:7] + '-01-' + df.year_month[0][0:4]
end_date = df.year_month[len(df.year_month) - 1][5:7] + '-01-' + df.year_month[len(df.year_month) - 1][0:4]
dfperiod = pd.period_range(start_date, end_date, freq='M')

def new_zero_row ( year_month ):
    
    new_row = {
        'year_month': year_month,
        'commit_count': 0,
        'additions': 0,
        'deletions': 0,
        'agg_loc': 0,
        'agg_complexity': 0,
        'agg_token_count': 0,
        'dmm_unit_size': 0,
        'dmm_unit_complexity': 0,
        'dmm_unit_interfacing': 0
    }
    
    return new_row

for year_month in dfperiod:
    if df [ ( df['year_month'] == str(year_month) ) ].shape[0] == 0:
        df = df.append ( new_zero_row(year_month), ignore_index = True )

df.shape
# Out:
# (105, 10)

# %%
df['year_month'] = df['year_month'].astype(str)
df = df.sort_values ( by=['year_month'] )
df.reset_index(drop=True, inplace=True)
df
# Out:
#     year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0      2013-11            21       3028         51      0.0             0.0
# 1      2013-12            13        660         45      0.0             0.0
# 2      2014-01            14       3299         91   3079.0          1686.0
# 3      2014-02            29       1465        481      0.0             0.0
# 4      2014-03            50       2102        520      0.0             0.0
# ..         ...           ...        ...        ...      ...             ...
# 100    2022-03             1          6          6      0.0             0.0
# 101    2022-04             2         14         13      0.0             0.0
# 102    2022-05             0          0          0      0.0             0.0
# 103    2022-06             0          0          0      0.0             0.0
# 104    2022-07            39       4654        884      0.0             0.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0                0.0       0.000000               0.0000              0.000000
# 1                0.0       0.000000               0.0000              0.000000
# 2            39555.0       0.665134               0.7773              0.944937
# 3                0.0       0.000000               0.0000              0.000000
# 4                0.0       0.000000               0.0000              0.000000
# ..               ...            ...                  ...                   ...
# 100              0.0       0.000000               0.0000              0.000000
# 101              0.0       0.000000               0.0000              0.000000
# 102              0.0       0.000000               0.0000              0.000000
# 103              0.0       0.000000               0.0000              0.000000
# 104              0.0       0.000000               0.0000              0.000000
#
# [105 rows x 10 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_final.csv', index = False )

# %% [markdown]
# # Analysis

# %%
for idx in range(1, 10):
    ma_prefix = 'ma_'
    df[ma_prefix + df.columns[idx]] = df[df.columns[idx]].rolling ( window = 3 ).mean()
df
# Out:
#     year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0      2013-11            21       3028         51      0.0             0.0
# 1      2013-12            13        660         45      0.0             0.0
# 2      2014-01            14       3299         91   3079.0          1686.0
# 3      2014-02            29       1465        481      0.0             0.0
# 4      2014-03            50       2102        520      0.0             0.0
# ..         ...           ...        ...        ...      ...             ...
# 100    2022-03             1          6          6      0.0             0.0
# 101    2022-04             2         14         13      0.0             0.0
# 102    2022-05             0          0          0      0.0             0.0
# 103    2022-06             0          0          0      0.0             0.0
# 104    2022-07            39       4654        884      0.0             0.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  \
# 0                0.0       0.000000               0.0000
# 1                0.0       0.000000               0.0000
# 2            39555.0       0.665134               0.7773
# 3                0.0       0.000000               0.0000
# 4                0.0       0.000000               0.0000
# ..               ...            ...                  ...
# 100              0.0       0.000000               0.0000
# 101              0.0       0.000000               0.0000
# 102              0.0       0.000000               0.0000
# 103              0.0       0.000000               0.0000
# 104              0.0       0.000000               0.0000
#
#      dmm_unit_interfacing  ma_commit_count  ma_additions  ma_deletions  \
# 0                0.000000              NaN           NaN           NaN
# 1                0.000000              NaN           NaN           NaN
# 2                0.944937        16.000000   2329.000000     62.333333
# 3                0.000000        18.666667   1808.000000    205.666667
# 4                0.000000        31.000000   2288.666667    364.000000
# ..                    ...              ...           ...           ...
# 100              0.000000         5.333333    593.666667    119.666667
# 101              0.000000         2.333333     58.333333     11.333333
# 102              0.000000         1.000000      6.666667      6.333333
# 103              0.000000         0.666667      4.666667      4.333333
# 104              0.000000        13.000000   1551.333333    294.666667
#
#       ma_agg_loc  ma_agg_complexity  ma_agg_token_count  ma_dmm_unit_size  \
# 0            NaN                NaN                 NaN               NaN
# 1            NaN                NaN                 NaN               NaN
# 2    1026.333333              562.0             13185.0          0.221711
# 3    1026.333333              562.0             13185.0          0.221711
# 4    1026.333333              562.0             13185.0          0.221711
# ..           ...                ...                 ...               ...
# 100     0.000000                0.0                 0.0          0.000000
# 101     0.000000                0.0                 0.0          0.000000
# 102     0.000000                0.0                 0.0          0.000000
# 103     0.000000                0.0                 0.0          0.000000
# 104     0.000000                0.0                 0.0          0.000000
#
#      ma_dmm_unit_complexity  ma_dmm_unit_interfacing
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                    0.2591                 0.314979
# 3                    0.2591                 0.314979
# 4                    0.2591                 0.314979
# ..                      ...                      ...
# 100                  0.0000                 0.000000
# 101                  0.0000                 0.000000
# 102                  0.0000                 0.000000
# 103                  0.0000                 0.000000
# 104                  0.0000                 0.000000
#
# [105 rows x 19 columns]

# %%
from plot_line_lib import plot_line

for idx in range ( 1, 7 ):
    
    images_path = f'images/'
    plot_line ( df.columns[idx], idx, df, images_path, repo_name, major_locator = True )

# %%
from analysis_lib import year_pre_covid_ym, pre_covid_ym, covid_ym, year_post_covid_ym

df = df.set_index(df['year_month'])

df1 = df [ year_pre_covid_ym : pre_covid_ym ]
df2 = df [ covid_ym : year_post_covid_ym ]
df1 = df1.reset_index ( drop = True )
df2 = df2.reset_index ( drop = True )

df1.shape, df2.shape
# Out:
# ((12, 19), (12, 19))

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( df1, df2 )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  17  vs  5  ->  Down (70.6%)
# additions :  1362  vs  116  ->  Down (91.5%)
# deletions :  934  vs  2382  ->  Up (155.0%)
# agg loc :  0  vs  0  ->  No change
# agg complexity :  0  vs  0  ->  No change
# agg token count :  0  vs  0  ->  No change

# %% [markdown]
# # Distribution

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_equilibrium_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_equilibrium_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 16.7
# additions = 16.7
# deletions = 25.0
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
#
# Post-pandemic equilibrium percentages:
# commit_count = 8.3
# additions = 8.3
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_pareto_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_pareto_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 33.3
# additions = 33.3
# deletions = 33.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
#
# Post-pandemic pareto percentages:
# commit_count = 8.3
# additions = 8.3
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
