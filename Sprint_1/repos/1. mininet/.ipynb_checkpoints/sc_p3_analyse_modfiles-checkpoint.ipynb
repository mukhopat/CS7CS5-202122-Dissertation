# %%
import pandas as pd

dataset_path = 'datasets/sc_p3_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  ec3ff00271eeaad747f2deaff616d80620817084       Ellen Whelan
# 1  515351875bb17b7c8aaae9946be21ffcbdec6c75       Ellen Whelan
# 2  8a842e027e2c6e2742697d86064bed177183b489       Ellen Whelan
# 3  e493d3146ed442f12248cbe203ed9991d7fc49b7        EllenWhelan
# 4  f6fb2cb2adaff585d02ff6702732a11e3f62fa36        EllenWhelan
#
#   commit_author_email            commit_datetime  commit_merge  file_name  \
# 0     whelane5@tcd.ie  2021-11-24 13:03:24+00:00         False  README.md
# 1     whelane5@tcd.ie  2021-11-24 13:08:12+00:00         False  README.md
# 2     whelane5@tcd.ie  2021-11-27 09:56:16+00:00         False  README.md
# 3     whelane5@tcd.ie  2021-11-27 12:30:56+00:00         False  sensor.py
# 4     whelane5@tcd.ie  2021-11-27 12:32:27+00:00         False  sensor.py
#
#           file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0     ModificationType.ADD                 1                   0       NaN
# 1  ModificationType.MODIFY                30                   1       NaN
# 2  ModificationType.MODIFY                13                  13       NaN
# 3     ModificationType.ADD                83                   0      65.0
# 4  ModificationType.MODIFY                 2                   2      64.0
#
#    file_complexity  file_token_count
# 0              NaN               NaN
# 1              NaN               NaN
# 2              NaN               NaN
# 3             13.0             574.0
# 4             13.0             572.0

# %%
def generate_ordinal_encoding_map ( series ):
    enc_map = series.unique()
    enc_map = dict ( enumerate( enc_map.flatten(), 1 ) )
    enc_map = { val: key for key, val in enc_map.items() }
    enc_map['None'] = 0
    return enc_map

# %%
enc_map = generate_ordinal_encoding_map ( df["commit_author_email"] )
df["commit_author_enc"] = df["commit_author_email"].replace(enc_map)
df
# Out:
#                                   commit_hash commit_author_name  \
# 0    ec3ff00271eeaad747f2deaff616d80620817084       Ellen Whelan
# 1    515351875bb17b7c8aaae9946be21ffcbdec6c75       Ellen Whelan
# 2    8a842e027e2c6e2742697d86064bed177183b489       Ellen Whelan
# 3    e493d3146ed442f12248cbe203ed9991d7fc49b7        EllenWhelan
# 4    f6fb2cb2adaff585d02ff6702732a11e3f62fa36        EllenWhelan
# ..                                        ...                ...
# 483  1d207b909f30901757e3384f6a51162ae21d162a       Chinmay Rane
# 484  b7e675c7b02eb1b39274b8cdf9c05f9f8aa602f6      Chinmayrane16
# 485  b7e675c7b02eb1b39274b8cdf9c05f9f8aa602f6      Chinmayrane16
# 486  b7e675c7b02eb1b39274b8cdf9c05f9f8aa602f6      Chinmayrane16
# 487  64536f851e28535537291c8d0dc350d79cc5e72a       Chinmay Rane
#
#          commit_author_email            commit_datetime  commit_merge  \
# 0            whelane5@tcd.ie  2021-11-24 13:03:24+00:00         False
# 1            whelane5@tcd.ie  2021-11-24 13:08:12+00:00         False
# 2            whelane5@tcd.ie  2021-11-27 09:56:16+00:00         False
# 3            whelane5@tcd.ie  2021-11-27 12:30:56+00:00         False
# 4            whelane5@tcd.ie  2021-11-27 12:32:27+00:00         False
# ..                       ...                        ...           ...
# 483  chinmayrane16@gmail.com  2021-12-10 22:31:46+00:00         False
# 484  chinmayrane16@gmail.com  2021-12-10 22:51:22+00:00         False
# 485  chinmayrane16@gmail.com  2021-12-10 22:51:22+00:00         False
# 486  chinmayrane16@gmail.com  2021-12-10 22:51:22+00:00         False
# 487  chinmayrane16@gmail.com  2021-12-10 22:54:32+00:00         False
#
#             file_name         file_change_type  file_lines_added  \
# 0           README.md     ModificationType.ADD                 1
# 1           README.md  ModificationType.MODIFY                30
# 2           README.md  ModificationType.MODIFY                13
# 3           sensor.py     ModificationType.ADD                83
# 4           sensor.py  ModificationType.MODIFY                 2
# ..                ...                      ...               ...
# 483  requirements.txt  ModificationType.MODIFY                 1
# 484       .run.sh.swp     ModificationType.ADD                 0
# 485        image1.png     ModificationType.ADD                 0
# 486        image2.png     ModificationType.ADD                 0
# 487         README.md  ModificationType.MODIFY                 7
#
#      file_lines_deleted  file_loc  file_complexity  file_token_count  \
# 0                     0       NaN              NaN               NaN
# 1                     1       NaN              NaN               NaN
# 2                    13       NaN              NaN               NaN
# 3                     0      65.0             13.0             574.0
# 4                     2      64.0             13.0             572.0
# ..                  ...       ...              ...               ...
# 483                   1       NaN              NaN               NaN
# 484                   0       NaN              NaN               NaN
# 485                   0       NaN              NaN               NaN
# 486                   0       NaN              NaN               NaN
# 487                   0       NaN              NaN               NaN
#
#      commit_author_enc
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1
# ..                 ...
# 483                  3
# 484                  3
# 485                  3
# 486                  3
# 487                  3
#
# [488 rows x 13 columns]

# %%
from datetime import datetime

date_list = []

for date_time_str in df['commit_datetime']:
    date_time_str = date_time_str[0:-6].replace('-', '/')
    date_time_obj = datetime.strptime(date_time_str, '%Y/%m/%d %H:%M:%S')
    date_list.append ( date_time_obj.date() )
    
df['commit_date'] = date_list
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  ec3ff00271eeaad747f2deaff616d80620817084       Ellen Whelan
# 1  515351875bb17b7c8aaae9946be21ffcbdec6c75       Ellen Whelan
# 2  8a842e027e2c6e2742697d86064bed177183b489       Ellen Whelan
# 3  e493d3146ed442f12248cbe203ed9991d7fc49b7        EllenWhelan
# 4  f6fb2cb2adaff585d02ff6702732a11e3f62fa36        EllenWhelan
#
#   commit_author_email            commit_datetime  commit_merge  file_name  \
# 0     whelane5@tcd.ie  2021-11-24 13:03:24+00:00         False  README.md
# 1     whelane5@tcd.ie  2021-11-24 13:08:12+00:00         False  README.md
# 2     whelane5@tcd.ie  2021-11-27 09:56:16+00:00         False  README.md
# 3     whelane5@tcd.ie  2021-11-27 12:30:56+00:00         False  sensor.py
# 4     whelane5@tcd.ie  2021-11-27 12:32:27+00:00         False  sensor.py
#
#           file_change_type  file_lines_added  file_lines_deleted  file_loc  \
# 0     ModificationType.ADD                 1                   0       NaN
# 1  ModificationType.MODIFY                30                   1       NaN
# 2  ModificationType.MODIFY                13                  13       NaN
# 3     ModificationType.ADD                83                   0      65.0
# 4  ModificationType.MODIFY                 2                   2      64.0
#
#    file_complexity  file_token_count  commit_author_enc commit_date
# 0              NaN               NaN                  1  2021-11-24
# 1              NaN               NaN                  1  2021-11-24
# 2              NaN               NaN                  1  2021-11-27
# 3             13.0             574.0                  1  2021-11-27
# 4             13.0             572.0                  1  2021-11-27

# %%
# Cx = df.corr()
# fig = plt.figure(figsize = (15,15))
# sb.heatmap(Cx, vmax = .8, square = True)
# plt.show()

# %%
grouped_df = df.groupby(['commit_date', 'commit_author_enc']).agg({
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum'
}
).reset_index(level=[0,1])

grouped_df.rename(columns = {
    'commit_date':'date', 
    'commit_author_enc':'author_code',
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count'
}, inplace = True)

grouped_df
# Out:
#           date  author_code  commit_count  additions  deletions  agg_loc  \
# 0   2021-11-24            1             2         31          1      0.0
# 1   2021-11-27            1             9        370         69    769.0
# 2   2021-11-28            1             3        157         88    602.0
# 3   2021-11-29            1             8        246        236    975.0
# 4   2021-11-29            2             1         32         16     90.0
# 5   2021-11-30            1             3         48         44    304.0
# 6   2021-12-09            2             2        278        168    622.0
# 7   2021-12-09            3             1         54         11    269.0
# 8   2021-12-10            1             2        199         49      0.0
# 9   2021-12-10            2             3        171         76    906.0
# 10  2021-12-10            3             7        284        228    473.0
#
#     agg_complexity  agg_token_count
# 0              0.0              0.0
# 1            197.0           5963.0
# 2            162.0           4248.0
# 3            271.0           7288.0
# 4             26.0            747.0
# 5             83.0           2294.0
# 6            109.0           4657.0
# 7             75.0           2103.0
# 8              0.0              0.0
# 9            178.0           6670.0
# 10            83.0           3480.0

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

fig, ax = plt.subplots(2, 3)

author_dict = {}
for author_code in grouped_df['author_code'].unique():    
    
    date = grouped_df['date'].loc[grouped_df['author_code'] == author_code].tolist()
            
    commit_count = grouped_df['commit_count'].loc[grouped_df['author_code'] == author_code].tolist()
    additions = grouped_df['additions'].loc[grouped_df['author_code'] == author_code].tolist()
    deletions = grouped_df['deletions'].loc[grouped_df['author_code'] == author_code].tolist()
    agg_loc = grouped_df['agg_loc'].loc[grouped_df['author_code'] == author_code].tolist()
    agg_complexity = grouped_df['agg_complexity'].loc[grouped_df['author_code'] == author_code].tolist()
    agg_token_count = grouped_df['agg_token_count'].loc[grouped_df['author_code'] == author_code].tolist()
    
    ax[0, 0].plot(date, commit_count, label = f"Author #{author_code}")
    ax[0, 1].plot(date, additions, label = f"Author #{author_code}")
    ax[0, 2].plot(date, deletions, label = f"Author #{author_code}")
    ax[1, 0].plot(date, agg_loc, label = f"Author #{author_code}")
    ax[1, 1].plot(date, agg_complexity, label = f"Author #{author_code}")
    ax[1, 2].plot(date, agg_token_count, label = f"Author #{author_code}")
    
fig.autofmt_xdate()

ax[0, 0].set_title("date vs commit count")
ax[0, 1].set_title("date vs additions")
ax[0, 2].set_title("date vs deletions")
ax[1, 0].set_title("date vs agg. LOC")
ax[1, 1].set_title("date vs agg. complexity")
ax[1, 2].set_title("date vs agg. token count")

ax[0, 0].set_xlabel("date")
ax[0, 1].set_xlabel("date")
ax[0, 2].set_xlabel("date")
ax[1, 0].set_xlabel("date")
ax[1, 1].set_xlabel("date")
ax[1, 2].set_xlabel("date")

ax[0, 0].set_ylabel("commit count")
ax[0, 1].set_ylabel("additions")
ax[0, 2].set_ylabel("deletions")
ax[1, 0].set_ylabel("agg. LOC")
ax[1, 1].set_ylabel("agg. complexity")
ax[1, 2].set_ylabel("agg. token count")

plt.show()
