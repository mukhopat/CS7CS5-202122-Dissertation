# %%
from pydriller import Repository
from time import time
from datetime import timedelta
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
repo_path = f'./clone/{repo_name}'

commit_data = []

start_time = time()

for commit in Repository(repo_path).traverse_commits():
    for file in commit.modified_files:
        commit_data.append( [
            commit.hash, 
            commit.author.name, 
            commit.author.email,
            commit.committer_date,
            commit.merge,
            commit.dmm_unit_size,
            commit.dmm_unit_complexity,
            commit.dmm_unit_interfacing,
            file.filename, 
            file.change_type, 
            file.added_lines, 
            file.deleted_lines,
            file.nloc,
            file.complexity,
            file.token_count
        ] )
        
print( f'Execution time = { str ( timedelta ( seconds = time() - start_time ) ) }' )
# Out:
# Execution time = 0:00:47.087094

# %%
import pandas as pd

df = pd.DataFrame(commit_data)

df.columns = [
    'commit_hash', 
    'commit_author_name', 
    'commit_author_email',
    'commit_datetime', 
    'commit_merge',
    'dmm_unit_size',
    'dmm_unit_complexity',
    'dmm_unit_interfacing',
    'file_name', 
    'file_change_type', 
    'file_lines_added',
    'file_lines_deleted',
    'file_loc',
    'file_complexity',
    'file_token_count'
]

df
# Out:
#                                   commit_hash commit_author_name  \
# 0    f680aaf8595bb6511d3ea36ba401476a161d7448      Sindre Sorhus
# 1    d1dea0d52ce2ead8bfe06ebde1468d1c6d0224a5            Yuvaraj
# 2    55505684dc34d4b2bf2301ef144f84b09f2c4bdf      Sindre Sorhus
# 3    2dc7b7f2bd4fe11798410ed876c9b85d88c418d7             dimlev
# 4    d858a98dee54c5766b13fd42ca62cee81e04d4d4       Costin Moise
# ..                                        ...                ...
# 932  537ad564e517478a6909c4fcfe62c696e8850f29          Oaker Min
# 933  6e4c2a13355020b9f57b330db12696f30b384ec1       Ege Can ÖZER
# 934  e55a7d007f3e29c21a444050a6bf33e557f7d09e             h3nk42
# 935  1870e51e0ae1438a0503854fa2b71f67bb434634     Alan Christian
# 936  d5832cebce13c2e91735c7ecf40bf26628042454         Yu-Zhe Shi
#
#                             commit_author_email            commit_datetime  \
# 0                        sindresorhus@gmail.com  2014-07-11 15:42:24+02:00
# 1                             uvaraj6@gmail.com  2014-07-12 09:02:06+05:18
# 2                        sindresorhus@gmail.com  2014-07-12 10:47:26+02:00
# 3                              dimlev@gmail.com  2014-07-12 16:44:09+03:00
# 4                          necenzurat@gmail.com  2014-07-12 17:41:59+03:00
# ..                                          ...                        ...
# 932  7734956+brootware@users.noreply.github.com  2022-06-09 21:29:01+07:00
# 933                       egecan.ozer@gmail.com  2022-06-13 14:38:12+07:00
# 934    35529607+h3nk42@users.noreply.github.com  2022-06-26 21:50:44+02:00
# 935                       alancsystem@gmail.com  2022-07-20 13:13:25+02:00
# 936                       yuzhe_shi@outlook.com  2022-07-23 12:37:54+02:00
#
#      commit_merge dmm_unit_size dmm_unit_complexity dmm_unit_interfacing  \
# 0           False          None                None                 None
# 1           False          None                None                 None
# 2           False          None                None                 None
# 3           False          None                None                 None
# 4           False          None                None                 None
# ..            ...           ...                 ...                  ...
# 932         False          None                None                 None
# 933         False          None                None                 None
# 934         False          None                None                 None
# 935         False          None                None                 None
# 936         False          None                None                 None
#
#      file_name         file_change_type  file_lines_added  file_lines_deleted  \
# 0    readme.md     ModificationType.ADD                19                   0
# 1    readme.md  ModificationType.MODIFY                 1                   0
# 2    readme.md  ModificationType.MODIFY                32                   9
# 3    readme.md  ModificationType.MODIFY                 0                   1
# 4    readme.md  ModificationType.MODIFY                 1                   0
# ..         ...                      ...               ...                 ...
# 932  readme.md  ModificationType.MODIFY                 1                   0
# 933  readme.md  ModificationType.MODIFY                 1                   0
# 934  readme.md  ModificationType.MODIFY                 2                   2
# 935  readme.md  ModificationType.MODIFY                 2                   2
# 936  readme.md  ModificationType.MODIFY                 1                   0
#
#     file_loc file_complexity file_token_count
# 0       None            None             None
# 1       None            None             None
# 2       None            None             None
# 3       None            None             None
# 4       None            None             None
# ..       ...             ...              ...
# 932     None            None             None
# 933     None            None             None
# 934     None            None             None
# 935     None            None             None
# 936     None            None             None
#
# [937 rows x 15 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_modfiles.csv', index = False )

# %%
import winsound
winsound.MessageBeep ( type = -1 )
