# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_final.csv'
df = pd.read_csv (dataset_path)
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2017-02            48       1238         18      0.0             0.0
# 1     2017-03            86       6291        706    692.0           192.0
# 2     2017-04            23       1840         29      0.0             0.0
# 3     2017-05             6         15          5      0.0             0.0
# 4     2017-06             2          3          2      0.0             0.0
# ..        ...           ...        ...        ...      ...             ...
# 61    2022-03             0          0          0      0.0             0.0
# 62    2022-04             2          4          4      0.0             0.0
# 63    2022-05             0          0          0      0.0             0.0
# 64    2022-06             0          0          0      0.0             0.0
# 65    2022-07             1          1          1      0.0             0.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0               0.0       0.000000             0.000000              0.000000
# 1            4511.0       0.919958             0.908609              0.599393
# 2               0.0       0.000000             0.000000              0.000000
# 3               0.0       0.000000             0.000000              0.000000
# 4               0.0       0.000000             0.000000              0.000000
# ..              ...            ...                  ...                   ...
# 61              0.0       0.000000             0.000000              0.000000
# 62              0.0       0.000000             0.000000              0.000000
# 63              0.0       0.000000             0.000000              0.000000
# 64              0.0       0.000000             0.000000              0.000000
# 65              0.0       0.000000             0.000000              0.000000
#
# [66 rows x 10 columns]

# %%
# df['year_month'] = pd.to_datetime(df['year_month'])
df = df.set_index(df['year_month'])
df
# Out:
#            year_month  commit_count  additions  deletions  agg_loc  \
# year_month
# 2017-02       2017-02            48       1238         18      0.0
# 2017-03       2017-03            86       6291        706    692.0
# 2017-04       2017-04            23       1840         29      0.0
# 2017-05       2017-05             6         15          5      0.0
# 2017-06       2017-06             2          3          2      0.0
# ...               ...           ...        ...        ...      ...
# 2022-03       2022-03             0          0          0      0.0
# 2022-04       2022-04             2          4          4      0.0
# 2022-05       2022-05             0          0          0      0.0
# 2022-06       2022-06             0          0          0      0.0
# 2022-07       2022-07             1          1          1      0.0
#
#             agg_complexity  agg_token_count  dmm_unit_size  \
# year_month
# 2017-02                0.0              0.0       0.000000
# 2017-03              192.0           4511.0       0.919958
# 2017-04                0.0              0.0       0.000000
# 2017-05                0.0              0.0       0.000000
# 2017-06                0.0              0.0       0.000000
# ...                    ...              ...            ...
# 2022-03                0.0              0.0       0.000000
# 2022-04                0.0              0.0       0.000000
# 2022-05                0.0              0.0       0.000000
# 2022-06                0.0              0.0       0.000000
# 2022-07                0.0              0.0       0.000000
#
#             dmm_unit_complexity  dmm_unit_interfacing
# year_month
# 2017-02                0.000000              0.000000
# 2017-03                0.908609              0.599393
# 2017-04                0.000000              0.000000
# 2017-05                0.000000              0.000000
# 2017-06                0.000000              0.000000
# ...                         ...                   ...
# 2022-03                0.000000              0.000000
# 2022-04                0.000000              0.000000
# 2022-05                0.000000              0.000000
# 2022-06                0.000000              0.000000
# 2022-07                0.000000              0.000000
#
# [66 rows x 10 columns]

# %%
pre_covid_ym = '2020-02'
covid_ym = '2020-03'
df1 = df [ str(df.year_month[0]) : pre_covid_ym ]
df2 = df [ covid_ym: str(df.year_month[-1]) ]
df1 = df1.reset_index ( drop = True )
df2 = df2.reset_index ( drop = True )

df1.shape, df2.shape
# Out:
# ((37, 10), (29, 10))

# %%
from top_contributors import get_equilibrium_pc, get_pareto_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, len(df1.columns) ):
    print ( f'{df1.columns[idx]} = { get_equilibrium_pc ( list ( df1[df1.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 11
# additions = 8
# deletions = 5
# agg_loc = 8
# agg_complexity = 8
# agg_token_count = 8
# dmm_unit_size = 5
# dmm_unit_complexity = 5
# dmm_unit_interfacing = 5

# %%
print("Post-pandemic equilibrium percentages:")
for idx in range ( 1, len(df2.columns) ):
    print ( f'{df2.columns[idx]} = { get_equilibrium_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Post-pandemic equilibrium percentages:
# commit_count = 7
# additions = 7
# deletions = 7
# agg_loc = 3
# agg_complexity = 3
# agg_token_count = 3
# dmm_unit_size = 3
# dmm_unit_complexity = 3
# dmm_unit_interfacing = 3

# %%
print("Pre-pandemic Pareto percentages:")
for idx in range ( 1, len(df1.columns) ):
    print ( f'{df1.columns[idx]} = { get_pareto_pc ( list ( df1[df1.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic Pareto percentages:
# commit_count = 34
# additions = 13
# deletions = 13
# agg_loc = 13
# agg_complexity = 13
# agg_token_count = 13
# dmm_unit_size = 8
# dmm_unit_complexity = 8
# dmm_unit_interfacing = 8

# %%
print("Post-pandemic Pareto percentages:")
for idx in range ( 1, len(df2.columns) ):
    print ( f'{df2.columns[idx]} = { get_pareto_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Post-pandemic Pareto percentages:
# commit_count = 20
# additions = 7
# deletions = 7
# agg_loc = 3
# agg_complexity = 3
# agg_token_count = 3
# dmm_unit_size = 3
# dmm_unit_complexity = 3
# dmm_unit_interfacing = 3
