# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  71c54fcad3a1a28269a7ae4e7b892d2bb8dd544d            CyC2018
# 1  18ca5d06f8be7fb368de3ce36152bebcd8a58321            CyC2018
# 2  9dc95e1b814d796762c3a598f85ef4c4f371f07a            CyC2018
# 3  6948fe550c9dfbd9556da1c662cb28553a472080            CyC2018
# 4  aa787c0ce2bef21c310e7d7c72a2ea75de4b4346            CyC2018
#
#                          commit_author_email            commit_datetime  \
# 0  36260787+CyC2018@users.noreply.github.com  2018-02-13 22:57:01+08:00
# 1  36260787+CyC2018@users.noreply.github.com  2018-02-13 22:59:02+08:00
# 2  36260787+CyC2018@users.noreply.github.com  2018-02-13 23:00:40+08:00
# 3  36260787+CyC2018@users.noreply.github.com  2018-02-13 23:01:07+08:00
# 4  36260787+CyC2018@users.noreply.github.com  2018-02-13 23:02:10+08:00
#
#    commit_merge  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0         False            NaN                  NaN                   NaN
# 1         False            NaN                  NaN                   NaN
# 2         False            NaN                  NaN                   NaN
# 3         False            NaN                  NaN                   NaN
# 4         False            NaN                  NaN                   NaN
#
#        file_name         file_change_type  file_lines_added  \
# 0      README.md     ModificationType.ADD                 3
# 1     2016校招真题题解     ModificationType.ADD               741
# 2      README.md  ModificationType.MODIFY                 1
# 3  2016校招真题题解.md  ModificationType.RENAME                 0
# 4   剑指offer题解.md     ModificationType.ADD              1526
#
#    file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                   0       NaN              NaN               NaN
# 1                   0       NaN              NaN               NaN
# 2                   1       NaN              NaN               NaN
# 3                   0       NaN              NaN               NaN
# 4                   0       NaN              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                     commit_hash year_month commit_author_name  \
# 0      71c54fcad3a1a28269a7ae4e7b892d2bb8dd544d    2018-02            CyC2018
# 1      18ca5d06f8be7fb368de3ce36152bebcd8a58321    2018-02            CyC2018
# 2      9dc95e1b814d796762c3a598f85ef4c4f371f07a    2018-02            CyC2018
# 3      6948fe550c9dfbd9556da1c662cb28553a472080    2018-02            CyC2018
# 4      aa787c0ce2bef21c310e7d7c72a2ea75de4b4346    2018-02            CyC2018
# ...                                         ...        ...                ...
# 35105  a8c5a570659e419bca951dfa431bfd6d4e10b37f    2021-04            CyC2018
# 35106  d385d1d1056f11ef8dbbe87ffe5dc136accbec36    2021-07            CyC2018
# 35107  25c9ae3161e301965ae25cf95b890a31e80b4d37    2021-07            CyC2018
# 35108  456ff183d550baba9f1f5f54a3f736a5089f1cb2    2021-07            CyC2018
# 35109  2c31eddf3481a31ab5c10ebced395497c6bf9d61    2022-02            CyC2018
#
#                              commit_author_email            commit_datetime  \
# 0      36260787+CyC2018@users.noreply.github.com  2018-02-13 22:57:01+08:00
# 1      36260787+CyC2018@users.noreply.github.com  2018-02-13 22:59:02+08:00
# 2      36260787+CyC2018@users.noreply.github.com  2018-02-13 23:00:40+08:00
# 3      36260787+CyC2018@users.noreply.github.com  2018-02-13 23:01:07+08:00
# 4      36260787+CyC2018@users.noreply.github.com  2018-02-13 23:02:10+08:00
# ...                                          ...                        ...
# 35105                         zhengyc101@163.com  2021-04-19 01:32:23+08:00
# 35106                         zhengyc101@163.com  2021-07-30 01:56:34+08:00
# 35107                         zhengyc101@163.com  2021-07-30 01:57:14+08:00
# 35108                         zhengyc101@163.com  2021-07-30 01:59:53+08:00
# 35109                         zhengyc101@163.com  2022-02-05 11:45:27+08:00
#
#        commit_merge  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0             False            NaN                  NaN                   NaN
# 1             False            NaN                  NaN                   NaN
# 2             False            NaN                  NaN                   NaN
# 3             False            NaN                  NaN                   NaN
# 4             False            NaN                  NaN                   NaN
# ...             ...            ...                  ...                   ...
# 35105         False            NaN                  NaN                   NaN
# 35106         False            NaN                  NaN                   NaN
# 35107         False            NaN                  NaN                   NaN
# 35108         False            NaN                  NaN                   NaN
# 35109         False            NaN                  NaN                   NaN
#
#             file_name         file_change_type  file_lines_added  \
# 0           README.md     ModificationType.ADD                 3
# 1          2016校招真题题解     ModificationType.ADD               741
# 2           README.md  ModificationType.MODIFY                 1
# 3       2016校招真题题解.md  ModificationType.RENAME                 0
# 4        剑指offer题解.md     ModificationType.ADD              1526
# ...               ...                      ...               ...
# 35105      Java 基础.md  ModificationType.MODIFY                 1
# 35106     国际化电商内推.png     ModificationType.ADD                 0
# 35107       国际化电商.png     ModificationType.ADD                 0
# 35108           内推.md  ModificationType.MODIFY                 8
# 35109  .gitattributes  ModificationType.DELETE                 0
#
#        file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                       0       NaN              NaN               NaN
# 1                       0       NaN              NaN               NaN
# 2                       1       NaN              NaN               NaN
# 3                       0       NaN              NaN               NaN
# 4                       0       NaN              NaN               NaN
# ...                   ...       ...              ...               ...
# 35105                   1       NaN              NaN               NaN
# 35106                   0       NaN              NaN               NaN
# 35107                   0       NaN              NaN               NaN
# 35108                   4       NaN              NaN               NaN
# 35109                   1       NaN              NaN               NaN
#
# [35110 rows x 16 columns]

# %%
df.drop ( df[df.year_month == '2022-08'].index, inplace = True )
df
# Out:
#                                     commit_hash year_month commit_author_name  \
# 0      71c54fcad3a1a28269a7ae4e7b892d2bb8dd544d    2018-02            CyC2018
# 1      18ca5d06f8be7fb368de3ce36152bebcd8a58321    2018-02            CyC2018
# 2      9dc95e1b814d796762c3a598f85ef4c4f371f07a    2018-02            CyC2018
# 3      6948fe550c9dfbd9556da1c662cb28553a472080    2018-02            CyC2018
# 4      aa787c0ce2bef21c310e7d7c72a2ea75de4b4346    2018-02            CyC2018
# ...                                         ...        ...                ...
# 35105  a8c5a570659e419bca951dfa431bfd6d4e10b37f    2021-04            CyC2018
# 35106  d385d1d1056f11ef8dbbe87ffe5dc136accbec36    2021-07            CyC2018
# 35107  25c9ae3161e301965ae25cf95b890a31e80b4d37    2021-07            CyC2018
# 35108  456ff183d550baba9f1f5f54a3f736a5089f1cb2    2021-07            CyC2018
# 35109  2c31eddf3481a31ab5c10ebced395497c6bf9d61    2022-02            CyC2018
#
#                              commit_author_email            commit_datetime  \
# 0      36260787+CyC2018@users.noreply.github.com  2018-02-13 22:57:01+08:00
# 1      36260787+CyC2018@users.noreply.github.com  2018-02-13 22:59:02+08:00
# 2      36260787+CyC2018@users.noreply.github.com  2018-02-13 23:00:40+08:00
# 3      36260787+CyC2018@users.noreply.github.com  2018-02-13 23:01:07+08:00
# 4      36260787+CyC2018@users.noreply.github.com  2018-02-13 23:02:10+08:00
# ...                                          ...                        ...
# 35105                         zhengyc101@163.com  2021-04-19 01:32:23+08:00
# 35106                         zhengyc101@163.com  2021-07-30 01:56:34+08:00
# 35107                         zhengyc101@163.com  2021-07-30 01:57:14+08:00
# 35108                         zhengyc101@163.com  2021-07-30 01:59:53+08:00
# 35109                         zhengyc101@163.com  2022-02-05 11:45:27+08:00
#
#        commit_merge  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0             False            NaN                  NaN                   NaN
# 1             False            NaN                  NaN                   NaN
# 2             False            NaN                  NaN                   NaN
# 3             False            NaN                  NaN                   NaN
# 4             False            NaN                  NaN                   NaN
# ...             ...            ...                  ...                   ...
# 35105         False            NaN                  NaN                   NaN
# 35106         False            NaN                  NaN                   NaN
# 35107         False            NaN                  NaN                   NaN
# 35108         False            NaN                  NaN                   NaN
# 35109         False            NaN                  NaN                   NaN
#
#             file_name         file_change_type  file_lines_added  \
# 0           README.md     ModificationType.ADD                 3
# 1          2016校招真题题解     ModificationType.ADD               741
# 2           README.md  ModificationType.MODIFY                 1
# 3       2016校招真题题解.md  ModificationType.RENAME                 0
# 4        剑指offer题解.md     ModificationType.ADD              1526
# ...               ...                      ...               ...
# 35105      Java 基础.md  ModificationType.MODIFY                 1
# 35106     国际化电商内推.png     ModificationType.ADD                 0
# 35107       国际化电商.png     ModificationType.ADD                 0
# 35108           内推.md  ModificationType.MODIFY                 8
# 35109  .gitattributes  ModificationType.DELETE                 0
#
#        file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                       0       NaN              NaN               NaN
# 1                       0       NaN              NaN               NaN
# 2                       1       NaN              NaN               NaN
# 3                       0       NaN              NaN               NaN
# 4                       0       NaN              NaN               NaN
# ...                   ...       ...              ...               ...
# 35105                   1       NaN              NaN               NaN
# 35106                   0       NaN              NaN               NaN
# 35107                   0       NaN              NaN               NaN
# 35108                   4       NaN              NaN               NaN
# 35109                   1       NaN              NaN               NaN
#
# [35110 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2018-02           184      96273      63752  10974.0          3334.0
# 1     2018-03           873     329374     338072      0.0             0.0
# 2     2018-04           194     146615     143245      0.0             0.0
# 3     2018-05            52       4745       3594      0.0             0.0
# 4     2018-06           160      35723      32288      0.0             0.0
# 5     2018-07            89       3230       1560      0.0             0.0
# 6     2018-08           143       9873      16257      0.0             0.0
# 7     2018-09            72       1186        862      0.0             0.0
# 8     2018-10            31        348        201      0.0             0.0
# 9     2018-11            26        246        245      0.0             0.0
# 10    2018-12           108     113587      36040  25571.0         10521.0
# 11    2019-01           260      37599      38013      0.0             0.0
# 12    2019-02           120        702        678      0.0             0.0
# 13    2019-03           197      95934     135794      0.0             0.0
# 14    2019-04           134      68355      37897      0.0             0.0
# 15    2019-05            96       4751       4242      0.0             0.0
# 16    2019-06           135       6179       5589     16.0             3.0
# 17    2019-07            21        535        537      0.0             0.0
# 18    2019-08             7        122         50      0.0             0.0
# 19    2019-09             8         26         26      0.0             0.0
# 20    2019-10            42       3299       3167      0.0             0.0
# 21    2019-11            42      18952       5121      0.0             0.0
# 22    2019-12            39       5477       5425      0.0             0.0
# 23    2020-01             3         16         13      0.0             0.0
# 24    2020-02            13       1326       1175      0.0             0.0
# 25    2020-03             2          2          2      0.0             0.0
# 26    2020-04             3          3          3      0.0             0.0
# 27    2020-05            14        451        489      0.0             0.0
# 28    2020-07             1          3          2      0.0             0.0
# 29    2020-08             2          6          6      0.0             0.0
# 30    2020-09             1         10         10      0.0             0.0
# 31    2020-10            15         41         23      0.0             0.0
# 32    2020-11            82       8366      52488      0.0             0.0
# 33    2021-03             3        118         89      0.0             0.0
# 34    2021-04             6         13          7      0.0             0.0
# 35    2021-07             3          8          4      0.0             0.0
# 36    2022-02             1          0          1      0.0             0.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0           76429.0       0.608394             0.638985              0.811468
# 1               0.0       0.331000             0.314833              0.112333
# 2               0.0            NaN                  NaN                   NaN
# 3               0.0            NaN                  NaN                   NaN
# 4               0.0            NaN                  NaN                   NaN
# 5               0.0            NaN                  NaN                   NaN
# 6               0.0            NaN                  NaN                   NaN
# 7               0.0            NaN                  NaN                   NaN
# 8               0.0            NaN                  NaN                   NaN
# 9               0.0            NaN                  NaN                   NaN
# 10         328577.0       0.447027             0.633575              0.855372
# 11              0.0            NaN                  NaN                   NaN
# 12              0.0            NaN                  NaN                   NaN
# 13              0.0       0.492887             0.297193              0.041394
# 14              0.0            NaN                  NaN                   NaN
# 15              0.0            NaN                  NaN                   NaN
# 16             71.0       0.500000             0.500000              0.500000
# 17              0.0            NaN                  NaN                   NaN
# 18              0.0            NaN                  NaN                   NaN
# 19              0.0            NaN                  NaN                   NaN
# 20              0.0            NaN                  NaN                   NaN
# 21              0.0            NaN                  NaN                   NaN
# 22              0.0            NaN                  NaN                   NaN
# 23              0.0            NaN                  NaN                   NaN
# 24              0.0            NaN                  NaN                   NaN
# 25              0.0            NaN                  NaN                   NaN
# 26              0.0            NaN                  NaN                   NaN
# 27              0.0            NaN                  NaN                   NaN
# 28              0.0            NaN                  NaN                   NaN
# 29              0.0            NaN                  NaN                   NaN
# 30              0.0            NaN                  NaN                   NaN
# 31              0.0            NaN                  NaN                   NaN
# 32              0.0            NaN                  NaN                   NaN
# 33              0.0            NaN                  NaN                   NaN
# 34              0.0            NaN                  NaN                   NaN
# 35              0.0            NaN                  NaN                   NaN
# 36              0.0            NaN                  NaN                   NaN

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
