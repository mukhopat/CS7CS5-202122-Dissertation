# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_groupedby_yearmonth.csv'
df = pd.read_csv (dataset_path)
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2017-02            48       1238         18      0.0             0.0
# 1     2017-03            86       6291        706    692.0           192.0
# 2     2017-04            23       1840         29      0.0             0.0
# 3     2017-05             6         15          5      0.0             0.0
# 4     2017-06             2          3          2      0.0             0.0
# 5     2017-07             4          5          3      0.0             0.0
# 6     2017-08             1          0          0      0.0             0.0
# 7     2017-09             3          3          3      0.0             0.0
# 8     2017-10             3          3          2      0.0             0.0
# 9     2017-12             6       1794          7      0.0             0.0
# 10    2018-01             4         11         12      0.0             0.0
# 11    2018-02             6       1812         25      0.0             0.0
# 12    2018-03             8        110         69    674.0           218.0
# 13    2018-04             5         12         12    194.0            59.0
# 14    2018-05             3          8          4    209.0            62.0
# 15    2018-06             2          3          3      0.0             0.0
# 16    2018-07             9         33         25    179.0            59.0
# 17    2018-08             9         23         24      0.0             0.0
# 18    2018-09             7         13         13      0.0             0.0
# 19    2018-10             4         35         35      0.0             0.0
# 20    2018-11             1          1          1      0.0             0.0
# 21    2018-12             2          5          5      0.0             0.0
# 22    2019-01             2          2          2      0.0             0.0
# 23    2019-02             3          4          4      0.0             0.0
# 24    2019-03             2          2          2      0.0             0.0
# 25    2019-05             7        251        158      0.0             0.0
# 26    2019-06             1        331          1      0.0             0.0
# 27    2019-07             4          4          4      0.0             0.0
# 28    2019-08             6          7          7      0.0             0.0
# 29    2019-11             1          1          0      0.0             0.0
# 30    2019-12             3         13         13     85.0            27.0
# 31    2020-01             2          3          3      0.0             0.0
# 32    2020-03             3       5449       2934      0.0             0.0
# 33    2020-05             1          4          4      0.0             0.0
# 34    2020-07            27        400        201      0.0             0.0
# 35    2020-08             2          1          1      0.0             0.0
# 36    2020-10             1          2          2      0.0             0.0
# 37    2020-12             1          1          1      0.0             0.0
# 38    2021-01             1          4          4      0.0             0.0
# 39    2021-02             1          1          1      0.0             0.0
# 40    2021-05             1          1          1      0.0             0.0
# 41    2021-11             1          4          4      0.0             0.0
# 42    2022-02             1          4          4      0.0             0.0
# 43    2022-04             2          4          4      0.0             0.0
# 44    2022-07             1          1          1      0.0             0.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0               0.0            NaN                  NaN                   NaN
# 1            4511.0       0.919958             0.908609              0.599393
# 2               0.0            NaN                  NaN                   NaN
# 3               0.0            NaN                  NaN                   NaN
# 4               0.0            NaN                  NaN                   NaN
# 5               0.0            NaN                  NaN                   NaN
# 6               0.0            NaN                  NaN                   NaN
# 7               0.0            NaN                  NaN                   NaN
# 8               0.0            NaN                  NaN                   NaN
# 9               0.0            NaN                  NaN                   NaN
# 10              0.0            NaN                  NaN                   NaN
# 11              0.0            NaN                  NaN                   NaN
# 12           4100.0       0.777778             0.777778              0.502315
# 13           1246.0            NaN                  NaN              0.000000
# 14           1298.0            NaN                  NaN                   NaN
# 15              0.0            NaN                  NaN                   NaN
# 16           1151.0            NaN                  NaN                   NaN
# 17              0.0            NaN                  NaN                   NaN
# 18              0.0            NaN                  NaN                   NaN
# 19              0.0            NaN                  NaN                   NaN
# 20              0.0            NaN                  NaN                   NaN
# 21              0.0            NaN                  NaN                   NaN
# 22              0.0            NaN                  NaN                   NaN
# 23              0.0            NaN                  NaN                   NaN
# 24              0.0            NaN                  NaN                   NaN
# 25              0.0            NaN                  NaN                   NaN
# 26              0.0            NaN                  NaN                   NaN
# 27              0.0            NaN                  NaN                   NaN
# 28              0.0            NaN                  NaN                   NaN
# 29              0.0            NaN                  NaN                   NaN
# 30            597.0            NaN                  NaN                   NaN
# 31              0.0            NaN                  NaN                   NaN
# 32              0.0            NaN                  NaN                   NaN
# 33              0.0            NaN                  NaN                   NaN
# 34              0.0            NaN                  NaN                   NaN
# 35              0.0            NaN                  NaN                   NaN
# 36              0.0            NaN                  NaN                   NaN
# 37              0.0            NaN                  NaN                   NaN
# 38              0.0            NaN                  NaN                   NaN
# 39              0.0            NaN                  NaN                   NaN
# 40              0.0            NaN                  NaN                   NaN
# 41              0.0            NaN                  NaN                   NaN
# 42              0.0            NaN                  NaN                   NaN
# 43              0.0            NaN                  NaN                   NaN
# 44              0.0            NaN                  NaN                   NaN

# %%
df['dmm_unit_size'] = df['dmm_unit_size'].fillna(0)
df['dmm_unit_complexity'] = df['dmm_unit_complexity'].fillna(0)
df['dmm_unit_interfacing'] = df['dmm_unit_interfacing'].fillna(0)

# %%
start_date = df.year_month[0][5:7] + '-01-' + df.year_month[0][0:4]
end_date = df.year_month[len(df.year_month) - 1][5:7] + '-01-' + df.year_month[len(df.year_month) - 1][0:4]
dfperiod = pd.period_range(start_date, end_date, freq='M')

def new_zero_row ( year_month ):
    
    new_row = {
        'year_month': year_month,
        'commit_count': 0,
        'additions': 0,
        'deletions': 0,
        'agg_loc': 0,
        'agg_complexity': 0,
        'agg_token_count': 0,
        'dmm_unit_size': 0,
        'dmm_unit_complexity': 0,
        'dmm_unit_interfacing': 0
    }
    
    return new_row

for year_month in dfperiod:
    if df [ ( df['year_month'] == str(year_month) ) ].shape[0] == 0:
        df = df.append ( new_zero_row(year_month), ignore_index = True )

df.shape
# Out:
# (66, 10)

# %%
df['year_month'] = df['year_month'].astype(str)
df = df.sort_values ( by=['year_month'] )
df.reset_index(drop=True, inplace=True)
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2017-02            48       1238         18      0.0             0.0
# 1     2017-03            86       6291        706    692.0           192.0
# 2     2017-04            23       1840         29      0.0             0.0
# 3     2017-05             6         15          5      0.0             0.0
# 4     2017-06             2          3          2      0.0             0.0
# ..        ...           ...        ...        ...      ...             ...
# 61    2022-03             0          0          0      0.0             0.0
# 62    2022-04             2          4          4      0.0             0.0
# 63    2022-05             0          0          0      0.0             0.0
# 64    2022-06             0          0          0      0.0             0.0
# 65    2022-07             1          1          1      0.0             0.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0               0.0       0.000000             0.000000              0.000000
# 1            4511.0       0.919958             0.908609              0.599393
# 2               0.0       0.000000             0.000000              0.000000
# 3               0.0       0.000000             0.000000              0.000000
# 4               0.0       0.000000             0.000000              0.000000
# ..              ...            ...                  ...                   ...
# 61              0.0       0.000000             0.000000              0.000000
# 62              0.0       0.000000             0.000000              0.000000
# 63              0.0       0.000000             0.000000              0.000000
# 64              0.0       0.000000             0.000000              0.000000
# 65              0.0       0.000000             0.000000              0.000000
#
# [66 rows x 10 columns]

# %%
df.to_csv ( f'datasets/{repo_name}_final.csv', index = False )

# %% [markdown]
# # Analysis

# %%
for idx in range(1, 10):
    ma_prefix = 'ma_'
    df[ma_prefix + df.columns[idx]] = df[df.columns[idx]].rolling ( window = 3 ).mean()
df
# Out:
#    year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0     2017-02            48       1238         18      0.0             0.0
# 1     2017-03            86       6291        706    692.0           192.0
# 2     2017-04            23       1840         29      0.0             0.0
# 3     2017-05             6         15          5      0.0             0.0
# 4     2017-06             2          3          2      0.0             0.0
# ..        ...           ...        ...        ...      ...             ...
# 61    2022-03             0          0          0      0.0             0.0
# 62    2022-04             2          4          4      0.0             0.0
# 63    2022-05             0          0          0      0.0             0.0
# 64    2022-06             0          0          0      0.0             0.0
# 65    2022-07             1          1          1      0.0             0.0
#
#     agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0               0.0       0.000000             0.000000              0.000000
# 1            4511.0       0.919958             0.908609              0.599393
# 2               0.0       0.000000             0.000000              0.000000
# 3               0.0       0.000000             0.000000              0.000000
# 4               0.0       0.000000             0.000000              0.000000
# ..              ...            ...                  ...                   ...
# 61              0.0       0.000000             0.000000              0.000000
# 62              0.0       0.000000             0.000000              0.000000
# 63              0.0       0.000000             0.000000              0.000000
# 64              0.0       0.000000             0.000000              0.000000
# 65              0.0       0.000000             0.000000              0.000000
#
#     ma_commit_count  ma_additions  ma_deletions  ma_agg_loc  \
# 0               NaN           NaN           NaN         NaN
# 1               NaN           NaN           NaN         NaN
# 2         52.333333   3123.000000    251.000000  230.666667
# 3         38.333333   2715.333333    246.666667  230.666667
# 4         10.333333    619.333333     12.000000    0.000000
# ..              ...           ...           ...         ...
# 61         0.333333      1.333333      1.333333    0.000000
# 62         1.000000      2.666667      2.666667    0.000000
# 63         0.666667      1.333333      1.333333    0.000000
# 64         0.666667      1.333333      1.333333    0.000000
# 65         0.333333      0.333333      0.333333    0.000000
#
#     ma_agg_complexity  ma_agg_token_count  ma_dmm_unit_size  \
# 0                 NaN                 NaN               NaN
# 1                 NaN                 NaN               NaN
# 2                64.0         1503.666667          0.306653
# 3                64.0         1503.666667          0.306653
# 4                 0.0            0.000000          0.000000
# ..                ...                 ...               ...
# 61                0.0            0.000000          0.000000
# 62                0.0            0.000000          0.000000
# 63                0.0            0.000000          0.000000
# 64                0.0            0.000000          0.000000
# 65                0.0            0.000000          0.000000
#
#     ma_dmm_unit_complexity  ma_dmm_unit_interfacing
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                  0.30287                 0.199798
# 3                  0.30287                 0.199798
# 4                  0.00000                 0.000000
# ..                     ...                      ...
# 61                 0.00000                 0.000000
# 62                 0.00000                 0.000000
# 63                 0.00000                 0.000000
# 64                 0.00000                 0.000000
# 65                 0.00000                 0.000000
#
# [66 rows x 19 columns]

# %%
from plot_line_lib import plot_line

for idx in range ( 1, 7 ):
    
    images_path = f'images/'
    plot_line ( df.columns[idx], idx, df, images_path, repo_name, major_locator = True )

# %%
from analysis_lib import year_pre_covid_ym, pre_covid_ym, covid_ym, year_post_covid_ym

df = df.set_index(df['year_month'])

df1 = df [ year_pre_covid_ym : pre_covid_ym ]
df2 = df [ covid_ym : year_post_covid_ym ]
df1 = df1.reset_index ( drop = True )
df2 = df2.reset_index ( drop = True )

df1.shape, df2.shape
# Out:
# ((12, 19), (12, 19))

# %%
from analysis_lib import calc_and_compare_means

calc_and_compare_means ( df1, df2 )
# Out:
# Pre and Post-Covid Mean Comparisons:
# commit count :  2  vs  3  ->  Up (50.0%)
# additions :  51  vs  488  ->  Up (856.9%)
# deletions :  16  vs  262  ->  Up (1537.5%)
# agg loc :  7  vs  0  ->  Down (100.0%)
# agg complexity :  2  vs  0  ->  Down (100.0%)
# agg token count :  50  vs  0  ->  Down (100.0%)

# %% [markdown]
# # Distribution

# %%
from analysis_lib import get_equilibrium_pc

print("Pre-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_equilibrium_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic equilibrium percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_equilibrium_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic equilibrium percentages:
# commit_count = 16.7
# additions = 8.3
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
#
# Post-pandemic equilibrium percentages:
# commit_count = 8.3
# additions = 8.3
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3

# %%
from analysis_lib import get_pareto_pc

print("Pre-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df1.columns[idx]} = { get_pareto_pc ( list ( df1[df1.columns[idx]] ) ) }' )
    
print("\nPost-pandemic pareto percentages:")
for idx in range ( 1, 7 ):
    print ( f'{df2.columns[idx]} = { get_pareto_pc ( list ( df2[df2.columns[idx]] ) ) }' )
# Out:
# Pre-pandemic pareto percentages:
# commit_count = 41.7
# additions = 16.7
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
#
# Post-pandemic pareto percentages:
# commit_count = 16.7
# additions = 8.3
# deletions = 8.3
# agg_loc = 8.3
# agg_complexity = 8.3
# agg_token_count = 8.3
