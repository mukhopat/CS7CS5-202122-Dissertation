# %%
import pandas as pd
import os
from get_repo_name import get_repo_name

repo_name = get_repo_name ( os.path.basename ( os.getcwd() ) )
dataset_path = f'datasets/{repo_name}_modfiles.csv'
df = pd.read_csv (dataset_path)
df.head()
# Out:
#                                 commit_hash commit_author_name  \
# 0  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
# 1  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
# 2  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
# 3  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
# 4  eb81782cdbdc68aaebe4fa561b5fbb73ef866611          Mark Otto
#
#    commit_author_email            commit_datetime  commit_merge  \
# 0  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 1  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 2  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 3  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 4  markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
#
#    dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0       0.627007             0.660057              0.774315
# 1       0.627007             0.660057              0.774315
# 2       0.627007             0.660057              0.774315
# 3       0.627007             0.660057              0.774315
# 4       0.627007             0.660057              0.774315
#
#                     file_name      file_change_type  file_lines_added  \
# 0           baseline-20px.png  ModificationType.ADD                 0
# 1          blueprint-icon.png  ModificationType.ADD                 0
# 2               grid-20px.png  ModificationType.ADD                 0
# 3              grid-940px.png  ModificationType.ADD                 0
# 4  tablesorter-indicators.png  ModificationType.ADD                 0
#
#    file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                   0       NaN              NaN               NaN
# 1                   0       NaN              NaN               NaN
# 2                   0       NaN              NaN               NaN
# 3                   0       NaN              NaN               NaN
# 4                   0       NaN              NaN               NaN

# %%
df.insert ( 1, 'year_month', pd.to_datetime(df['commit_datetime'], utc=True).dt.to_period('M') )
df
# Out:
# G:\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py:1101: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#                                     commit_hash year_month commit_author_name  \
# 0      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 1      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 2      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 3      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 4      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# ...                                         ...        ...                ...
# 58058  9e57dfadac9cd924c35b7ff5b3d82981b59502de    2022-08       Vipin Mishra
# 58059  aad77f32bd58175ab5c3577aed558adf8598b394    2022-08    dependabot[bot]
# 58060  aad77f32bd58175ab5c3577aed558adf8598b394    2022-08    dependabot[bot]
# 58061  a685b9648bf14c853b9a417c7c68f95d93e1aabc    2022-08           XhmikosR
# 58062  a685b9648bf14c853b9a417c7c68f95d93e1aabc    2022-08           XhmikosR
#
#                                      commit_author_email  \
# 0                                    markdotto@gmail.com
# 1                                    markdotto@gmail.com
# 2                                    markdotto@gmail.com
# 3                                    markdotto@gmail.com
# 4                                    markdotto@gmail.com
# ...                                                  ...
# 58058   52159805+thevipinmishra@users.noreply.github.com
# 58059  49699333+dependabot[bot]@users.noreply.github.com
# 58060  49699333+dependabot[bot]@users.noreply.github.com
# 58061                                 xhmikosr@gmail.com
# 58062                                 xhmikosr@gmail.com
#
#                  commit_datetime  commit_merge  dmm_unit_size  \
# 0      2011-04-27 13:53:51-07:00         False       0.627007
# 1      2011-04-27 13:53:51-07:00         False       0.627007
# 2      2011-04-27 13:53:51-07:00         False       0.627007
# 3      2011-04-27 13:53:51-07:00         False       0.627007
# 4      2011-04-27 13:53:51-07:00         False       0.627007
# ...                          ...           ...            ...
# 58058  2022-08-03 21:52:41-07:00         False            NaN
# 58059  2022-08-04 08:29:27+03:00         False            NaN
# 58060  2022-08-04 08:29:27+03:00         False            NaN
# 58061  2022-08-04 09:48:23+03:00         False            NaN
# 58062  2022-08-04 09:48:23+03:00         False            NaN
#
#        dmm_unit_complexity  dmm_unit_interfacing                   file_name  \
# 0                 0.660057              0.774315           baseline-20px.png
# 1                 0.660057              0.774315          blueprint-icon.png
# 2                 0.660057              0.774315               grid-20px.png
# 3                 0.660057              0.774315              grid-940px.png
# 4                 0.660057              0.774315  tablesorter-indicators.png
# ...                    ...                   ...                         ...
# 58058                  NaN                   NaN                  index.html
# 58059                  NaN                   NaN           package-lock.json
# 58060                  NaN                   NaN                package.json
# 58061                  NaN                   NaN           package-lock.json
# 58062                  NaN                   NaN                package.json
#
#               file_change_type  file_lines_added  file_lines_deleted  \
# 0         ModificationType.ADD                 0                   0
# 1         ModificationType.ADD                 0                   0
# 2         ModificationType.ADD                 0                   0
# 3         ModificationType.ADD                 0                   0
# 4         ModificationType.ADD                 0                   0
# ...                        ...               ...                 ...
# 58058  ModificationType.MODIFY                59                   0
# 58059  ModificationType.MODIFY                 7                   7
# 58060  ModificationType.MODIFY                 1                   1
# 58061  ModificationType.MODIFY               591                 490
# 58062  ModificationType.MODIFY                 5                   5
#
#        file_loc  file_complexity  file_token_count
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4           NaN              NaN               NaN
# ...         ...              ...               ...
# 58058       NaN              NaN               NaN
# 58059       NaN              NaN               NaN
# 58060       NaN              NaN               NaN
# 58061       NaN              NaN               NaN
# 58062       NaN              NaN               NaN
#
# [58063 rows x 16 columns]

# %%
df.drop ( df[df.year_month == '2022-08'].index, inplace = True )
df
# Out:
#                                     commit_hash year_month commit_author_name  \
# 0      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 1      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 2      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 3      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# 4      eb81782cdbdc68aaebe4fa561b5fbb73ef866611    2011-04          Mark Otto
# ...                                         ...        ...                ...
# 58046  17aa6732ab83653501e70dc88afcccead1dc0892    2022-07    Julien Déramond
# 58047  17aa6732ab83653501e70dc88afcccead1dc0892    2022-07    Julien Déramond
# 58048  85530309fabf6c7316e8511016d3daed1ab3aee4    2022-07    Julien Déramond
# 58049  a4f81c04b5da87b9b05ceeeee87ae235f836d4e6    2022-07    Julien Déramond
# 58050  a4f81c04b5da87b9b05ceeeee87ae235f836d4e6    2022-07    Julien Déramond
#
#               commit_author_email            commit_datetime  commit_merge  \
# 0             markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 1             markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 2             markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 3             markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# 4             markdotto@gmail.com  2011-04-27 13:53:51-07:00         False
# ...                           ...                        ...           ...
# 58046  julien.deramond@orange.com  2022-07-29 21:49:01+02:00         False
# 58047  julien.deramond@orange.com  2022-07-29 21:49:01+02:00         False
# 58048  julien.deramond@orange.com  2022-07-29 21:54:18+02:00         False
# 58049  julien.deramond@orange.com  2022-07-31 09:41:12+03:00         False
# 58050  julien.deramond@orange.com  2022-07-31 09:41:12+03:00         False
#
#        dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing  \
# 0           0.627007             0.660057              0.774315
# 1           0.627007             0.660057              0.774315
# 2           0.627007             0.660057              0.774315
# 3           0.627007             0.660057              0.774315
# 4           0.627007             0.660057              0.774315
# ...              ...                  ...                   ...
# 58046            NaN                  NaN                   NaN
# 58047            NaN                  NaN                   NaN
# 58048            NaN                  NaN                   NaN
# 58049            NaN                  NaN                   NaN
# 58050            NaN                  NaN                   NaN
#
#                         file_name         file_change_type  file_lines_added  \
# 0               baseline-20px.png     ModificationType.ADD                 0
# 1              blueprint-icon.png     ModificationType.ADD                 0
# 2                   grid-20px.png     ModificationType.ADD                 0
# 3                  grid-940px.png     ModificationType.ADD                 0
# 4      tablesorter-indicators.png     ModificationType.ADD                 0
# ...                           ...                      ...               ...
# 58046             introduction.md  ModificationType.MODIFY                 1
# 58047                examples.yml  ModificationType.MODIFY                 1
# 58048             _variables.scss  ModificationType.MODIFY                 1
# 58049           package-lock.json  ModificationType.MODIFY                35
# 58050                package.json  ModificationType.MODIFY                 1
#
#        file_lines_deleted  file_loc  file_complexity  file_token_count
# 0                       0       NaN              NaN               NaN
# 1                       0       NaN              NaN               NaN
# 2                       0       NaN              NaN               NaN
# 3                       0       NaN              NaN               NaN
# 4                       0       NaN              NaN               NaN
# ...                   ...       ...              ...               ...
# 58046                   1       NaN              NaN               NaN
# 58047                   1       NaN              NaN               NaN
# 58048                   1       NaN              NaN               NaN
# 58049                  35       NaN              NaN               NaN
# 58050                   1       NaN              NaN               NaN
#
# [58051 rows x 16 columns]

# %%
grouped_df = df.groupby(['year_month']).agg({
    
    'commit_hash': 'nunique', 
    'file_lines_added': 'sum', 
    'file_lines_deleted': 'sum',
    'file_loc': 'sum',
    'file_complexity': 'sum',
    'file_token_count': 'sum',
    'dmm_unit_size': 'mean',
    'dmm_unit_complexity': 'mean',
    'dmm_unit_interfacing': 'mean'
} ).reset_index(level=[0])


grouped_df.rename(columns = {
    'commit_hash': 'commit_count',
    'file_lines_added': 'additions',
    'file_lines_deleted': 'deletions',
    'file_loc': 'agg_loc',
    'file_complexity': 'agg_complexity',
    'file_token_count': 'agg_token_count',
}, inplace = True)

grouped_df
# Out:
#     year_month  commit_count  additions  deletions  agg_loc  agg_complexity  \
# 0      2011-04            10       6018        473   1767.0           802.0
# 1      2011-05             7       4124       2398     80.0            20.0
# 2      2011-06            44       3058       4872    384.0           295.0
# 3      2011-07            19        975        449    267.0            59.0
# 4      2011-08           194       7538       6520   3125.0          1235.0
# ..         ...           ...        ...        ...      ...             ...
# 113    2022-03            84       3079       3876  17215.0          2958.0
# 114    2022-04            76       5804       3674   7308.0          1316.0
# 115    2022-05            76      17944      16621  33802.0          9845.0
# 116    2022-06            47       2948       2503  11361.0          2273.0
# 117    2022-07            58       2545       9038  29030.0          9201.0
#
#      agg_token_count  dmm_unit_size  dmm_unit_complexity  dmm_unit_interfacing
# 0            21032.0       0.607772             0.585377              0.806309
# 1              664.0       0.275748             0.814401              0.803438
# 2             9813.0       0.723452             0.640178              0.420451
# 3             2183.0       1.000000             0.000000              0.000000
# 4            26259.0       0.779613             0.550695              0.630656
# ..               ...            ...                  ...                   ...
# 113          97012.0       0.373446             0.572800              0.549909
# 114          43495.0       0.712159             0.316700              0.882979
# 115         256934.0       0.623509             0.834515              0.099291
# 116          68556.0       0.583333             0.583333              0.728070
# 117         230991.0       0.078082             0.993151              0.993151
#
# [118 rows x 10 columns]

# %%
grouped_df.to_csv ( f'datasets/{repo_name}_groupedby_yearmonth.csv', index = False )
